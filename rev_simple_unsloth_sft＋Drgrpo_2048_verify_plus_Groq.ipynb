# %% [markdown]
# <a href="https://colab.research.google.com/github/Haraguchi-T/minicomp-codes/blob/main/rev_simple_unsloth_sft%EF%BC%8BDrgrpo_2048_verify_plus_Groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## GRPOを行うためのシンプルなコード
#
# GRPOとはLLMにオンライン強化学習の一種です．
# 以下が簡単なフロー解説になります．
#
# １．まず学習対象のモデルである問題に対して複数生成します．(同じプロンプトで複数回生成する)
#
# ２．次に生成した各サンプルの解答を答え合わせします．あっていたら1点，間違っていたら0点を振ります．それ以外にも同時に色々なポイント(報酬)を与えます．
#
# ３．次に各生成サンプルの報酬を"相対化(報酬分布の正規化)"します．
#
# ４．最後に計算された相対的な報酬を元に勾配を更新(モデルパラメータの更新)をします．
#
# ５．これをループしていきます．![1_IBSrfnY3ULbBsxi6RD2kdg.jpg](data:image/jpeg;base64,...)
#
#
# GRPOを効果的に機能させるためには、まずモデルに基本的な回答フォーマットを学習させる必要があります。
# これをスキップすると、モデルが適切な形式で回答を生成できず、報酬関数が正しく機能しません。
# そのため、以下の流れで学習を行います：
#
# 1. **SFT（Supervised Fine-Tuning）**: 少量のデータで正しい回答フォーマットを学習
# 2. **GRPO**: 強化学習で回答の質を向上

# %% [markdown]
# ##必要なライブラリのインストール
# ※結構長いです．最後の方にエラーがでますが，一旦は無視できるので，ほっといて下さい()
#
# 今回は学習ライブラリとしてunslothを使います．シングルGPUに最適化した超高速学習ライブラリです．GRPOは仕組み上推論も同時に行うオンライン強化学習なので，推論ライブラリのvllmを使います．unslothは標準でvllmをサポートしており，公式でもこのセットが推奨されています．
#
# ※以下のインストールセルはipythonのカーネル再起動を要求することがあります．その通りセッションを再起動して再度実行してください．

# %%
# !pip install --no-deps unsloth vllm==0.8.5.post1

import sys, re, requests; modules = list(sys.modules.keys())
for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install math-verify[antlr4_13_2]
# !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" huggingface_hub hf_transfer pyyaml

# vLLMの公式要件ファイルを取得
f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
with open("vllm_requirements.txt", "wb") as file:
    file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f)) # 競合箇所の削除
# !pip install -r vllm_requirements.txt
# 暫定対応として追加
# 途中で聞かれるY/nは全てYを選択する
# !pip uninstall -y trl unsloth unsloth_zoo
# !pip install trl==0.19.1 unsloth==2025.7.8 unsloth_zoo==2025.7.10
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (2025.7.8)
# Requirement already satisfied: vllm==0.8.5.post1 in /usr/local/lib/python3.12/dist-packages (0.8.5.post1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.0)
# Requirement already satisfied: xformers==0.0.29.post3 in /usr/local/lib/python3.12/dist-packages (0.0.29.post3)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.0)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: triton in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (25.1.1)
# Requirement already satisfied: unsloth_zoo in /usr/local/lib/python3.12/dist-packages (2025.7.10)
# Requirement already satisfied: math-verify[antlr4_13_2] in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Requirement already satisfied: latex2sympy2_extended==1.10.2 in /usr/local/lib/python3.12/dist-packages (from math-verify[antlr4_13_2]) (1.10.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from latex2sympy2_extended==1.10.2->math-verify[antlr4_13_2]) (1.13.1)
# Requirement already satisfied: antlr4-python3-runtime<=4.13.2,>=4.9.3 in /usr/local/lib/python3.12/dist-packages (from latex2sympy2_extended==1.10.2->math-verify[antlr4_13_2]) (4.13.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->latex2sympy2_extended==1.10.2->math-verify[antlr4_13_2]) (1.3.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (4.25.8)
# Requirement already satisfied: datasets<4.0.0,>=3.4.1 in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (2023.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<4.0.0,>=3.4.1) (1.17.0)
# Ignoring outlines: markers 'platform_machine == "s390x"' don't match your environment
# Ignoring importlib_metadata: markers 'python_version < "3.10"' don't match your environment
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 2)) (5.5.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 9)) (9.0.0)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 10)) (0.21.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 11)) (4.25.8)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.116.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 13)) (3.12.15)
# Requirement already satisfied: openai>=1.99.1 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 14)) (1.100.0)
# Requirement already satisfied: pydantic>=2.11.7 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 15)) (2.11.7)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 16)) (0.22.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 18)) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 19)) (0.11.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 20)) (0.10.12)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 21)) (0.7.30)
# Collecting outlines_core==0.2.10 (from -r vllm_requirements.txt (line 22))
#   Using cached outlines_core-0.2.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: diskcache==5.6.3 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 25)) (5.6.3)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 26)) (1.2.2)
# Collecting xgrammar==0.1.21 (from -r vllm_requirements.txt (line 27))
#   Using cached xgrammar-0.1.21-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 28)) (4.14.1)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 29)) (3.19.1)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 30)) (0.2.1.1.post6)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 31)) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 32)) (0.19.0)
# Requirement already satisfied: gguf>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 33)) (0.17.1)
# Requirement already satisfied: mistral_common>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (1.8.4)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 36)) (4.12.0.88)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 37)) (6.0.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 38)) (1.17.0)
# Requirement already satisfied: setuptools<80,>=77.0.3 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 39)) (79.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 40)) (0.8.1)
# Collecting compressed-tensors==0.11.0 (from -r vllm_requirements.txt (line 41))
#   Using cached compressed_tensors-0.11.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting depyf==0.19.0 (from -r vllm_requirements.txt (line 42))
#   Using cached depyf-0.19.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 43)) (3.1.1)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 44)) (1.1.0)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 45)) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 46)) (1.16.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 47)) (1.13.0)
# Requirement already satisfied: pybase64 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 48)) (1.4.2)
# Requirement already satisfied: cbor2 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 49)) (5.7.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 50)) (1.3.6)
# Requirement already satisfied: openai-harmony>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from -r vllm_requirements.txt (line 51)) (0.0.4)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (2.6.0)
# Requirement already satisfied: transformers>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (4.55.2)
# Requirement already satisfied: triton in /usr/local/lib/python3.12/dist-packages (from xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (3.2.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from compressed-tensors==0.11.0->-r vllm_requirements.txt (line 41)) (2.4.6)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->-r vllm_requirements.txt (line 42)) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->-r vllm_requirements.txt (line 42)) (0.3.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->-r vllm_requirements.txt (line 6)) (2025.8.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.21.1->-r vllm_requirements.txt (line 10)) (0.34.4)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.47.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->-r vllm_requirements.txt (line 13)) (1.20.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->-r vllm_requirements.txt (line 14)) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->-r vllm_requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->-r vllm_requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->-r vllm_requirements.txt (line 14)) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->-r vllm_requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r vllm_requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r vllm_requirements.txt (line 15)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->-r vllm_requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: interegular>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lm-format-enforcer<0.11,>=0.10.11->-r vllm_requirements.txt (line 20)) (0.3.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lm-format-enforcer<0.11,>=0.10.11->-r vllm_requirements.txt (line 20)) (25.0)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (4.25.1)
# Requirement already satisfied: pydantic-extra-types>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (2.10.5)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.0.8)
# Requirement already satisfied: jinja2>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.35.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.7.0)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.16.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.15.0)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.1.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.99.1->-r vllm_requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.99.1->-r vllm_requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.21.1->-r vllm_requirements.txt (line 10)) (2023.9.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.21.1->-r vllm_requirements.txt (line 10)) (1.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.5->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (0.27.0)
# Requirement already satisfied: pycountry>=23 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (24.6.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=1.10.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.38.0->xgrammar==0.1.21->-r vllm_requirements.txt (line 27)) (0.6.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (8.2.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (15.0.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (0.5.0.post1)
# Requirement already satisfied: rignore>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.6.4)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.35.0)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (1.17.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->-r vllm_requirements.txt (line 35)) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->-r vllm_requirements.txt (line 12)) (0.1.2)
# Using cached outlines_core-0.2.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Using cached xgrammar-0.1.21-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
# Using cached compressed_tensors-0.11.0-py3-none-any.whl (179 kB)
# Using cached depyf-0.19.0-py3-none-any.whl (39 kB)
# Installing collected packages: outlines_core, depyf, xgrammar, compressed-tensors
#   Attempting uninstall: outlines_core
#     Found existing installation: outlines_core 0.1.26
#     Uninstalling outlines_core-0.1.26:
#       Successfully uninstalled outlines_core-0.1.26
#   Attempting uninstall: depyf
#     Found existing installation: depyf 0.18.0
#     Uninstalling depyf-0.18.0:
#       Successfully uninstalled depyf-0.18.0
#   Attempting uninstall: xgrammar
#     Found existing installation: xgrammar 0.1.18
#     Uninstalling xgrammar-0.1.18:
#       Successfully uninstalled xgrammar-0.1.18
#   Attempting uninstall: compressed-tensors
#     Found existing installation: compressed-tensors 0.9.3
#     Uninstalling compressed-tensors-0.9.3:
#       Successfully uninstalled compressed-tensors-0.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# outlines 0.1.11 requires outlines_core==0.1.26, but you have outlines-core 0.2.10 which is incompatible.
# vllm 0.8.5.post1 requires compressed-tensors==0.9.3, but you have compressed-tensors 0.11.0 which is incompatible.
# vllm 0.8.5.post1 requires depyf==0.18.0, but you have depyf 0.19.0 which is incompatible.
# vllm 0.8.5.post1 requires xformers==0.0.29.post2; platform_system == "Linux" and platform_machine == "x86_64", but you have xformers 0.0.29.post3 which is incompatible.
# vllm 0.8.5.post1 requires xgrammar==0.1.18; platform_machine == "x86_64" or platform_machine == "aarch64", but you have xgrammar 0.1.21 which is incompatible.
# Successfully installed compressed-tensors-0.11.0 depyf-0.19.0 outlines_core-0.2.10 xgrammar-0.1.21
# Found existing installation: trl 0.19.1
# Uninstalling trl-0.19.1:
#   Successfully uninstalled trl-0.19.1
# Found existing installation: unsloth 2025.7.8
# Uninstalling unsloth-2025.7.8:
#   Successfully uninstalled unsloth-2025.7.8
# Found existing installation: unsloth_zoo 2025.7.10
# Uninstalling unsloth_zoo-2025.7.10:
#   Successfully uninstalled unsloth_zoo-2025.7.10
# Collecting trl==0.19.1
#   Using cached trl-0.19.1-py3-none-any.whl.metadata (10 kB)
# Collecting unsloth==2025.7.8
#   Using cached unsloth-2025.7.8-py3-none-any.whl.metadata (47 kB)
# Collecting unsloth_zoo==2025.7.10
#   Using cached unsloth_zoo-2025.7.10-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl==0.19.1) (1.10.0)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from trl==0.19.1) (3.6.0)
# Requirement already satisfied: transformers>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from trl==0.19.1) (4.55.2)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (2.6.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.0.29.post3)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.47.0)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (3.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (25.0)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.9.28)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (2.0.2)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.17.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (4.25.8)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.34.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth==2025.7.8) (0.21.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo==2025.7.10) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo==2025.7.10) (11.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo==2025.7.10) (2024.11.6)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo==2025.7.10) (0.19.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo==2025.7.10) (4.14.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl==0.19.1) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl==0.19.1) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0.0->trl==0.19.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (2023.9.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->unsloth==2025.7.8) (1.1.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (12.4.127)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (79.0.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth==2025.7.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth==2025.7.8) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.0->trl==0.19.1) (0.21.4)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth==2025.7.8) (8.0.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2025.7.8) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2025.7.8) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2025.7.8) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth==2025.7.8) (4.4.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl==0.19.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl==0.19.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl==0.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0.0->trl==0.19.1) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro->unsloth==2025.7.8) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro->unsloth==2025.7.8) (2.19.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth==2025.7.8) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth==2025.7.8) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl==0.19.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl==0.19.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0.0->trl==0.19.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0.0->trl==0.19.1) (1.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth==2025.7.8) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.0.0->trl==0.19.1) (1.17.0)
# Using cached trl-0.19.1-py3-none-any.whl (376 kB)
# Using cached unsloth-2025.7.8-py3-none-any.whl (299 kB)
# Using cached unsloth_zoo-2025.7.10-py3-none-any.whl (166 kB)
# Installing collected packages: trl, unsloth_zoo, unsloth
# Successfully installed trl-0.19.1 unsloth-2025.7.8 unsloth_zoo-2025.7.10

# %%
# !pip install vllm
# !pip install -U datasets
# !pip install fsspec==2023.9.2

# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
# !pip install --no-deps unsloth

# !pip install groq
# Out:
# Requirement already satisfied: vllm in /usr/local/lib/python3.12/dist-packages (0.8.5.post1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm) (5.5.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from vllm) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from vllm) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vllm) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vllm) (4.67.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.0.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.51.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.55.2)
# Requirement already satisfied: huggingface-hub>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub[hf_xet]>=0.30.0->vllm) (0.34.4)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.21.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from vllm) (4.25.8)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.116.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from vllm) (3.12.15)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.100.0)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.11.7)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.22.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm) (11.3.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.11.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.10.12)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.9 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.7.30)
# Requirement already satisfied: outlines==0.1.11 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.2.2)
# Collecting xgrammar==0.1.18 (from vllm)
#   Using cached xgrammar-0.1.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.14.1)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (3.19.1)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.12/dist-packages (from vllm) (0.2.1.1.post6)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.17.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from vllm) (8.0.0)
# Requirement already satisfied: mistral_common>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from mistral_common[opencv]>=1.5.4->vllm) (1.8.4)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.12.0.88)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.17.0)
# Requirement already satisfied: setuptools>=74.1.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (79.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm) (0.8.1)
# Collecting compressed-tensors==0.9.3 (from vllm)
#   Using cached compressed_tensors-0.9.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting depyf==0.18.0 (from vllm)
#   Using cached depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm) (3.1.1)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm) (1.1.0)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm) (3.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from vllm) (1.16.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from vllm) (1.13.0)
# Requirement already satisfied: opentelemetry-sdk<1.27.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-api<1.27.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp<1.27.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.4.13)
# Requirement already satisfied: numba==0.61.2 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.61.2)
# Requirement already satisfied: ray!=2.44.*,>=2.43.0 in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]!=2.44.*,>=2.43.0->vllm) (2.48.0)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.6.0)
# Requirement already satisfied: torchaudio==2.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.6.0)
# Requirement already satisfied: torchvision==0.21.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.21.0)
# Collecting xformers==0.0.29.post2 (from vllm)
#   Using cached xformers-0.0.29.post2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from depyf==0.18.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.18.0->vllm) (0.3.8)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba==0.61.2->vllm) (0.44.0)
# Requirement already satisfied: interegular in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (0.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (3.1.6)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (4.25.1)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.12/dist-packages (from outlines==0.1.11->vllm) (20250811)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm)
#   Using cached outlines_core-0.1.26-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->vllm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.6.0->vllm) (1.3.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.47.2)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.0.8)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.35.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.0->huggingface-hub[hf_xet]>=0.30.0->vllm) (25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.0->huggingface-hub[hf_xet]>=0.30.0->vllm) (1.1.7)
# Requirement already satisfied: pydantic-extra-types>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.5.4->mistral_common[opencv]>=1.5.4->vllm) (2.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.52.0->vllm) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.52.0->vllm) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<1.27.0,>=1.26.0->vllm) (1.2.18)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->vllm) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.26.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.26.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.26.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp<1.27.0,>=1.26.0->vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<1.27.0,>=1.26.0->vllm) (0.47b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->vllm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->vllm) (0.4.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray!=2.44.*,>=2.43.0->ray[cgraph]!=2.44.*,>=2.43.0->vllm) (8.2.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray!=2.44.*,>=2.43.0->ray[cgraph]!=2.44.*,>=2.43.0->vllm) (1.1.1)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]!=2.44.*,>=2.43.0->vllm) (13.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm) (2025.8.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.51.1->vllm) (0.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm) (1.20.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.6->opentelemetry-api<1.27.0,>=1.26.0->vllm) (1.17.3)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm) (2.7.0)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.16.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.15.0)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.1.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->outlines==0.1.11->vllm) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->outlines==0.1.11->vllm) (0.27.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]!=2.44.*,>=2.43.0->vllm) (0.8.3)
# Requirement already satisfied: rignore>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.35.0)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.1.2)
# Using cached compressed_tensors-0.9.3-py3-none-any.whl (98 kB)
# Using cached depyf-0.18.0-py3-none-any.whl (38 kB)
# Using cached xformers-0.0.29.post2-cp312-cp312-manylinux_2_28_x86_64.whl (44.3 MB)
# Using cached xgrammar-0.1.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Using cached outlines_core-0.1.26-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
# Installing collected packages: depyf, xformers, outlines_core, xgrammar, compressed-tensors
#   Attempting uninstall: depyf
#     Found existing installation: depyf 0.19.0
#     Uninstalling depyf-0.19.0:
#       Successfully uninstalled depyf-0.19.0
#   Attempting uninstall: xformers
#     Found existing installation: xformers 0.0.29.post3
#     Uninstalling xformers-0.0.29.post3:
#       Successfully uninstalled xformers-0.0.29.post3
#   Attempting uninstall: outlines_core
#     Found existing installation: outlines_core 0.2.10
#     Uninstalling outlines_core-0.2.10:
#       Successfully uninstalled outlines_core-0.2.10
#   Attempting uninstall: xgrammar
#     Found existing installation: xgrammar 0.1.21
#     Uninstalling xgrammar-0.1.21:
#       Successfully uninstalled xgrammar-0.1.21
#   Attempting uninstall: compressed-tensors
#     Found existing installation: compressed-tensors 0.11.0
#     Uninstalling compressed-tensors-0.11.0:
#       Successfully uninstalled compressed-tensors-0.11.0
# Successfully installed compressed-tensors-0.9.3 depyf-0.18.0 outlines_core-0.1.26 xformers-0.0.29.post2 xgrammar-0.1.18
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (3.6.0)
# Collecting datasets
#   Using cached datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2023.9.2)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.34.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached datasets-4.0.0-py3-none-any.whl (494 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.6.0
#     Uninstalling datasets-3.6.0:
#       Successfully uninstalled datasets-3.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth 2025.7.8 requires datasets<4.0.0,>=3.4.1, but you have datasets 4.0.0 which is incompatible.
# unsloth-zoo 2025.7.10 requires datasets<4.0.0,>=3.4.1, but you have datasets 4.0.0 which is incompatible.
# Successfully installed datasets-4.0.0
# Requirement already satisfied: fsspec==2023.9.2 in /usr/local/lib/python3.12/dist-packages (2023.9.2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.0)
# Collecting xformers==0.0.29.post3
#   Using cached xformers-0.0.29.post3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.0)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: triton in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (25.1.1)
# Requirement already satisfied: unsloth_zoo in /usr/local/lib/python3.12/dist-packages (2025.7.10)
# Using cached xformers-0.0.29.post3-cp312-cp312-manylinux_2_28_x86_64.whl (43.4 MB)
# Installing collected packages: xformers
#   Attempting uninstall: xformers
#     Found existing installation: xformers 0.0.29.post2
#     Uninstalling xformers-0.0.29.post2:
#       Successfully uninstalled xformers-0.0.29.post2
# Successfully installed xformers-0.0.29.post3
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (4.25.8)
# Collecting datasets<4.0.0,>=3.4.1
#   Using cached datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (2023.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0) (1.1.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<4.0.0,>=3.4.1) (1.17.0)
# Using cached datasets-3.6.0-py3-none-any.whl (491 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-3.6.0
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (2025.7.8)
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (0.31.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.1)

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# absolufy-imports                         0.3.1
# accelerate                               1.10.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.12.15
# aiosignal                                1.4.0
# airportsdata                             20250811
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# altair                                   5.5.0
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.13.2
# anyio                                    4.10.0
# anywidget                                0.9.18
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# array_record                             0.7.2
# arviz                                    0.22.0
# astor                                    0.8.1
# astropy                                  7.1.0
# astropy-iers-data                        0.2025.8.18.0.40.14
# astunparse                               1.6.3
# atpublic                                 5.1
# attrs                                    25.3.0
# audioread                                3.0.1
# Authlib                                  1.6.1
# autograd                                 1.8.0
# babel                                    2.17.0
# backcall                                 0.2.0
# beartype                                 0.21.0
# beautifulsoup4                           4.13.4
# betterproto                              2.0.0b6
# bigframes                                2.15.0
# bigquery-magics                          0.10.2
# bitsandbytes                             0.47.0
# blake3                                   1.0.5
# bleach                                   6.2.0
# blinker                                  1.9.0
# blis                                     1.3.0
# blobfile                                 3.0.0
# blosc2                                   3.7.1
# bokeh                                    3.7.3
# Bottleneck                               1.4.2
# bqplot                                   0.12.45
# branca                                   0.8.1
# Brotli                                   1.1.0
# build                                    1.3.0
# CacheControl                             0.14.3
# cachetools                               5.5.2
# catalogue                                2.0.10
# cbor2                                    5.7.0
# certifi                                  2025.8.3
# cffi                                     1.17.1
# chardet                                  5.2.0
# charset-normalizer                       3.4.3
# chex                                     0.1.90
# clarabel                                 0.11.1
# click                                    8.2.1
# cloudpathlib                             0.21.1
# cloudpickle                              3.1.1
# cmake                                    3.31.6
# cmdstanpy                                1.2.5
# colorcet                                 3.1.0
# colorlover                               0.3.0
# colour                                   0.1.5
# community                                1.0.0b1
# compressed-tensors                       0.9.3
# confection                               0.1.5
# cons                                     0.4.7
# contourpy                                1.3.3
# cramjam                                  2.11.0
# cryptography                             43.0.3
# cuda-python                              12.6.2.post1
# cudf-cu12                                25.6.0
# cudf-polars-cu12                         25.6.0
# cufflinks                                0.17.3
# cuml-cu12                                25.6.0
# cupy-cuda12x                             13.3.0
# curl_cffi                                0.13.0
# cut-cross-entropy                        25.1.1
# cuvs-cu12                                25.6.1
# cvxopt                                   1.3.2
# cvxpy                                    1.6.7
# cycler                                   0.12.1
# cyipopt                                  1.5.0
# cymem                                    2.0.11
# Cython                                   3.0.12
# dask                                     2025.5.0
# dask-cuda                                25.6.0
# dask-cudf-cu12                           25.6.0
# dataproc-spark-connect                   0.8.3
# datasets                                 3.6.0
# db-dtypes                                1.4.3
# dbus-python                              1.2.18
# debugpy                                  1.8.15
# decorator                                4.4.2
# defusedxml                               0.7.1
# Deprecated                               1.2.18
# depyf                                    0.18.0
# diffusers                                0.34.0
# dill                                     0.3.8
# diskcache                                5.6.3
# distributed                              2025.5.0
# distributed-ucxx-cu12                    0.44.0
# distro                                   1.9.0
# dlib                                     19.24.6
# dm-tree                                  0.1.9
# dnspython                                2.7.0
# docstring_parser                         0.17.0
# docutils                                 0.21.2
# dopamine_rl                              4.1.2
# duckdb                                   1.3.2
# earthengine-api                          1.5.24
# easydict                                 1.13
# editdistance                             0.8.1
# eerepr                                   0.1.2
# einops                                   0.8.1
# email_validator                          2.2.0
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# et_xmlfile                               2.0.0
# etils                                    1.13.0
# etuples                                  0.3.10
# Farama-Notifications                     0.0.4
# fastai                                   2.8.3
# fastapi                                  0.116.1
# fastapi-cli                              0.0.8
# fastapi-cloud-cli                        0.1.5
# fastcore                                 1.8.7
# fastdownload                             0.0.7
# fastjsonschema                           2.21.2
# fastprogress                             1.0.3
# fastrlock                                0.8.3
# fasttransform                            0.0.2
# ffmpy                                    0.6.1
# filelock                                 3.19.1
# firebase-admin                           6.9.0
# Flask                                    3.1.1
# flatbuffers                              25.2.10
# flax                                     0.10.6
# folium                                   0.20.0
# fonttools                                4.59.1
# frozendict                               2.4.6
# frozenlist                               1.7.0
# fsspec                                   2023.9.2
# future                                   1.0.0
# gast                                     0.6.0
# gcsfs                                    2025.3.0
# GDAL                                     3.8.4
# gdown                                    5.2.0
# geemap                                   0.35.3
# geocoder                                 1.38.1
# geographiclib                            2.0
# geopandas                                1.1.1
# geopy                                    2.4.1
# gguf                                     0.17.1
# gin-config                               0.5.0
# gitdb                                    4.0.12
# GitPython                                3.1.45
# glob2                                    0.7
# google                                   2.0.3
# google-adk                               1.11.0
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.25.1
# google-api-python-client                 2.179.0
# google-auth                              2.38.0
# google-auth-httplib2                     0.2.0
# google-auth-oauthlib                     1.2.2
# google-cloud-aiplatform                  1.109.0
# google-cloud-appengine-logging           1.6.2
# google-cloud-audit-log                   0.3.2
# google-cloud-bigquery                    3.35.1
# google-cloud-bigquery-connection         1.18.3
# google-cloud-bigquery-storage            2.32.0
# google-cloud-core                        2.4.3
# google-cloud-dataproc                    5.21.0
# google-cloud-datastore                   2.21.0
# google-cloud-firestore                   2.21.0
# google-cloud-functions                   1.20.4
# google-cloud-language                    2.17.2
# google-cloud-logging                     3.12.1
# google-cloud-resource-manager            1.14.2
# google-cloud-secret-manager              2.24.0
# google-cloud-spanner                     3.57.0
# google-cloud-speech                      2.33.0
# google-cloud-storage                     2.19.0
# google-cloud-trace                       1.16.2
# google-cloud-translate                   3.21.1
# google-colab                             1.0.0
# google-crc32c                            1.7.1
# google-genai                             1.30.0
# google-generativeai                      0.8.5
# google-pasta                             0.2.0
# google-resumable-media                   2.7.2
# googleapis-common-protos                 1.70.0
# googledrivedownloader                    1.1.0
# gradio                                   5.42.0
# gradio_client                            1.11.1
# graphviz                                 0.21
# greenlet                                 3.2.4
# groovy                                   0.1.2
# groq                                     0.31.0
# grpc-google-iam-v1                       0.14.2
# grpc-interceptor                         0.15.4
# grpcio                                   1.74.0
# grpcio-status                            1.71.2
# grpclib                                  0.4.8
# gspread                                  6.2.1
# gspread-dataframe                        4.0.0
# gym                                      0.25.2
# gym-notices                              0.1.0
# gymnasium                                1.2.0
# h11                                      0.16.0
# h2                                       4.2.0
# h5netcdf                                 1.6.4
# h5py                                     3.14.0
# hdbscan                                  0.8.40
# hf_transfer                              0.1.9
# hf-xet                                   1.1.7
# highspy                                  1.11.0
# holidays                                 0.78
# holoviews                                1.21.0
# hpack                                    4.1.0
# html5lib                                 1.1
# httpcore                                 1.0.9
# httpimport                               1.4.1
# httplib2                                 0.22.0
# httptools                                0.6.4
# httpx                                    0.28.1
# httpx-sse                                0.4.1
# huggingface-hub                          0.34.4
# humanize                                 4.12.3
# hyperframe                               6.1.0
# hyperopt                                 0.2.7
# ibis-framework                           9.5.0
# idna                                     3.10
# imageio                                  2.37.0
# imageio-ffmpeg                           0.6.0
# imagesize                                1.4.1
# imbalanced-learn                         0.14.0
# immutabledict                            4.2.1
# importlib_metadata                       8.0.0
# importlib_resources                      6.5.2
# imutils                                  0.5.4
# inflect                                  7.5.0
# iniconfig                                2.1.0
# intel-cmplr-lib-ur                       2025.2.1
# intel-openmp                             2025.2.1
# interegular                              0.3.3
# ipyevents                                2.0.2
# ipyfilechooser                           0.6.0
# ipykernel                                6.17.1
# ipyleaflet                               0.20.0
# ipyparallel                              8.8.0
# ipython                                  7.34.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipytree                                  0.2.2
# ipywidgets                               7.7.1
# itsdangerous                             2.2.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.0.1
# jaraco.functools                         4.2.1
# jax                                      0.5.3
# jax-cuda12-pjrt                          0.5.3
# jax-cuda12-plugin                        0.5.3
# jaxlib                                   0.5.3
# jeepney                                  0.9.0
# jieba                                    0.42.1
# Jinja2                                   3.1.6
# jiter                                    0.10.0
# joblib                                   1.5.1
# jsonpatch                                1.33
# jsonpickle                               4.1.1
# jsonpointer                              3.0.0
# jsonschema                               4.25.1
# jsonschema-specifications                2025.4.1
# jupyter-client                           6.1.12
# jupyter-console                          6.1.0
# jupyter_core                             5.8.1
# jupyter_kernel_gateway                   2.5.2
# jupyter-leaflet                          0.20.0
# jupyter-server                           1.16.0
# jupyterlab_pygments                      0.3.0
# jupyterlab_widgets                       3.0.15
# jupytext                                 1.17.2
# kaggle                                   1.7.4.5
# kagglehub                                0.3.12
# keras                                    3.10.0
# keras-hub                                0.21.1
# keras-nlp                                0.21.1
# keyring                                  25.6.0
# keyrings.google-artifactregistry-auth    1.1.2
# kiwisolver                               1.4.9
# langchain                                0.3.27
# langchain-core                           0.3.74
# langchain-text-splitters                 0.3.9
# langcodes                                3.5.0
# langsmith                                0.4.14
# language_data                            1.3.0
# lark                                     1.2.2
# latex2sympy2_extended                    1.10.2
# launchpadlib                             1.10.16
# lazr.restfulclient                       0.14.4
# lazr.uri                                 1.0.6
# lazy_loader                              0.4
# libclang                                 18.1.1
# libcudf-cu12                             25.6.0
# libcugraph-cu12                          25.6.0
# libcuml-cu12                             25.6.0
# libcuvs-cu12                             25.6.1
# libkvikio-cu12                           25.6.0
# libpysal                                 4.13.0
# libraft-cu12                             25.6.0
# librmm-cu12                              25.6.0
# librosa                                  0.11.0
# libucx-cu12                              1.18.1
# libucxx-cu12                             0.44.0
# lightgbm                                 4.6.0
# linkify-it-py                            2.0.3
# llguidance                               0.7.30
# llvmlite                                 0.44.0
# lm-format-enforcer                       0.10.12
# locket                                   1.0.0
# logical-unification                      0.4.6
# lxml                                     5.4.0
# Mako                                     1.1.3
# marisa-trie                              1.3.0
# Markdown                                 3.8.2
# markdown-it-py                           4.0.0
# MarkupSafe                               3.0.2
# math-verify                              0.8.0
# matplotlib                               3.10.0
# matplotlib-inline                        0.1.7
# matplotlib-venn                          1.1.2
# mcp                                      1.13.0
# mdit-py-plugins                          0.5.0
# mdurl                                    0.1.2
# miniKanren                               1.0.5
# missingno                                0.5.2
# mistral_common                           1.8.4
# mistune                                  3.1.3
# mizani                                   0.13.5
# mkl                                      2025.2.0
# ml_dtypes                                0.5.3
# mlxtend                                  0.23.4
# more-itertools                           10.7.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.1.1
# msgspec                                  0.19.0
# multidict                                6.6.4
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# multitasking                             0.0.12
# murmurhash                               1.0.13
# music21                                  9.3.0
# namex                                    0.1.0
# narwhals                                 2.1.2
# natsort                                  8.4.0
# nbclassic                                1.3.1
# nbclient                                 0.10.2
# nbconvert                                7.16.6
# nbformat                                 5.10.4
# ndindex                                  1.10.0
# nest-asyncio                             1.6.0
# networkx                                 3.5
# nibabel                                  5.3.2
# ninja                                    1.13.0
# nltk                                     3.9.1
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.61.2
# numba-cuda                               0.11.0
# numexpr                                  2.11.0
# numpy                                    2.0.2
# nvidia-cublas-cu12                       12.4.5.8
# nvidia-cuda-cupti-cu12                   12.4.127
# nvidia-cuda-nvcc-cu12                    12.5.82
# nvidia-cuda-nvrtc-cu12                   12.4.127
# nvidia-cuda-runtime-cu12                 12.4.127
# nvidia-cudnn-cu12                        9.1.0.70
# nvidia-cufft-cu12                        11.2.1.3
# nvidia-cufile-cu12                       1.11.1.6
# nvidia-curand-cu12                       10.3.5.147
# nvidia-cusolver-cu12                     11.6.1.9
# nvidia-cusparse-cu12                     12.3.1.170
# nvidia-cusparselt-cu12                   0.6.2
# nvidia-ml-py                             12.575.51
# nvidia-nccl-cu12                         2.21.5
# nvidia-nvjitlink-cu12                    12.4.127
# nvidia-nvtx-cu12                         12.4.127
# nvtx                                     0.2.13
# nx-cugraph-cu12                          25.6.0
# oauth2client                             4.1.3
# oauthlib                                 3.3.1
# omegaconf                                2.3.0
# openai                                   1.100.0
# openai-harmony                           0.0.4
# opencv-contrib-python                    4.12.0.88
# opencv-python                            4.12.0.88
# opencv-python-headless                   4.12.0.88
# openpyxl                                 3.1.5
# opentelemetry-api                        1.26.0
# opentelemetry-exporter-gcp-trace         1.9.0
# opentelemetry-exporter-otlp              1.26.0
# opentelemetry-exporter-otlp-proto-common 1.26.0
# opentelemetry-exporter-otlp-proto-grpc   1.26.0
# opentelemetry-exporter-otlp-proto-http   1.26.0
# opentelemetry-proto                      1.26.0
# opentelemetry-resourcedetector-gcp       1.9.0a0
# opentelemetry-sdk                        1.26.0
# opentelemetry-semantic-conventions       0.47b0
# opentelemetry-semantic-conventions-ai    0.4.13
# opt_einsum                               3.4.0
# optax                                    0.2.5
# optree                                   0.17.0
# orbax-checkpoint                         0.11.22
# orjson                                   3.11.2
# osqp                                     1.0.4
# outlines                                 0.1.11
# outlines_core                            0.1.26
# packaging                                25.0
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.29.2
# pandas-stubs                             2.2.2.240909
# pandocfilters                            1.5.1
# panel                                    1.7.5
# param                                    2.2.1
# parso                                    0.8.4
# parsy                                    2.1
# partd                                    1.4.2
# partial-json-parser                      0.2.1.1.post6
# patsy                                    1.0.1
# peewee                                   3.18.2
# peft                                     0.17.0
# pexpect                                  4.9.0
# pickleshare                              0.7.5
# pillow                                   11.3.0
# pip                                      24.1.2
# platformdirs                             4.3.8
# plotly                                   5.24.1
# plotnine                                 0.14.5
# pluggy                                   1.6.0
# plum-dispatch                            2.5.7
# ply                                      3.11
# polars                                   1.25.2
# pooch                                    1.8.2
# portpicker                               1.5.2
# preshed                                  3.0.10
# prettytable                              3.16.0
# proglog                                  0.1.12
# progressbar2                             4.5.0
# prometheus_client                        0.22.1
# prometheus-fastapi-instrumentator        7.1.0
# promise                                  2.3
# prompt_toolkit                           3.0.51
# propcache                                0.3.2
# prophet                                  1.1.7
# proto-plus                               1.26.1
# protobuf                                 4.25.8
# psutil                                   5.9.5
# psycopg2                                 2.9.10
# psygnal                                  0.14.1
# ptyprocess                               0.7.0
# py-cpuinfo                               9.0.0
# py4j                                     0.10.9.7
# pyarrow                                  18.1.0
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.2
# pybase64                                 1.4.2
# pycairo                                  1.28.0
# pycocotools                              2.0.10
# pycountry                                24.6.1
# pycparser                                2.22
# pycryptodomex                            3.23.0
# pydantic                                 2.11.7
# pydantic_core                            2.33.2
# pydantic-extra-types                     2.10.5
# pydantic-settings                        2.10.1
# pydata-google-auth                       1.9.1
# pydot                                    3.0.4
# pydotplus                                2.0.2
# PyDrive2                                 1.21.3
# pydub                                    0.25.1
# pyerfa                                   2.0.1.5
# pygame                                   2.6.1
# pygit2                                   1.18.2
# Pygments                                 2.19.2
# PyGObject                                3.42.0
# PyJWT                                    2.10.1
# pylibcudf-cu12                           25.6.0
# pylibcugraph-cu12                        25.6.0
# pylibraft-cu12                           25.6.0
# pymc                                     5.25.1
# pynndescent                              0.5.13
# pynvjitlink-cu12                         0.7.0
# pynvml                                   12.0.0
# pyogrio                                  0.11.1
# pyomo                                    6.9.3
# PyOpenGL                                 3.1.10
# pyOpenSSL                                24.2.1
# pyparsing                                3.2.3
# pyperclip                                1.9.0
# pyproj                                   3.7.2
# pyproject_hooks                          1.2.0
# pyshp                                    2.3.1
# PySocks                                  1.7.1
# pyspark                                  3.5.1
# pytensor                                 2.31.7
# pytest                                   8.4.1
# python-apt                               0.0.0
# python-box                               7.3.2
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.1.1
# python-json-logger                       3.3.0
# python-louvain                           0.16
# python-multipart                         0.0.20
# python-slugify                           8.0.4
# python-snappy                            0.7.3
# python-utils                             3.9.1
# pytz                                     2025.2
# pyviz_comms                              3.0.6
# PyWavelets                               1.9.0
# PyYAML                                   6.0.2
# pyzmq                                    26.2.1
# raft-dask-cu12                           25.6.0
# rapids-dask-dependency                   25.6.0
# rapids-logger                            0.1.1
# ratelim                                  0.1.6
# ray                                      2.48.0
# referencing                              0.36.2
# regex                                    2024.11.6
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# requirements-parser                      0.9.0
# rich                                     13.9.4
# rich-toolkit                             0.15.0
# rignore                                  0.6.4
# rmm-cu12                                 25.6.0
# roman-numerals-py                        3.1.0
# rpds-py                                  0.27.0
# rpy2                                     3.5.17
# rsa                                      4.9.1
# ruff                                     0.12.9
# safehttpx                                0.1.6
# safetensors                              0.6.2
# scikit-image                             0.25.2
# scikit-learn                             1.6.1
# scipy                                    1.16.1
# scooby                                   0.10.1
# scs                                      3.2.8
# seaborn                                  0.13.2
# SecretStorage                            3.3.3
# semantic-version                         2.10.0
# Send2Trash                               1.8.3
# sentence-transformers                    5.1.0
# sentencepiece                            0.2.1
# sentry-sdk                               2.35.0
# setproctitle                             1.3.6
# setuptools                               79.0.1
# shap                                     0.48.0
# shapely                                  2.1.1
# shellingham                              1.5.4
# shtab                                    1.7.2
# simple-parsing                           0.1.7
# simplejson                               3.20.1
# simsimd                                  6.5.1
# six                                      1.17.0
# sklearn-pandas                           2.2.0
# slicer                                   0.0.8
# smart_open                               7.3.0.post1
# smmap                                    5.0.2
# sniffio                                  1.3.1
# snowballstemmer                          3.0.1
# sortedcontainers                         2.4.0
# soundfile                                0.13.1
# soupsieve                                2.7
# soxr                                     0.5.0.post1
# spacy                                    3.8.7
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spanner-graph-notebook                   1.1.7
# Sphinx                                   8.2.3
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# SQLAlchemy                               2.0.43
# sqlglot                                  25.20.2
# sqlparse                                 0.5.3
# srsly                                    2.5.1
# sse-starlette                            3.0.2
# stanio                                   0.5.1
# starlette                                0.47.2
# statsmodels                              0.14.5
# stringzilla                              3.12.6
# stumpy                                   1.13.0
# sympy                                    1.13.1
# tables                                   3.10.2
# tabulate                                 0.9.0
# tbb                                      2022.2.0
# tblib                                    3.1.0
# tcmlib                                   1.4.0
# tenacity                                 8.5.0
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.19.0
# tensorflow-datasets                      4.9.9
# tensorflow_decision_forests              1.12.0
# tensorflow-hub                           0.16.1
# tensorflow-metadata                      1.17.2
# tensorflow-probability                   0.25.0
# tensorflow-text                          2.19.0
# tensorstore                              0.1.76
# termcolor                                3.1.0
# terminado                                0.18.1
# text-unidecode                           1.3
# textblob                                 0.19.0
# tf_keras                                 2.19.0
# tf-slim                                  1.1.0
# thinc                                    8.3.6
# threadpoolctl                            3.6.0
# tifffile                                 2025.6.11
# tiktoken                                 0.11.0
# timm                                     1.0.19
# tinycss2                                 1.4.0
# tokenizers                               0.21.4
# toml                                     0.10.2
# tomlkit                                  0.13.3
# toolz                                    0.12.1
# torch                                    2.6.0
# torchao                                  0.10.0
# torchaudio                               2.6.0
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.21.0
# tornado                                  6.4.2
# tqdm                                     4.67.1
# traitlets                                5.7.1
# traittypes                               0.2.1
# transformers                             4.55.2
# treelite                                 4.4.1
# treescope                                0.1.10
# triton                                   3.2.0
# trl                                      0.19.1
# tsfresh                                  0.21.0
# tweepy                                   4.16.0
# typeguard                                4.4.4
# typer                                    0.16.0
# types-pytz                               2025.2.0.20250809
# types-setuptools                         80.9.0.20250809
# typing_extensions                        4.14.1
# typing-inspection                        0.4.1
# tyro                                     0.9.28
# tzdata                                   2025.2
# tzlocal                                  5.3.1
# uc-micro-py                              1.0.3
# ucx-py-cu12                              0.44.0
# ucxx-cu12                                0.44.0
# umap-learn                               0.5.9.post2
# umf                                      0.11.0
# unsloth                                  2025.7.8
# unsloth_zoo                              2025.7.10
# uritemplate                              4.2.0
# urllib3                                  2.5.0
# uvicorn                                  0.35.0
# uvloop                                   0.21.0
# vega-datasets                            0.9.0
# vllm                                     0.8.5.post1
# wadllib                                  1.3.6
# wandb                                    0.21.1
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# watchfiles                               1.1.0
# wcwidth                                  0.2.13
# weasel                                   0.4.1
# webcolors                                24.11.1
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               15.0.1
# Werkzeug                                 3.1.3
# wheel                                    0.45.1
# widgetsnbextension                       3.6.10
# wordcloud                                1.9.4
# wrapt                                    1.17.3
# wurlitzer                                3.1.1
# xarray                                   2025.8.0
# xarray-einstats                          0.9.1
# xformers                                 0.0.29.post3
# xgboost                                  3.0.4
# xgrammar                                 0.1.18
# xlrd                                     2.0.2
# xxhash                                   3.5.0
# xyzservices                              2025.4.0
# yarl                                     1.20.1
# ydf                                      0.13.0
# yellowbrick                              1.5
# yfinance                                 0.2.65
# zict                                     3.0.0
# zipp                                     3.23.0
# zstandard                                0.24.0

# %% [markdown]
# huggingfaceのトークンを認証しておきます．
# トークンの取得方法は下記を参照してください．
# https://zenn.dev/protoout/articles/73-hugging-face-setup

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import userdata
from huggingface_hub import login
import wandb

HF_TOKEN = userdata.get('HF_TOKEN')
login(token=HF_TOKEN)

WANDB_API_KEY = userdata.get('wandb')
wandb.login(key=WANDB_API_KEY)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: haraguchi (haraguchi-chiba-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !huggingface-cli login

# %%
# !git config --global credential.helper store

# %%
# !wandb login --relogin

# %%
import torch
import numpy as np
from datasets import load_dataset
from unsloth import FastLanguageModel
from transformers import TextStreamer
from trl import GRPOConfig, GRPOTrainer, SFTTrainer, SFTConfig
from vllm import SamplingParams
from math_verify import parse, verify
import re
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 08-23 10:32:57 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 08-23 10:32:57 [__init__.py:239] Automatically detected platform cuda.

# %% [markdown]
# ###諸々のconfigの準備

# %%
MAX_SEQ_LENGTH = 2048 # モデルの取り扱うことのできるコンテキストの最大量を設定します．
# MAX_SEQ_LENGTH = 4096
LORA_RANK = 64# LoRAのハイパーパラメータです．更新パラメータの量を決めます．
MODEL_NAME = "unsloth/Qwen3-4B"# unslothの用意した専用モデルです．基本これを使うことが推奨されています．
RUN_NAME = "Drgrpo_2048_verify_plus_groq" # 各自自分の実験だとわかるように書き換えてください。
LEARNED_MODEL_NAME = "hara-CU/minicompe-model" #学習したモデルを保存するHFのレポジトリです

# %%
# wandbの設定
import wandb

WANDB_PROJECT = "minicomp-test2"
# RUN_NAME = "test" # 各自自分の実験だとわかるように書き換えてください。
wandb.init(
    project=WANDB_PROJECT,
    name=RUN_NAME,
)
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250823_103304-7cgzplns</code>
# Syncing run <strong><a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/7cgzplns' target="_blank">Drgrpo_2048_verify_plus_groq</a></strong> to <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test2' target="_blank">https://wandb.ai/haraguchi-chiba-university/minicomp-test2</a>
#  View run at <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/7cgzplns' target="_blank">https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/7cgzplns</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/7cgzplns?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ##モデルとトークナイザーの準備
#
# 今回はUnslothのFastLanguageModelを使ってモデルをロードし，それに対してLoRA学習のためのアダプターをガッチャンします．
#
# LoRAとはLLMのtransformerアーキテクチャにおける各層に対して追加のパラメータをアダプター的にくっつけて，そこだけ学習するという手法です．使用するGPUのvramを全層を学習するより少なく済みます．

# %%
def prepare_model_and_tokenizer():
    """モデルとトークナイザーを準備"""
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_NAME,
        max_seq_length=MAX_SEQ_LENGTH,
        load_in_4bit=False,
        fast_inference=True,  # vLLM高速推論を有効化
        max_lora_rank=LORA_RANK,
        gpu_memory_utilization=0.8,
    )

    # LoRAアダプターの追加
    model = FastLanguageModel.get_peft_model(
        model,
        r=LORA_RANK,
        target_modules=[
            "q_proj", "k_proj", "v_proj", "o_proj",
            "gate_proj", "up_proj", "down_proj",
        ],# アダプターはLLMの線形層につけますが，ここでは一般的なところにつけときます．
        lora_alpha=LORA_RANK * 2,
        use_gradient_checkpointing="unsloth", # 勾配更新の計算方法ですね．unslothは独自のgradient_checkpoingの手法を持っています．
        random_state=3407,
    )

    return model, tokenizer

# %% [markdown]
# ## SFTのデータセットの準備
#
# SFTでは、モデルに正しい回答フォーマットを学習させます。
# Qwen3は<think>タグで思考過程を記述するreasoningモードを持っているので、ここでの効果はそこまでありませんが，一般にはSFTを活用してフォーマットを学習させます。
#
# 今回はMiroMindのデータセットをサンプリングして使います．

# %%
def prepare_sft_dataset():
    """SFT用のデータセットを準備（少量のサンプル）"""
    dataset = load_dataset("miromind-ai/MiroMind-M1-SFT-719K", split="train")

    # 少量のサンプルだけを使用（100件程度）
    dataset = dataset.select(range(min(1000, len(dataset))))

    def format_sft_data(example):
        """SFT用のフォーマット：問題と解答のペアを作成"""
        messages = [
            {"role": "user", "content": example["question"]},
            {"role": "assistant", "content": example['response']}
        ]

        # chat_templateを適用してテキスト化.Qwenではこのタイミングで勝手に
        text = tokenizer.apply_chat_template(messages, tokenize=False)
        return {"text": text}

    # データセットをフォーマット
    formatted_dataset = dataset.map(format_sft_data)

    # # トークン長でフィルタリング（長すぎるものを除外）
    # def filter_by_length(example):
    #     return len(tokenizer.encode(example["text"])) <= MAX_SEQ_LENGTH // 2
    # formatted_dataset = formatted_dataset.filter(filter_by_length)
    # ↑　これはやってもいいですが，max_tokenを超えた分についてはあとでtruncateされます．

    return formatted_dataset

# %% [markdown]
# ## trainerの定義と実行

# %%
def train_sft(model, tokenizer, sft_dataset, sft_config):
    """SFTでフォーマットを学習"""

    # SFTトレーナーの作成と実行
    sft_trainer = SFTTrainer(
        model=model,
        tokenizer=tokenizer,
        train_dataset=sft_dataset,
        args=sft_config,
    )

    print("#########学習開始#########")
    sft_trainer.train()

    return model

# %% [markdown]
# ### GRPOのデータセットを準備
#
# 今回はnvidiaのAIME攻略用の数学データセットを使います．
# unslothがサイズを小さくしたものを用意してくれているので，そのまま使います．ついでにprompt状態にしておきましょう．

# %%
def prepare_grpo_dataset(SYSTEM_PROMPT):
    """GRPOトレーニング用のデータセットを準備"""
    dataset = load_dataset("unsloth/OpenMathReasoning-mini", split="cot")

    """ データセットのフォーマット（シンプルな形式）
    今回はシステムプロンプトなし＋問題のプロンプトにします．Qwen3はOpenAIのmessage形式のchattemplateの対応しているので，以下のようにpromptを用意しておきます．
    Qwen3はシステムプロンプト無しを推奨しているようです．
    """
    def format_grpo_data(example): # 修正
        return {
            "prompt": [
                {"role": "user", "content": example["problem"]},
            ],
            "answer": example["expected_answer"],
        }

    dataset = dataset.map(format_grpo_data)
    return dataset

# %% [markdown]
# ## trainerの定義と実行
#
# unslothでもtrlやtransfomersなどと同様にtrainerを作って学習を回します．てか，基本trlをラップしているライブラリなんでそうなんですが．
#
# 今回はプロンプトの時点で最大トークンを超えている場合はそのデータはfilterしておく設定にしています．
#
# またQwen3はデフォルトでReasoningモードになっていることに注意です．

# %%
def train_grpo(model, tokenizer, dataset, reward_funcs, grpo_config):
    """GRPOトレーニングを実行（reasoning mode有効）"""

    trainer = GRPOTrainer(
        model=model,
        processing_class=tokenizer,
        reward_funcs=reward_funcs,
        args=grpo_config,
        train_dataset=dataset,
    )

    print("#########学習開始#########")
    trainer.train()
    return model

# %% [markdown]
# ## メインの実行処理

# %%
print("1. モデル準備...")
model, tokenizer = prepare_model_and_tokenizer()
# Out:
# 1. モデル準備...
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.7.8: Fast Qwen3 patching. Transformers: 4.55.2. vLLM: 0.8.5.post1.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/Qwen3-4B with actual GPU utilization = 79.08%
# Unsloth: Your GPU has CUDA compute capability 8.0 with VRAM = 39.56 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 320.
# Unsloth: vLLM's KV Cache can use up to 24.22 GB. Also swap space = 6 GB.
# INFO 08-23 10:33:48 [config.py:717] This model supports multiple tasks: {'score', 'generate', 'reward', 'embed', 'classify'}. Defaulting to 'generate'.
# INFO 08-23 10:33:48 [config.py:2003] Chunked prefill is enabled with max_num_batched_tokens=2048.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# INFO 08-23 10:33:53 [core.py:58] Initializing a V1 LLM engine (v0.8.5.post1) with config: model='unsloth/Qwen3-4B', speculative_config=None, tokenizer='unsloth/Qwen3-4B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/Qwen3-4B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"backend":"inductor","custom_ops":["none"],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":true,"trace.graph_diagram":false,"compile_threads":12,"combo_kernels":false,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":true,"enable_auto_functionalized_v2":false},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}
# WARNING 08-23 10:33:54 [utils.py:2522] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x7db504a913d0>
# INFO 08-23 10:33:54 [parallel_state.py:1004] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 08-23 10:33:54 [cuda.py:221] Using Flash Attention backend on V1 engine.
# WARNING 08-23 10:33:54 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 08-23 10:33:54 [gpu_model_runner.py:1329] Starting to load model unsloth/Qwen3-4B...
# INFO 08-23 10:33:55 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# INFO 08-23 10:34:17 [weight_utils.py:281] Time spent downloading weights for unsloth/Qwen3-4B: 22.495518 seconds
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 08-23 10:34:20 [loader.py:458] Loading weights took 2.38 seconds
# INFO 08-23 10:34:20 [punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 08-23 10:34:20 [gpu_model_runner.py:1347] Model loading took 7.7584 GiB and 25.891201 seconds
# INFO 08-23 10:34:41 [backends.py:420] Using cache directory: /root/.cache/vllm/torch_compile_cache/fe69ad95aa/rank_0_0 for vLLM's torch.compile
# INFO 08-23 10:34:41 [backends.py:430] Dynamo bytecode transform time: 20.37 s
# Unsloth: Compiling kernels: 100%|██████████| 6/6 [00:01<00:00,  3.15it/s, triton_poi_fused_add_mul_sub_5]
# Unsloth: Compiling kernels: 100%|██████████| 6/6 [00:00<00:00, 73.79it/s, triton_poi_fused_add_mul_sub_5]
# INFO 08-23 10:35:04 [backends.py:136] Cache the graph of shape None for later use
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:01<00:00,  6.51it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 120.82it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.15it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 117.47it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 118.52it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.12it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 110.72it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.08it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 109.37it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.98it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.65it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 119.74it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 79.44it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 121.16it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 111.61it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.79it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 111.22it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.61it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 122.26it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.23it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 117.64it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.49it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 111.61it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.91it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 117.78it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 119.60it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.17it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.50it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.34it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.80it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 119.26it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 104.98it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 108.40it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.43it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 120.72it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.35it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 24.21it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 75.64it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# INFO 08-23 10:36:27 [backends.py:148] Compiling a graph for general shape takes 102.36 s
# INFO 08-23 10:36:37 [monitor.py:33] torch.compile takes 122.73 s in total
# INFO 08-23 10:36:38 [kv_cache_utils.py:634] GPU KV cache size: 154,528 tokens
# INFO 08-23 10:36:38 [kv_cache_utils.py:637] Maximum concurrency for 2,048 tokens per request: 75.45x
# INFO 08-23 10:36:38 [vllm_utils.py:641] Unsloth: Running patched vLLM v1 `capture_model`.
# INFO 08-23 10:37:11 [gpu_model_runner.py:1686] Graph capturing finished in 34 secs, took 0.84 GiB
# INFO 08-23 10:37:11 [vllm_utils.py:648] Unsloth: Patched vLLM v1 graph capture finished in 34 secs.
# INFO 08-23 10:37:13 [core.py:159] init engine (profile, create kv cache, warmup model) took 172.47 seconds
# Unsloth: Just some info: will skip parsing ['post_feedforward_layernorm', 'pre_feedforward_layernorm']
# Unsloth: Just some info: will skip parsing ['post_feedforward_layernorm', 'pre_feedforward_layernorm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth 2025.7.8 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### SFTの学習します

# %%
print("SFT用データセット準備中...")
sft_dataset = prepare_sft_dataset()
# Out:
# SFT用データセット準備中...
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/22 [00:00<?, ?files/s]
# train-00000-of-00022.parquet:   0%|          | 0.00/270M [00:00<?, ?B/s]
# train-00001-of-00022.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00002-of-00022.parquet:   0%|          | 0.00/250M [00:00<?, ?B/s]
# train-00003-of-00022.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00004-of-00022.parquet:   0%|          | 0.00/265M [00:00<?, ?B/s]
# train-00005-of-00022.parquet:   0%|          | 0.00/206M [00:00<?, ?B/s]
# train-00006-of-00022.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
# train-00007-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00008-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00009-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00010-of-00022.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00011-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00012-of-00022.parquet:   0%|          | 0.00/169M [00:00<?, ?B/s]
# train-00013-of-00022.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00014-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00015-of-00022.parquet:   0%|          | 0.00/214M [00:00<?, ?B/s]
# train-00016-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00017-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00018-of-00022.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# train-00019-of-00022.parquet:   0%|          | 0.00/221M [00:00<?, ?B/s]
# train-00020-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00021-of-00022.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/719232 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/21 [00:00<?, ?it/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# SFTの設定
sft_config = SFTConfig(
    dataset_text_field="text",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=2,
    warmup_ratio=0.1,
    num_train_epochs=2, # LLMのSFTだと一般的ですかね．
    learning_rate=2e-5,
    logging_steps=5,
    optim="adamw_torch",
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs_sft",
    report_to="wandb"
)

# %%
print("\n=== 2. SFT（教師あり学習）フェーズ ===")
print("まず、正しい回答フォーマットを学習させます...")
model = train_sft(model, tokenizer, sft_dataset, sft_config)
# Out:
# === 2. SFT（教師あり学習）フェーズ ===
# まず、正しい回答フォーマットを学習させます...
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/1000 [00:00<?, ? examples/s]
# #########学習開始#########
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 2 | Total steps = 500
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 2 x 1) = 4
#  "-____-"     Trainable parameters = 132,120,576 of 4,154,588,672 (3.18% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 12:15, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.625800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.582000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.610200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.565000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.535600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.560500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.516200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.494600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.454400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.483600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.462500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.421300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.429600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.467800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.520900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.446500</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.478100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.478100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.429100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.413200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.456700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.397000</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.387600</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.423100</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.406800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.472900</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.398000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.469300</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.437400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.384800</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.442000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.416800</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.364100</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.434400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.436800</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.515600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.463300</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.444100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.386700</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.476000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.445200</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.436600</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.493500</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.420800</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.405700</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.484700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.417300</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.394200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.485700</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.389900</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.406300</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.494400</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.413100</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.430400</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.431700</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.363700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.440100</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.401400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.463700</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.438700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.420100</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.432500</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.426600</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.442300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.466200</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.405400</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.431200</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.408400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.387400</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.396200</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.408900</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.433000</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.373500</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.397800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.420500</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.422300</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.432800</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.391000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.451100</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.380300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.419300</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.428300</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.436800</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.414800</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.420700</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.417200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.354200</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.357900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.396700</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.454300</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.447000</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>0.455000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.401300</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.442000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.396400</td>
#     </tr>
#     <tr>
#       <td>485</td>
#       <td>0.378100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.426900</td>
#     </tr>
#     <tr>
#       <td>495</td>
#       <td>0.439100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.418000</td>
#     </tr>
#   </tbody>
# </table><p>
# wandb: WARNING The get_url method is deprecated and will be removed in a future release. Please use `run.url` instead.

# %%
# 学習後のテスト
print("\n### SFT後のテスト生成 ###")
test_prompt = [{"role": "user", "content": "What is 15 + 23?"}]
inputs = tokenizer.apply_chat_template(
    test_prompt,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
).to("cuda")

with torch.no_grad():
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=512,
        temperature=0.1,
        do_sample=True,
        top_p=0.95,
    )

response = tokenizer.decode(outputs[0], skip_special_tokens=False)
print("生成例:")
print(response)
print("\n正しくreasoningフォーマットで生成できているか確認してください。")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ### SFT後のテスト生成 ###
# 生成例:
# <|im_start|>user
# What is 15 + 23?<|im_end|>
# <|im_start|>assistant
# <think>
# Okay, let's see. The problem is 15 plus 23. Hmm, I need to add these two numbers together. Let me start by breaking them down. 15 is 10 plus 5, and 23 is 20 plus 3. So if I add the tens first, 10 plus 20 is 30. Then the ones: 5 plus 3 is 8. So 30 plus 8 is 38. Wait, that seems right. Let me check another way. Maybe counting up from 15. 15 plus 10 is 25, then plus 13 more would be 38. Yeah, that matches. Or maybe using a number line. Starting at 15, moving 20 to the right gets me to 35, then 3 more makes 38. All the methods point to 38. I think that's the correct answer.
# </think>
#
# 15 + 23 = 38<|im_end|>
#
# 正しくreasoningフォーマットで生成できているか確認してください。

# %%
# メモリ解放
if 'sft_trainer' in locals(): # 修正
    del sft_trainer
torch.cuda.empty_cache()
torch.cuda.ipc_collect()  # 修正

# %% [markdown]
# ### GRPO学習します．
#
# 今回はmaxstepを100にしているので，100step(設定上実質バッチサイズは8なので，データセットのうち800件で学習したことになります．)

# %%
print("\n=== 3. GRPO（強化学習）フェーズ ===")
print("GRPOデータセット準備中...")
# Add a placeholder SYSTEM_PROMPT as it's a required argument
grpo_dataset = prepare_grpo_dataset(SYSTEM_PROMPT="") # 修正

# トークン長を計算（enable_thinking=Trueで）
def get_token_length(example):
    return len(tokenizer.apply_chat_template(
        example["prompt"],
        add_generation_prompt=True,
        tokenize=True,
    ))

grpo_dataset = grpo_dataset.map(lambda x: {"token_length": get_token_length(x)})
max_prompt_length = int(np.quantile(grpo_dataset["token_length"], 0.9))
grpo_dataset = grpo_dataset.filter(lambda x: x["token_length"] <= max_prompt_length)

MAX_STEP = 100
grpo_config = GRPOConfig(
    temperature=0.6, # Qwen3の推奨値
    learning_rate=5e-6, #LoRAなんでやや高めで．
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    num_generations=4, # 同時に生成するサンプル数です．基本4以上が推奨です．ここを2にするとオンラインDPOを同じようなことをやっていることになります(lossの仕組みとか違いますが)
    max_prompt_length=max_prompt_length,
    max_completion_length=MAX_SEQ_LENGTH - max_prompt_length,
    max_steps = MAX_STEP,
    save_steps=100,
    loss_type="dr_grpo",
    output_dir="outputs",
    report_to="wandb"
)
# Out:
# === 3. GRPO（強化学習）フェーズ ===
# GRPOデータセット準備中...
# README.md:   0%|          | 0.00/603 [00:00<?, ?B/s]
# data/cot-00000-of-00001.parquet:   0%|          | 0.00/106M [00:00<?, ?B/s]
# Generating cot split:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Unsloth: The Dr GRPO paper recommends setting `scale_rewards` to False! Will override. Set it to `None` to force False.
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %%
max_prompt_length
# Out:
# 95

# %%
#@title reward_funcの引数
"""
reward_func args: []
reward_func kwargs:
{'prompts': 'list(len=32)',
'completions': 'list(len=32)',
'completion_ids': 'list(len=32)',
'expected_answer': 'list(len=32)',
'problem_type': 'list(len=32)',
 'problem_source': 'list(len=32)',
 'generation_model': 'list(len=32)',
 'pass_rate_72b_tir': 'list(len=32)',
  'problem': 'list(len=32)',
   'generated_solution': 'list(len=32)',
   'inference_mode': 'list(len=32)',
   'answer': 'list(len=32)',
    'token_length': 'list(len=32)'}

"""
# Out:
# "\nreward_func args: []\nreward_func kwargs:\n{'prompts': 'list(len=32)',\n'completions': 'list(len=32)',\n'completion_ids': 'list(len=32)',\n'expected_answer': 'list(len=32)',\n'problem_type': 'list(len=32)',\n 'problem_source': 'list(len=32)',\n 'generation_model': 'list(len=32)',\n 'pass_rate_72b_tir': 'list(len=32)',\n  'problem': 'list(len=32)',\n   'generated_solution': 'list(len=32)',\n   'inference_mode': 'list(len=32)',\n   'answer': 'list(len=32)',\n    'token_length': 'list(len=32)'}\n\n"

# %%
#@title 報酬関数設計


import re
import numpy as np
from math_verify import parse, verify
from sympy import sympify, simplify, N, expand, factor, trigsimp, lambdify
import math
from itertools import zip_longest



def math_verify_score(gold_answer,cleaned_response):
    if verify(parse(gold_answer), parse(cleaned_response)):
        score = 1.0
    else:
      score = 0

    return score



# -----------------------------
# Groq API スコアリング関数
# -----------------------------

from groq import Groq
from google.colab import userdata
import requests


GROQ_model = "qwen/qwen3-32b"

GROQ_API_KEY = userdata.get('Groq_API_KEY')
url = "https://api.groq.com/openai/v1/chat/completions"

def Groq_api(content,model_name):

  client = Groq(api_key=GROQ_API_KEY)
  completion = client.chat.completions.create(
      model=model_name,
      messages=[
          {
              "role": "user",
              "content": content,
          }
      ]
  )
  # print(completion.choices[0].message.content)


  return completion.choices[0].message.content


def complete_content_GRPO_judge(response, gold_answer):
  contents = (
f"""
Your role is to evaluate the model's answer by comparing it to the reference (gold) answer.
Please assign a score out of 100 points according to the following grading criteria.

[Grading Criteria]
- The maximum score is 100.
- Only the final answer in the model's response should be evaluated.
- The reasoning or calculation process in the model's response should not be considered when grading.
- If the final answer and the gold answer are semantically equivalent, the answer should be considered correct, even if the format differs.
- If the final answer differs from the gold answer but is close, partial credit may be awarded.

Respond strictly in the following format:

★Score: XX
(XX is an integer. Grade out of 100 points)

---

[Model Answer]
{response}

[Gold Answer]
{gold_answer}
"""
)

  return contents

def extract_score_from_API_judge(text):
    # 正規表現で ★Score: に続く半角の整数（最大3桁）を抽出
    match = re.search(r'★Score[:：]\s*(\d{1,3})', text)
    if match:
        try:
            score = int(match.group(1))
            if 0 <= score <= 100:
                return score / 100
        except ValueError:
            pass
    return 0


def Groq_api_scoring(response, gold_answer,model_name):
    content = complete_content_GRPO_judge(response, gold_answer)
    scoring_text = Groq_api(content,model_name)
    score = extract_score_from_API_judge(scoring_text)

    return score

# -----------------------------
# 長さペナルティ
# -----------------------------
def calc_length_penalty(completion_length, max_length, start_ratio=0.85):
    L_start = start_ratio * max_length
    max_length = max_length + 100
    if completion_length <= L_start:
        return 1.0
    elif completion_length >= max_length:
        return 0.0
    else:
        ratio = (completion_length - L_start)/(max_length - L_start)
        return 0.5*(1 + np.cos(np.pi*ratio))

# -----------------------------
# 短答ボーナス 満点回答のみ
# -----------------------------
def reward_length_rank_bonus(base_scores, token_lengths):
    # 満点回答のインデックス
    full_idx = [i for i, s in enumerate(base_scores) if s >= 1.0]
    n = len(full_idx)
    if n == 0:
        return base_scores

    # 満点回答の平均長さ
    mean_length = np.mean([token_lengths[i] for i in full_idx])

    # 平均に近い順にソート
    ranked = sorted(full_idx, key=lambda i: abs(token_lengths[i] - mean_length))

    final_scores = base_scores.copy()
    for rank, i in enumerate(ranked):
        bonus = 1 - rank / n
        final_scores[i] += bonus  # スコアに加算

    return final_scores

# -----------------------------
# 報酬関数（verifyで採点、0点をGroqで採点して補強 + 短答報酬 適用）
# -----------------------------
def reward_verify_plus_groq(prompts, completions, expected_answer, token_length,
                            numeric_points=None, max_penalty=10, expr_weight=1.0,
                            tau=0.1, min_score=0.2, max_seq_length=MAX_SEQ_LENGTH, pair_weight=1.0,
                            **kwargs):
    # batch_size = len(completions)
    scores = []
    correct_flags = []

    for completion, gold_answer, comp_len in zip(completions, expected_answer, token_length):
        response = completion[0]["content"]
        length_penalty = calc_length_penalty(comp_len, max_seq_length)
        length_penalty = 1

        # thinkタグ形式チェック
        if not re.search(r'<think>.*?</think>', response, flags=re.DOTALL):
            score = 0.1 if re.search(r'<think>|</think>', response, flags=re.DOTALL) else 0.0
            score *= length_penalty
            scores.append(score)
            continue

        cleaned_response = re.sub(r'<think>.*?</think>', '', response, flags=re.DOTALL)
        # cleaned_response = re.sub(r'<\|im_end\|>', '', cleaned_response)

        # スコアリング
        verify_score = math_verify_score(cleaned_response, gold_answer)
        groq_score = 0
        if verify_score != 1.0:
            groq_score = Groq_api_scoring(cleaned_response, gold_answer,GROQ_model)

        partial_score = max(verify_score, groq_score)
        partial_score = min(partial_score, 1.0)
        score = max(partial_score, min_score) * length_penalty

        scores.append(score)

    # scores = reward_length_rank_bonus(scores, token_length)

    return scores

# %%
reward_funcs = [reward_verify_plus_groq]

# %%
print("3. GRPO学習開始...")

model = train_grpo(model, tokenizer, grpo_dataset, reward_funcs, grpo_config)
# Out:
# 3. GRPO学習開始...
# #########学習開始#########
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 17,326 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 8 x 1) = 32
#  "-____-"     Trainable parameters = 132,120,576 of 4,154,588,672 (3.18% trained)
#     <div>
#
#       <progress value='6' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  6/100 03:55 < 1:32:23, 0.02 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / reward_verify_plus_groq / mean</th>
#       <th>rewards / reward_verify_plus_groq / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000200</td>
#       <td>0.315625</td>
#       <td>0.116042</td>
#       <td>1900.437500</td>
#       <td>1339.000000</td>
#       <td>1953.000000</td>
#       <td>0.875000</td>
#       <td>1532.500000</td>
#       <td>1339.000000</td>
#       <td>1879.000000</td>
#       <td>0.202743</td>
#       <td>0.315625</td>
#       <td>0.369925</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.215625</td>
#       <td>0.006250</td>
#       <td>1886.125000</td>
#       <td>1288.000000</td>
#       <td>1953.000000</td>
#       <td>0.875000</td>
#       <td>1418.000000</td>
#       <td>1288.000000</td>
#       <td>1595.000000</td>
#       <td>0.142126</td>
#       <td>0.215625</td>
#       <td>0.301726</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.159375</td>
#       <td>0.061555</td>
#       <td>1953.000000</td>
#       <td>1953.000000</td>
#       <td>1953.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.134051</td>
#       <td>0.159375</td>
#       <td>0.221227</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.005200</td>
#       <td>0.212500</td>
#       <td>0.112500</td>
#       <td>1900.906250</td>
#       <td>1143.000000</td>
#       <td>1953.000000</td>
#       <td>0.875000</td>
#       <td>1536.250000</td>
#       <td>1143.000000</td>
#       <td>1941.000000</td>
#       <td>0.185275</td>
#       <td>0.212500</td>
#       <td>0.302410</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# テスト（reasoning modeで）
test_prompt = [{"role": "user", "content": "What is 25 + 37?"}]
inputs = tokenizer.apply_chat_template(
  test_prompt,
  tokenize=True,
  add_generation_prompt=True,
  return_tensors="pt"
).to("cuda")

print("\nReasoning mode出力例:")
outputs = model.generate(
  input_ids=inputs,
  max_new_tokens=2048,
  temperature=0.6,
  streamer=TextStreamer(tokenizer, skip_prompt=True),
)

# %%
model = model.merge_and_unload()

# %%
model.push_to_hub(LEARNED_MODEL_NAME, revision=RUN_NAME)
tokenizer.push_to_hub(LEARNED_MODEL_NAME, revision=RUN_NAME)

# %% [markdown]
# # 評価環境の構築
# - セッションが切れてしまった場合に、HFへのモデルのアップロードが終了していれば、インストール、HFとWandBへのログイン、sft_configとgrpo_configを設定するセルを再実行することで、以下を再実行できます。

# %%
# %%bash
# # 評価環境の作成
#
# git clone https://github.com/Haraguchi-T/minicomp-codes.git
# cd minicomp-codes
# cd evaluation
#
# bash install.sh

# %%
import json
report_sft_key = {"dataset_text_field",
        "per_device_train_batch_size",
        "gradient_accumulation_steps",
        "warmup_ratio",
        "num_train_epochs",
        "learning_rate",
        "logging_steps",
        "optim",
        "weight_decay",
        "lr_scheduler_type",
        "seed"}
report_grpo_key = {"temperature",
        "learning_rate",
        "per_device_train_batch_size",
        "gradient_accumulation_steps",
        "num_generations",
        "max_prompt_length",
        "max_completion_length",
        "max_steps"}
output_sft_config = {key: value for key, value in sft_config.to_dict().items() if key in report_sft_key}
output_grpo_config = {key: value for key, value in grpo_config.to_dict().items() if key in report_grpo_key}
output_grpo_config["reward_funcs"] = "--".join([func.__name__ for func in reward_funcs])

configs = {
    "run_name": RUN_NAME,
    "base_model_name": MODEL_NAME,
    "sft_config": output_sft_config,
    "grpo_config": output_grpo_config,
    "model_name": LEARNED_MODEL_NAME,
}

eval_code_path = "./minicomp-codes/evaluation"

with open(f"{eval_code_path}/train_configs.json", "w") as f:
    json.dump(configs, f)

# %%
import yaml
with open(f"{eval_code_path}/eval_config.yaml", "r") as f:
    eval_config = yaml.safe_load(f)

eval_config["model_parameters"]["model_name"] = LEARNED_MODEL_NAME
eval_config["model_parameters"]["revision"] = RUN_NAME
with open(f"{eval_code_path}/eval_config.yaml", "w") as f:
    yaml.dump(eval_config, f)

# %%
import gc, torch

if 'grpo_trainer' in locals(): # 修正
    del grpo_trainer
if "model" in locals():
  del model
gc.collect()
torch.cuda.empty_cache()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()  # 修正

# %% [markdown]
# # 評価の実行とwandbへのアップロード
# - GPUメモリが足りない場合があります。その場合はセッション再起動をして、ここからやり直してください。

# %%
# %%bash
# nvidia-smi

# %%
# %%bash
# cd ./minicomp-codes/evaluation
# bash run.sh
# Out:
# INFO 08-23 09:46:05 [__init__.py:244] Automatically detected platform cuda.
# |      Task       |Version|     Metric     |Value |   |Stderr|
# |-----------------|------:|----------------|-----:|---|-----:|
# |all              |       |extractive_match|0.8059|±  |0.0109|
# |lighteval:gsm8k:0|      0|extractive_match|0.8059|±  |0.0109|
#
# INFO 08-23 09:53:13 [__init__.py:244] Automatically detected platform cuda.
# |       Task       |Version|        Metric        |Value |   |Stderr|
# |------------------|------:|----------------------|-----:|---|-----:|
# |all               |       |math_pass@1:1_samples |0.0333|±  |0.0333|
# |                  |       |math_pass@1:4_samples |0.0083|±  |0.0083|
# |                  |       |math_pass@1:8_samples |0.0125|±  |0.0092|
# |                  |       |math_pass@1:16_samples|0.0104|±  |0.0085|
# |                  |       |math_pass@1:32_samples|0.0177|±  |0.0157|
# |                  |       |math_pass@1:64_samples|0.0146|±  |0.0126|
# |lighteval:aime24:0|      2|math_pass@1:1_samples |0.0333|±  |0.0333|
# |                  |       |math_pass@1:4_samples |0.0083|±  |0.0083|
# |                  |       |math_pass@1:8_samples |0.0125|±  |0.0092|
# |                  |       |math_pass@1:16_samples|0.0104|±  |0.0085|
# |                  |       |math_pass@1:32_samples|0.0177|±  |0.0157|
# |                  |       |math_pass@1:64_samples|0.0146|±  |0.0126|
#
# INFO 08-23 10:01:37 [__init__.py:244] Automatically detected platform cuda.
# |          Task          |Version|       Metric        |Value |   |Stderr|
# |------------------------|------:|---------------------|-----:|---|-----:|
# |all                     |       |gpqa_pass@1:1_samples|0.3333|±  |0.0336|
# |                        |       |gpqa_pass@1:4_samples|0.3245|±  |0.0239|
# |                        |       |gpqa_pass@1:8_samples|0.3163|±  |0.0211|
# |lighteval:gpqa:diamond:0|      1|gpqa_pass@1:1_samples|0.3333|±  |0.0336|
# |                        |       |gpqa_pass@1:4_samples|0.3245|±  |0.0239|
# |                        |       |gpqa_pass@1:8_samples|0.3163|±  |0.0211|
#
# INFO 08-23 10:08:58 [__init__.py:244] Automatically detected platform cuda.
# |       Task        |Version| Metric |Value |   |Stderr|
# |-------------------|------:|--------|-----:|---|-----:|
# |all                |       |acc     |0.4319|±  |0.0162|
# |                   |       |acc_norm|0.4319|±  |0.0162|
# |lighteval:toxigen:0|      0|acc     |0.4319|±  |0.0162|
# |                   |       |acc_norm|0.4319|±  |0.0162|
#
# INFO 08-23 10:10:33 [__init__.py:244] Automatically detected platform cuda.
# |           Task            |Version|    Metric    |Value |   |Stderr|
# |---------------------------|------:|--------------|-----:|---|-----:|
# |all                        |       |truthfulqa_mc1|0.3488|±  |0.0167|
# |                           |       |truthfulqa_mc2|0.5000|±  |0.0160|
# |leaderboard:truthfulqa:mc:0|      0|truthfulqa_mc1|0.3488|±  |0.0167|
# |                           |       |truthfulqa_mc2|0.5000|±  |0.0160|
#
# Loading evaluation results...
#
# Processing task: gsm8k
# Loading results from: eval_results/gsm8k/results/hara-CU/minicompe-model/results_2025-08-23T09-53-02.761811.json
#   Loaded 2 metrics
#
# Processing task: aime24
# Loading results from: eval_results/aime24/results/hara-CU/minicompe-model/results_2025-08-23T10-01-26.236895.json
#   Loaded 12 metrics
#
# Processing task: gpqa-diamond
# Loading results from: eval_results/gpqa-diamond/results/hara-CU/minicompe-model/results_2025-08-23T10-08-47.688829.json
#   Loaded 6 metrics
#
# Processing task: truthfulqa-mc
# Loading results from: eval_results/truthfulqa-mc/results/hara-CU/minicompe-model/results_2025-08-23T10-13-40.617784.json
#   Loaded 4 metrics
#
# Processing task: toxigen
# Loading results from: eval_results/toxigen/results/hara-CU/minicompe-model/results_2025-08-23T10-10-24.827121.json
#   Loaded 4 metrics
#
# Calculating averages...
# Calculated 6 average metrics
#
# === Task Results ===
#
# gsm8k:
#   extractive_match: 0.8059
#   extractive_match_stderr: 0.0109
#
# aime24:
#   math_pass@1:1_samples: 0.0333
#   math_pass@1:1_samples_stderr: 0.0333
#   math_pass@1:4_samples: 0.0083
#   math_pass@1:4_samples_stderr: 0.0083
#   math_pass@1:8_samples: 0.0125
#   math_pass@1:8_samples_stderr: 0.0092
#   math_pass@1:16_samples: 0.0104
#   math_pass@1:16_samples_stderr: 0.0085
#   math_pass@1:32_samples: 0.0177
#   math_pass@1:32_samples_stderr: 0.0157
#   math_pass@1:64_samples: 0.0146
#   math_pass@1:64_samples_stderr: 0.0126
#
# gpqa-diamond:
#   gpqa_pass@1:1_samples: 0.3333
#   gpqa_pass@1:1_samples_stderr: 0.0336
#   gpqa_pass@1:4_samples: 0.3245
#   gpqa_pass@1:4_samples_stderr: 0.0239
#   gpqa_pass@1:8_samples: 0.3163
#   gpqa_pass@1:8_samples_stderr: 0.0211
#
# truthfulqa-mc:
#   truthfulqa_mc1: 0.3488
#   truthfulqa_mc1_stderr: 0.0167
#   truthfulqa_mc2: 0.5000
#   truthfulqa_mc2_stderr: 0.0160
#
# toxigen:
#   acc: 0.4319
#   acc_stderr: 0.0162
#   acc_norm: 0.4319
#   acc_norm_stderr: 0.0162
#
# === Average Results ===
# Average metrics: 0.3908
#
# Uploading to wandb...
# Training Config Table logged
# Detail Metrics Table logged
# Evaluation Score Table logged
# Evaluation Samples Table logged
# Successfully uploaded to wandb!
# [2025-08-23 09:46:01,627] [    INFO]: PyTorch version 2.7.0 available. (config.py:54)
# [2025-08-23 09:46:08,097] [    INFO]: --- LOADING MODEL --- (pipeline.py:187)
# [2025-08-23 09:46:17,724] [    INFO]: This model supports multiple tasks: {'classify', 'embed', 'generate', 'reward'}. Defaulting to 'generate'. (config.py:841)
# [2025-08-23 09:46:17,724] [    INFO]: Using max model len 2048 (config.py:1472)
# [2025-08-23 09:46:17,726] [    INFO]: Chunked prefill is enabled with max_num_batched_tokens=2048. (config.py:2285)
# [2025-08-23 09:46:18,659] [    INFO]: Waiting for init message from front-end. (core.py:526)
# [2025-08-23 09:46:18,663] [    INFO]: Initializing a V1 LLM engine (v0.9.2) with config: model='hara-CU/minicompe-model', speculative_config=None, tokenizer='hara-CU/minicompe-model', skip_tokenizer_init=False, tokenizer_mode=auto, revision=Drgrpo_2048_verify_plus_groq_short_length_bonus, override_neuron_config={}, tokenizer_revision=Drgrpo_2048_verify_plus_groq_short_length_bonus, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=1, served_model_name=hara-CU/minicompe-model, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":512,"local_cache_dir":null} (core.py:69)
# [2025-08-23 09:46:20,392] [    INFO]: rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0 (parallel_state.py:1076)
# [2025-08-23 09:46:20,396] [ WARNING]: FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer. (topk_topp_sampler.py:59)
# [2025-08-23 09:46:20,420] [    INFO]: Starting to load model hara-CU/minicompe-model... (gpu_model_runner.py:1770)
# [2025-08-23 09:46:20,726] [    INFO]: Loading model from scratch... (gpu_model_runner.py:1775)
# [2025-08-23 09:46:20,865] [    INFO]: Using Flash Attention backend on V1 engine. (cuda.py:284)
# [2025-08-23 09:46:21,292] [    INFO]: Using model weights format ['*.safetensors'] (weight_utils.py:292)
# [2025-08-23 09:47:02,822] [    INFO]: Time spent downloading weights for hara-CU/minicompe-model: 41.529364 seconds (weight_utils.py:308)
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:00<00:00,  1.11it/s]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.21s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.16s/it]
#
# [2025-08-23 09:47:05,589] [    INFO]: Loading weights took 2.44 seconds (default_loader.py:272)
# [2025-08-23 09:47:06,182] [    INFO]: Model loading took 7.5552 GiB and 44.868926 seconds (gpu_model_runner.py:1801)
# [2025-08-23 09:47:19,715] [    INFO]: Using cache directory: /root/.cache/vllm/torch_compile_cache/7c6a0a2af6/rank_0_0/backbone for vLLM's torch.compile (backends.py:508)
# [2025-08-23 09:47:19,715] [    INFO]: Dynamo bytecode transform time: 13.24 s (backends.py:519)
# [2025-08-23 09:47:26,436] [    INFO]: Cache the graph of shape None for later use (backends.py:181)
# [2025-08-23 09:48:08,357] [    INFO]: Compiling a graph for general shape takes 47.15 s (backends.py:193)
# [2025-08-23 09:48:27,270] [    INFO]: torch.compile takes 60.38 s in total (monitor.py:34)
# [2025-08-23 09:48:28,553] [    INFO]: Available KV cache memory: 27.25 GiB (gpu_worker.py:232)
# [2025-08-23 09:48:29,011] [    INFO]: GPU KV cache size: 198,384 tokens (kv_cache_utils.py:716)
# [2025-08-23 09:48:29,011] [    INFO]: Maximum concurrency for 2,048 tokens per request: 96.87x (kv_cache_utils.py:720)
# Capturing CUDA graph shapes: 100%|██████████| 67/67 [00:35<00:00,  1.90it/s]
# [2025-08-23 09:49:04,258] [    INFO]: Graph capturing finished in 35 secs, took 0.61 GiB (gpu_model_runner.py:2326)
# [2025-08-23 09:49:04,272] [    INFO]: init engine (profile, create kv cache, warmup model) took 118.09 seconds (core.py:172)
# [2025-08-23 09:49:04,983] [    INFO]: --- INIT SEEDS --- (pipeline.py:258)
# [2025-08-23 09:49:04,983] [    INFO]: --- LOADING TASKS --- (pipeline.py:212)
# [2025-08-23 09:49:04,984] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:137)
# [2025-08-23 09:49:04,987] [    INFO]: gsm8k main (lighteval_task.py:187)
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 430999.86 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 311906.58 examples/s]
# [2025-08-23 09:49:08,624] [    INFO]: --- RUNNING MODEL --- (pipeline.py:482)
# [2025-08-23 09:49:08,624] [    INFO]: Running RequestType.GREEDY_UNTIL requests (pipeline.py:468)
# [2025-08-23 09:49:09,324] [ WARNING]: You cannot select the number of dataset splits for a generative evaluation at the moment. Automatically inferring. (data.py:237)
# Splits:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests:   0%|          | 0/1319 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1319/1319 [00:00<00:00, 8892.35it/s]
#
# Processed prompts:   0%|          | 0/1319 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts:   0%|          | 1/1319 [00:07<2:49:14,  7.70s/it, est. speed input: 13.76 toks/s, output: 43.48 toks/s]
# Processed prompts:   0%|          | 2/1319 [00:10<1:46:26,  4.85s/it, est. speed input: 20.18 toks/s, output: 74.37 toks/s]
# Processed prompts:   0%|          | 3/1319 [00:11<1:06:05,  3.01s/it, est. speed input: 27.76 toks/s, output: 111.30 toks/s]
# Processed prompts:   0%|          | 4/1319 [00:11<41:28,  1.89s/it, est. speed input: 36.69 toks/s, output: 152.11 toks/s]
# Processed prompts:   0%|          | 5/1319 [00:11<28:53,  1.32s/it, est. speed input: 43.59 toks/s, output: 190.29 toks/s]
# Processed prompts:   0%|          | 6/1319 [00:12<21:53,  1.00s/it, est. speed input: 51.79 toks/s, output: 226.35 toks/s]
# Processed prompts:   1%|          | 7/1319 [00:12<18:01,  1.21it/s, est. speed input: 58.10 toks/s, output: 259.77 toks/s]
# Processed prompts:   1%|          | 9/1319 [00:12<10:30,  2.08it/s, est. speed input: 76.86 toks/s, output: 338.54 toks/s]
# Processed prompts:   1%|          | 10/1319 [00:14<14:42,  1.48it/s, est. speed input: 78.57 toks/s, output: 350.34 toks/s]
# Processed prompts:   1%|          | 11/1319 [00:14<12:08,  1.79it/s, est. speed input: 87.34 toks/s, output: 386.02 toks/s]
# Processed prompts:   1%|          | 13/1319 [00:14<08:13,  2.65it/s, est. speed input: 101.35 toks/s, output: 459.91 toks/s]
# Processed prompts:   1%|          | 14/1319 [00:15<08:51,  2.45it/s, est. speed input: 109.12 toks/s, output: 485.83 toks/s]
# Processed prompts:   1%|          | 15/1319 [00:15<07:47,  2.79it/s, est. speed input: 114.42 toks/s, output: 519.62 toks/s]
# Processed prompts:   1%|          | 16/1319 [00:15<07:06,  3.06it/s, est. speed input: 119.57 toks/s, output: 552.17 toks/s]
# Processed prompts:   1%|▏         | 17/1319 [00:16<07:41,  2.82it/s, est. speed input: 123.86 toks/s, output: 578.04 toks/s]
# Processed prompts:   1%|▏         | 18/1319 [00:16<07:39,  2.83it/s, est. speed input: 127.43 toks/s, output: 606.09 toks/s]
# Processed prompts:   1%|▏         | 19/1319 [00:16<07:18,  2.96it/s, est. speed input: 132.21 toks/s, output: 635.47 toks/s]
# Processed prompts:   2%|▏         | 20/1319 [00:16<05:51,  3.69it/s, est. speed input: 137.90 toks/s, output: 671.44 toks/s]
# Processed prompts:   2%|▏         | 21/1319 [00:17<06:53,  3.14it/s, est. speed input: 141.56 toks/s, output: 694.64 toks/s]
# Processed prompts:   2%|▏         | 22/1319 [00:17<05:53,  3.67it/s, est. speed input: 146.20 toks/s, output: 727.90 toks/s]
# Processed prompts:   2%|▏         | 23/1319 [00:17<04:50,  4.47it/s, est. speed input: 151.46 toks/s, output: 763.21 toks/s]
# Processed prompts:   2%|▏         | 25/1319 [00:18<09:15,  2.33it/s, est. speed input: 151.13 toks/s, output: 785.25 toks/s]
# Processed prompts:   2%|▏         | 26/1319 [00:19<09:27,  2.28it/s, est. speed input: 152.83 toks/s, output: 805.39 toks/s]
# Processed prompts:   2%|▏         | 27/1319 [00:19<09:19,  2.31it/s, est. speed input: 156.39 toks/s, output: 827.88 toks/s]
# Processed prompts:   2%|▏         | 28/1319 [00:20<08:34,  2.51it/s, est. speed input: 161.27 toks/s, output: 854.60 toks/s]
# Processed prompts:   2%|▏         | 29/1319 [00:20<09:22,  2.29it/s, est. speed input: 163.82 toks/s, output: 871.69 toks/s]
# Processed prompts:   2%|▏         | 30/1319 [00:20<08:25,  2.55it/s, est. speed input: 166.68 toks/s, output: 898.78 toks/s]
# Processed prompts:   2%|▏         | 31/1319 [00:21<12:40,  1.69it/s, est. speed input: 163.61 toks/s, output: 893.47 toks/s]
# Processed prompts:   2%|▏         | 32/1319 [00:22<10:14,  2.10it/s, est. speed input: 167.38 toks/s, output: 923.97 toks/s]
# Processed prompts:   3%|▎         | 33/1319 [00:22<09:23,  2.28it/s, est. speed input: 169.38 toks/s, output: 948.20 toks/s]
# Processed prompts:   3%|▎         | 34/1319 [00:22<08:37,  2.48it/s, est. speed input: 172.72 toks/s, output: 973.61 toks/s]
# Processed prompts:   3%|▎         | 35/1319 [00:23<07:09,  2.99it/s, est. speed input: 175.98 toks/s, output: 1004.51 toks/s]
# Processed prompts:   3%|▎         | 37/1319 [00:23<06:41,  3.19it/s, est. speed input: 182.48 toks/s, output: 1055.62 toks/s]
# Processed prompts:   3%|▎         | 38/1319 [00:23<05:48,  3.67it/s, est. speed input: 185.31 toks/s, output: 1087.10 toks/s]
# Processed prompts:   3%|▎         | 39/1319 [00:23<05:06,  4.18it/s, est. speed input: 188.58 toks/s, output: 1118.44 toks/s]
# Processed prompts:   3%|▎         | 41/1319 [00:24<03:43,  5.71it/s, est. speed input: 198.87 toks/s, output: 1186.01 toks/s]
# Processed prompts:   3%|▎         | 42/1319 [00:24<03:35,  5.93it/s, est. speed input: 202.79 toks/s, output: 1216.79 toks/s]
# Processed prompts:   3%|▎         | 43/1319 [00:24<04:49,  4.41it/s, est. speed input: 204.73 toks/s, output: 1234.78 toks/s]
# Processed prompts:   3%|▎         | 44/1319 [00:24<04:12,  5.05it/s, est. speed input: 207.96 toks/s, output: 1266.54 toks/s]
# Processed prompts:   3%|▎         | 45/1319 [00:24<03:43,  5.69it/s, est. speed input: 211.37 toks/s, output: 1298.22 toks/s]
# Processed prompts:   3%|▎         | 46/1319 [00:24<03:32,  5.98it/s, est. speed input: 214.27 toks/s, output: 1328.15 toks/s]
# Processed prompts:   4%|▎         | 48/1319 [00:25<03:44,  5.67it/s, est. speed input: 219.49 toks/s, output: 1382.93 toks/s]
# Processed prompts:   4%|▎         | 49/1319 [00:25<04:26,  4.76it/s, est. speed input: 221.28 toks/s, output: 1403.39 toks/s]
# Processed prompts:   4%|▍         | 51/1319 [00:25<03:44,  5.64it/s, est. speed input: 228.38 toks/s, output: 1463.86 toks/s]
# Processed prompts:   4%|▍         | 52/1319 [00:26<04:48,  4.39it/s, est. speed input: 229.01 toks/s, output: 1478.75 toks/s]
# Processed prompts:   4%|▍         | 53/1319 [00:26<04:22,  4.81it/s, est. speed input: 231.57 toks/s, output: 1507.70 toks/s]
# Processed prompts:   4%|▍         | 55/1319 [00:26<04:19,  4.87it/s, est. speed input: 236.64 toks/s, output: 1558.85 toks/s]
# Processed prompts:   4%|▍         | 56/1319 [00:26<03:53,  5.41it/s, est. speed input: 240.30 toks/s, output: 1589.27 toks/s]
# Processed prompts:   4%|▍         | 57/1319 [00:27<06:00,  3.50it/s, est. speed input: 242.36 toks/s, output: 1592.07 toks/s]
# Processed prompts:   5%|▌         | 66/1319 [00:27<01:40, 12.42it/s, est. speed input: 288.03 toks/s, output: 1916.47 toks/s]
# Processed prompts:   7%|▋         | 87/1319 [00:27<00:34, 35.27it/s, est. speed input: 382.76 toks/s, output: 2676.30 toks/s]
# Processed prompts:   8%|▊         | 107/1319 [00:28<00:21, 57.22it/s, est. speed input: 466.48 toks/s, output: 3395.17 toks/s]
# Processed prompts:   9%|▉         | 124/1319 [00:28<00:15, 75.62it/s, est. speed input: 529.22 toks/s, output: 4001.59 toks/s]
# Processed prompts:  10%|█         | 135/1319 [00:34<03:02,  6.48it/s, est. speed input: 465.86 toks/s, output: 3519.68 toks/s]
# Processed prompts:  11%|█         | 143/1319 [00:38<04:38,  4.22it/s, est. speed input: 431.85 toks/s, output: 3256.02 toks/s]
# Processed prompts:  11%|█▏        | 149/1319 [00:40<04:50,  4.03it/s, est. speed input: 426.95 toks/s, output: 3211.94 toks/s]
# Processed prompts:  12%|█▏        | 153/1319 [00:41<04:38,  4.19it/s, est. speed input: 428.67 toks/s, output: 3220.81 toks/s]
# Processed prompts:  12%|█▏        | 156/1319 [00:42<04:57,  3.91it/s, est. speed input: 424.26 toks/s, output: 3190.04 toks/s]
# Processed prompts:  12%|█▏        | 159/1319 [00:43<05:07,  3.77it/s, est. speed input: 421.98 toks/s, output: 3172.71 toks/s]
# Processed prompts:  12%|█▏        | 161/1319 [00:43<04:43,  4.08it/s, est. speed input: 424.50 toks/s, output: 3202.82 toks/s]
# Processed prompts:  12%|█▏        | 163/1319 [00:44<05:06,  3.77it/s, est. speed input: 421.97 toks/s, output: 3189.29 toks/s]
# Processed prompts:  13%|█▎        | 165/1319 [00:44<04:33,  4.22it/s, est. speed input: 424.58 toks/s, output: 3209.80 toks/s]
# Processed prompts:  13%|█▎        | 166/1319 [00:44<04:32,  4.23it/s, est. speed input: 424.39 toks/s, output: 3215.93 toks/s]
# Processed prompts:  13%|█▎        | 168/1319 [00:45<04:27,  4.30it/s, est. speed input: 424.01 toks/s, output: 3212.97 toks/s]
# Processed prompts:  13%|█▎        | 170/1319 [00:45<04:11,  4.57it/s, est. speed input: 425.16 toks/s, output: 3229.40 toks/s]
# Processed prompts:  13%|█▎        | 173/1319 [00:45<03:45,  5.09it/s, est. speed input: 427.10 toks/s, output: 3251.39 toks/s]
# Processed prompts:  13%|█▎        | 174/1319 [00:46<03:28,  5.48it/s, est. speed input: 428.31 toks/s, output: 3259.84 toks/s]
# Processed prompts:  13%|█▎        | 176/1319 [00:46<04:47,  3.98it/s, est. speed input: 424.81 toks/s, output: 3239.04 toks/s]
# Processed prompts:  14%|█▎        | 180/1319 [00:47<02:59,  6.34it/s, est. speed input: 430.97 toks/s, output: 3299.67 toks/s]
# Processed prompts:  14%|█▍        | 182/1319 [00:47<02:54,  6.51it/s, est. speed input: 432.10 toks/s, output: 3310.47 toks/s]
# Processed prompts:  14%|█▍        | 183/1319 [00:48<05:04,  3.73it/s, est. speed input: 425.76 toks/s, output: 3263.16 toks/s]
# Processed prompts:  14%|█▍        | 184/1319 [00:48<04:47,  3.95it/s, est. speed input: 425.94 toks/s, output: 3266.60 toks/s]
# Processed prompts:  14%|█▍        | 185/1319 [00:48<04:31,  4.18it/s, est. speed input: 426.62 toks/s, output: 3273.35 toks/s]
# Processed prompts:  14%|█▍        | 186/1319 [00:49<06:05,  3.10it/s, est. speed input: 423.25 toks/s, output: 3250.77 toks/s]
# Processed prompts:  14%|█▍        | 187/1319 [00:49<06:04,  3.10it/s, est. speed input: 422.50 toks/s, output: 3250.29 toks/s]
# Processed prompts:  14%|█▍        | 188/1319 [00:49<05:25,  3.48it/s, est. speed input: 422.78 toks/s, output: 3254.43 toks/s]
# Processed prompts:  14%|█▍        | 189/1319 [00:49<04:29,  4.19it/s, est. speed input: 423.89 toks/s, output: 3268.06 toks/s]
# Processed prompts:  14%|█▍        | 190/1319 [00:50<04:38,  4.06it/s, est. speed input: 423.49 toks/s, output: 3267.12 toks/s]
# Processed prompts:  15%|█▍        | 192/1319 [00:50<03:34,  5.26it/s, est. speed input: 425.13 toks/s, output: 3284.57 toks/s]
# Processed prompts:  15%|█▍        | 193/1319 [00:50<05:22,  3.50it/s, est. speed input: 422.40 toks/s, output: 3266.62 toks/s]
# Processed prompts:  15%|█▍        | 194/1319 [00:51<05:24,  3.47it/s, est. speed input: 421.96 toks/s, output: 3264.67 toks/s]
# Processed prompts:  15%|█▍        | 195/1319 [00:51<05:26,  3.44it/s, est. speed input: 421.17 toks/s, output: 3259.24 toks/s]
# Processed prompts:  15%|█▍        | 197/1319 [00:51<03:57,  4.72it/s, est. speed input: 422.93 toks/s, output: 3279.48 toks/s]
# Processed prompts:  15%|█▌        | 198/1319 [00:51<03:36,  5.18it/s, est. speed input: 423.52 toks/s, output: 3288.08 toks/s]
# Processed prompts:  15%|█▌        | 201/1319 [00:51<02:07,  8.76it/s, est. speed input: 428.18 toks/s, output: 3334.85 toks/s]
# Processed prompts:  15%|█▌        | 203/1319 [00:52<03:02,  6.13it/s, est. speed input: 428.36 toks/s, output: 3340.15 toks/s]
# Processed prompts:  15%|█▌        | 204/1319 [00:52<03:17,  5.65it/s, est. speed input: 428.13 toks/s, output: 3344.60 toks/s]
# Processed prompts:  16%|█▌        | 205/1319 [00:52<03:12,  5.79it/s, est. speed input: 428.43 toks/s, output: 3351.90 toks/s]
# Processed prompts:  16%|█▌        | 207/1319 [00:53<02:26,  7.59it/s, est. speed input: 430.88 toks/s, output: 3380.41 toks/s]
# Processed prompts:  16%|█▌        | 209/1319 [00:53<02:45,  6.70it/s, est. speed input: 431.24 toks/s, output: 3391.94 toks/s]
# Processed prompts:  16%|█▌        | 210/1319 [00:53<02:41,  6.89it/s, est. speed input: 432.34 toks/s, output: 3402.90 toks/s]
# Processed prompts:  16%|█▌        | 212/1319 [00:53<02:07,  8.68it/s, est. speed input: 434.48 toks/s, output: 3421.99 toks/s]
# Processed prompts:  16%|█▌        | 214/1319 [00:54<03:33,  5.19it/s, est. speed input: 433.01 toks/s, output: 3414.97 toks/s]
# Processed prompts:  16%|█▋        | 216/1319 [00:54<03:04,  5.98it/s, est. speed input: 434.52 toks/s, output: 3438.10 toks/s]
# Processed prompts:  17%|█▋        | 219/1319 [00:54<02:03,  8.91it/s, est. speed input: 438.51 toks/s, output: 3471.06 toks/s]
# Processed prompts:  17%|█▋        | 221/1319 [00:55<02:35,  7.05it/s, est. speed input: 438.63 toks/s, output: 3479.90 toks/s]
# Processed prompts:  17%|█▋        | 223/1319 [00:56<04:17,  4.25it/s, est. speed input: 434.93 toks/s, output: 3458.00 toks/s]
# Processed prompts:  17%|█▋        | 228/1319 [00:56<02:21,  7.72it/s, est. speed input: 441.98 toks/s, output: 3541.06 toks/s]
# Processed prompts:  18%|█▊        | 240/1319 [00:56<00:57, 18.82it/s, est. speed input: 461.55 toks/s, output: 3752.43 toks/s]
# Processed prompts:  19%|█▉        | 252/1319 [00:56<00:34, 31.38it/s, est. speed input: 480.64 toks/s, output: 3963.65 toks/s]
# Processed prompts:  20%|█▉        | 261/1319 [00:57<01:01, 17.24it/s, est. speed input: 486.32 toks/s, output: 4056.30 toks/s]
# Processed prompts:  20%|██        | 266/1319 [00:59<02:43,  6.43it/s, est. speed input: 472.78 toks/s, output: 3947.66 toks/s]
# Processed prompts:  20%|██        | 270/1319 [01:01<03:54,  4.48it/s, est. speed input: 462.79 toks/s, output: 3867.79 toks/s]
# Processed prompts:  21%|██        | 273/1319 [01:02<03:56,  4.43it/s, est. speed input: 461.99 toks/s, output: 3860.59 toks/s]
# Processed prompts:  21%|██        | 275/1319 [01:03<03:48,  4.57it/s, est. speed input: 462.26 toks/s, output: 3860.31 toks/s]
# Processed prompts:  21%|██        | 277/1319 [01:03<03:24,  5.09it/s, est. speed input: 463.76 toks/s, output: 3881.40 toks/s]
# Processed prompts:  21%|██        | 279/1319 [01:03<03:22,  5.13it/s, est. speed input: 463.66 toks/s, output: 3881.32 toks/s]
# Processed prompts:  21%|██▏       | 281/1319 [01:04<04:26,  3.90it/s, est. speed input: 459.39 toks/s, output: 3850.10 toks/s]
# Processed prompts:  21%|██▏       | 282/1319 [01:05<05:12,  3.32it/s, est. speed input: 456.59 toks/s, output: 3826.67 toks/s]
# Processed prompts:  21%|██▏       | 283/1319 [01:05<05:11,  3.33it/s, est. speed input: 455.73 toks/s, output: 3816.62 toks/s]
# Processed prompts:  22%|██▏       | 284/1319 [01:05<05:49,  2.96it/s, est. speed input: 453.43 toks/s, output: 3798.68 toks/s]
# Processed prompts:  22%|██▏       | 285/1319 [01:06<05:46,  2.98it/s, est. speed input: 452.45 toks/s, output: 3790.82 toks/s]
# Processed prompts:  22%|██▏       | 286/1319 [01:07<07:47,  2.21it/s, est. speed input: 447.92 toks/s, output: 3758.40 toks/s]
# Processed prompts:  22%|██▏       | 288/1319 [01:07<05:05,  3.37it/s, est. speed input: 449.67 toks/s, output: 3774.40 toks/s]
# Processed prompts:  22%|██▏       | 290/1319 [01:07<04:45,  3.60it/s, est. speed input: 449.05 toks/s, output: 3775.61 toks/s]
# Processed prompts:  22%|██▏       | 291/1319 [01:07<04:18,  3.98it/s, est. speed input: 449.42 toks/s, output: 3775.39 toks/s]
# Processed prompts:  22%|██▏       | 293/1319 [01:08<03:48,  4.48it/s, est. speed input: 449.40 toks/s, output: 3769.58 toks/s]
# Processed prompts:  22%|██▏       | 294/1319 [01:09<05:54,  2.89it/s, est. speed input: 445.40 toks/s, output: 3734.86 toks/s]
# Processed prompts:  23%|██▎       | 300/1319 [01:09<02:46,  6.13it/s, est. speed input: 450.53 toks/s, output: 3793.71 toks/s]
# Processed prompts:  23%|██▎       | 302/1319 [01:10<03:28,  4.87it/s, est. speed input: 448.46 toks/s, output: 3778.82 toks/s]
# Processed prompts:  23%|██▎       | 303/1319 [01:10<03:58,  4.25it/s, est. speed input: 447.07 toks/s, output: 3771.17 toks/s]
# Processed prompts:  23%|██▎       | 305/1319 [01:10<04:00,  4.22it/s, est. speed input: 446.30 toks/s, output: 3763.76 toks/s]
# Processed prompts:  23%|██▎       | 306/1319 [01:11<03:54,  4.32it/s, est. speed input: 446.26 toks/s, output: 3765.20 toks/s]
# Processed prompts:  23%|██▎       | 307/1319 [01:11<03:49,  4.42it/s, est. speed input: 446.24 toks/s, output: 3768.04 toks/s]
# Processed prompts:  23%|██▎       | 309/1319 [01:11<03:18,  5.08it/s, est. speed input: 446.92 toks/s, output: 3776.43 toks/s]
# Processed prompts:  24%|██▎       | 312/1319 [01:11<02:31,  6.63it/s, est. speed input: 448.80 toks/s, output: 3799.97 toks/s]
# Processed prompts:  24%|██▍       | 315/1319 [01:12<02:07,  7.85it/s, est. speed input: 450.77 toks/s, output: 3816.54 toks/s]
# Processed prompts:  24%|██▍       | 317/1319 [01:12<01:49,  9.17it/s, est. speed input: 452.44 toks/s, output: 3834.24 toks/s]
# Processed prompts:  24%|██▍       | 319/1319 [01:12<01:49,  9.16it/s, est. speed input: 453.35 toks/s, output: 3841.42 toks/s]
# Processed prompts:  24%|██▍       | 321/1319 [01:12<02:14,  7.43it/s, est. speed input: 453.20 toks/s, output: 3847.23 toks/s]
# Processed prompts:  24%|██▍       | 322/1319 [01:13<02:20,  7.09it/s, est. speed input: 453.32 toks/s, output: 3846.17 toks/s]
# Processed prompts:  24%|██▍       | 323/1319 [01:13<02:21,  7.03it/s, est. speed input: 453.45 toks/s, output: 3852.42 toks/s]
# Processed prompts:  25%|██▍       | 325/1319 [01:13<02:18,  7.17it/s, est. speed input: 453.91 toks/s, output: 3859.01 toks/s]
# Processed prompts:  25%|██▍       | 326/1319 [01:13<02:25,  6.85it/s, est. speed input: 453.95 toks/s, output: 3863.88 toks/s]
# Processed prompts:  25%|██▍       | 327/1319 [01:13<02:30,  6.59it/s, est. speed input: 453.98 toks/s, output: 3864.65 toks/s]
# Processed prompts:  25%|██▍       | 328/1319 [01:14<02:29,  6.64it/s, est. speed input: 454.35 toks/s, output: 3870.82 toks/s]
# Processed prompts:  25%|██▌       | 331/1319 [01:14<01:36, 10.24it/s, est. speed input: 456.80 toks/s, output: 3900.08 toks/s]
# Processed prompts:  25%|██▌       | 333/1319 [01:14<01:30, 10.87it/s, est. speed input: 458.09 toks/s, output: 3909.81 toks/s]
# Processed prompts:  25%|██▌       | 335/1319 [01:14<01:46,  9.20it/s, est. speed input: 458.50 toks/s, output: 3917.46 toks/s]
# Processed prompts:  26%|██▌       | 337/1319 [01:15<02:24,  6.80it/s, est. speed input: 457.83 toks/s, output: 3916.15 toks/s]
# Processed prompts:  26%|██▌       | 339/1319 [01:15<03:26,  4.75it/s, est. speed input: 455.82 toks/s, output: 3902.37 toks/s]
# Processed prompts:  26%|██▌       | 341/1319 [01:16<04:05,  3.98it/s, est. speed input: 453.82 toks/s, output: 3884.63 toks/s]
# Processed prompts:  26%|██▌       | 343/1319 [01:16<03:27,  4.71it/s, est. speed input: 454.64 toks/s, output: 3895.27 toks/s]
# Processed prompts:  26%|██▌       | 344/1319 [01:16<03:19,  4.88it/s, est. speed input: 454.75 toks/s, output: 3899.84 toks/s]
# Processed prompts:  26%|██▌       | 346/1319 [01:17<02:43,  5.96it/s, est. speed input: 455.74 toks/s, output: 3914.21 toks/s]
# Processed prompts:  26%|██▋       | 348/1319 [01:17<02:15,  7.16it/s, est. speed input: 456.91 toks/s, output: 3927.56 toks/s]
# Processed prompts:  26%|██▋       | 349/1319 [01:17<02:16,  7.12it/s, est. speed input: 457.16 toks/s, output: 3931.55 toks/s]
# Processed prompts:  27%|██▋       | 350/1319 [01:17<03:50,  4.20it/s, est. speed input: 454.68 toks/s, output: 3914.46 toks/s]
# Processed prompts:  27%|██▋       | 352/1319 [01:18<02:54,  5.53it/s, est. speed input: 455.71 toks/s, output: 3929.15 toks/s]
# Processed prompts:  27%|██▋       | 354/1319 [01:18<03:16,  4.92it/s, est. speed input: 454.90 toks/s, output: 3930.43 toks/s]
# Processed prompts:  27%|██▋       | 355/1319 [01:18<03:09,  5.08it/s, est. speed input: 455.13 toks/s, output: 3929.64 toks/s]
# Processed prompts:  27%|██▋       | 356/1319 [01:19<04:53,  3.29it/s, est. speed input: 452.41 toks/s, output: 3908.87 toks/s]
# Processed prompts:  27%|██▋       | 357/1319 [01:19<04:34,  3.51it/s, est. speed input: 452.15 toks/s, output: 3908.77 toks/s]
# Processed prompts:  27%|██▋       | 359/1319 [01:19<03:14,  4.93it/s, est. speed input: 453.19 toks/s, output: 3924.42 toks/s]
# Processed prompts:  27%|██▋       | 360/1319 [01:20<05:04,  3.15it/s, est. speed input: 450.29 toks/s, output: 3900.70 toks/s]
# Processed prompts:  28%|██▊       | 365/1319 [01:20<02:11,  7.23it/s, est. speed input: 454.83 toks/s, output: 3947.45 toks/s]
# Processed prompts:  28%|██▊       | 367/1319 [01:21<02:24,  6.57it/s, est. speed input: 454.65 toks/s, output: 3951.53 toks/s]
# Processed prompts:  28%|██▊       | 369/1319 [01:21<02:47,  5.66it/s, est. speed input: 453.89 toks/s, output: 3951.89 toks/s]
# Processed prompts:  28%|██▊       | 371/1319 [01:21<02:21,  6.69it/s, est. speed input: 455.16 toks/s, output: 3969.28 toks/s]
# Processed prompts:  28%|██▊       | 373/1319 [01:22<02:34,  6.13it/s, est. speed input: 454.77 toks/s, output: 3966.15 toks/s]
# Processed prompts:  28%|██▊       | 375/1319 [01:22<03:02,  5.18it/s, est. speed input: 453.77 toks/s, output: 3952.22 toks/s]
# Processed prompts:  29%|██▊       | 377/1319 [01:22<02:48,  5.60it/s, est. speed input: 454.11 toks/s, output: 3957.78 toks/s]
# Processed prompts:  29%|██▉       | 380/1319 [01:23<02:38,  5.91it/s, est. speed input: 454.47 toks/s, output: 3965.19 toks/s]
# Processed prompts:  29%|██▉       | 381/1319 [01:23<02:34,  6.06it/s, est. speed input: 454.60 toks/s, output: 3964.50 toks/s]
# Processed prompts:  29%|██▉       | 382/1319 [01:23<02:52,  5.44it/s, est. speed input: 454.10 toks/s, output: 3963.68 toks/s]
# Processed prompts:  29%|██▉       | 383/1319 [01:24<04:07,  3.79it/s, est. speed input: 451.99 toks/s, output: 3947.03 toks/s]
# Processed prompts:  30%|██▉       | 391/1319 [01:24<01:24, 11.00it/s, est. speed input: 458.98 toks/s, output: 4037.43 toks/s]
# Processed prompts:  30%|███       | 397/1319 [01:24<00:56, 16.43it/s, est. speed input: 463.89 toks/s, output: 4104.00 toks/s]
# Processed prompts:  30%|███       | 402/1319 [01:25<01:23, 11.04it/s, est. speed input: 464.45 toks/s, output: 4123.13 toks/s]
# Processed prompts:  31%|███       | 405/1319 [01:26<02:17,  6.65it/s, est. speed input: 461.28 toks/s, output: 4096.07 toks/s]
# Processed prompts:  31%|███       | 407/1319 [01:26<02:28,  6.14it/s, est. speed input: 460.75 toks/s, output: 4096.72 toks/s]
# Processed prompts:  31%|███       | 409/1319 [01:27<02:16,  6.66it/s, est. speed input: 461.68 toks/s, output: 4101.44 toks/s]
# Processed prompts:  31%|███       | 411/1319 [01:27<02:25,  6.24it/s, est. speed input: 461.22 toks/s, output: 4097.96 toks/s]
# Processed prompts:  31%|███       | 412/1319 [01:27<02:52,  5.25it/s, est. speed input: 460.19 toks/s, output: 4089.35 toks/s]
# Processed prompts:  31%|███▏      | 414/1319 [01:28<02:21,  6.40it/s, est. speed input: 461.24 toks/s, output: 4102.45 toks/s]
# Processed prompts:  31%|███▏      | 415/1319 [01:28<02:14,  6.73it/s, est. speed input: 461.53 toks/s, output: 4104.27 toks/s]
# Processed prompts:  32%|███▏      | 416/1319 [01:28<03:29,  4.32it/s, est. speed input: 459.55 toks/s, output: 4089.10 toks/s]
# Processed prompts:  32%|███▏      | 418/1319 [01:29<03:28,  4.33it/s, est. speed input: 458.84 toks/s, output: 4082.22 toks/s]
# Processed prompts:  32%|███▏      | 419/1319 [01:29<03:24,  4.39it/s, est. speed input: 458.65 toks/s, output: 4080.07 toks/s]
# Processed prompts:  32%|███▏      | 420/1319 [01:29<04:21,  3.44it/s, est. speed input: 456.80 toks/s, output: 4065.43 toks/s]
# Processed prompts:  32%|███▏      | 421/1319 [01:30<03:42,  4.03it/s, est. speed input: 457.02 toks/s, output: 4067.45 toks/s]
# Processed prompts:  32%|███▏      | 422/1319 [01:30<04:55,  3.03it/s, est. speed input: 455.01 toks/s, output: 4053.31 toks/s]
# Processed prompts:  32%|███▏      | 423/1319 [01:30<04:16,  3.50it/s, est. speed input: 455.01 toks/s, output: 4057.19 toks/s]
# Processed prompts:  32%|███▏      | 424/1319 [01:31<04:23,  3.40it/s, est. speed input: 454.55 toks/s, output: 4054.37 toks/s]
# Processed prompts:  32%|███▏      | 425/1319 [01:31<04:54,  3.04it/s, est. speed input: 453.31 toks/s, output: 4043.74 toks/s]
# Processed prompts:  32%|███▏      | 426/1319 [01:31<04:51,  3.07it/s, est. speed input: 452.65 toks/s, output: 4040.87 toks/s]
# Processed prompts:  32%|███▏      | 428/1319 [01:31<03:08,  4.72it/s, est. speed input: 453.70 toks/s, output: 4052.55 toks/s]
# Processed prompts:  33%|███▎      | 429/1319 [01:32<02:58,  4.97it/s, est. speed input: 453.70 toks/s, output: 4052.41 toks/s]
# Processed prompts:  33%|███▎      | 431/1319 [01:32<02:55,  5.07it/s, est. speed input: 453.67 toks/s, output: 4054.26 toks/s]
# Processed prompts:  33%|███▎      | 433/1319 [01:32<02:34,  5.73it/s, est. speed input: 453.96 toks/s, output: 4053.69 toks/s]
# Processed prompts:  33%|███▎      | 435/1319 [01:32<02:05,  7.07it/s, est. speed input: 454.92 toks/s, output: 4063.86 toks/s]
# Processed prompts:  33%|███▎      | 436/1319 [01:33<02:18,  6.39it/s, est. speed input: 454.66 toks/s, output: 4060.56 toks/s]
# Processed prompts:  33%|███▎      | 438/1319 [01:33<01:57,  7.52it/s, est. speed input: 455.37 toks/s, output: 4065.65 toks/s]
# Processed prompts:  33%|███▎      | 439/1319 [01:33<02:12,  6.65it/s, est. speed input: 455.19 toks/s, output: 4063.28 toks/s]
# Processed prompts:  33%|███▎      | 440/1319 [01:34<03:05,  4.73it/s, est. speed input: 453.95 toks/s, output: 4055.80 toks/s]
# Processed prompts:  33%|███▎      | 441/1319 [01:34<02:56,  4.98it/s, est. speed input: 453.92 toks/s, output: 4056.16 toks/s]
# Processed prompts:  34%|███▎      | 444/1319 [01:34<01:46,  8.23it/s, est. speed input: 455.56 toks/s, output: 4074.30 toks/s]
# Processed prompts:  34%|███▍      | 446/1319 [01:35<04:07,  3.53it/s, est. speed input: 451.50 toks/s, output: 4040.35 toks/s]
# Processed prompts:  34%|███▍      | 450/1319 [01:35<02:25,  5.97it/s, est. speed input: 453.93 toks/s, output: 4070.64 toks/s]
# Processed prompts:  34%|███▍      | 452/1319 [01:36<02:56,  4.92it/s, est. speed input: 452.77 toks/s, output: 4057.73 toks/s]
# Processed prompts:  34%|███▍      | 453/1319 [01:36<02:48,  5.15it/s, est. speed input: 452.78 toks/s, output: 4057.21 toks/s]
# Processed prompts:  34%|███▍      | 455/1319 [01:36<02:30,  5.72it/s, est. speed input: 453.07 toks/s, output: 4062.82 toks/s]
# Processed prompts:  35%|███▍      | 456/1319 [01:36<02:29,  5.76it/s, est. speed input: 453.10 toks/s, output: 4065.29 toks/s]
# Processed prompts:  35%|███▍      | 458/1319 [01:37<02:27,  5.82it/s, est. speed input: 453.17 toks/s, output: 4070.33 toks/s]
# Processed prompts:  35%|███▍      | 459/1319 [01:37<02:23,  6.01it/s, est. speed input: 453.19 toks/s, output: 4070.69 toks/s]
# Processed prompts:  35%|███▍      | 460/1319 [01:37<02:13,  6.43it/s, est. speed input: 453.38 toks/s, output: 4071.81 toks/s]
# Processed prompts:  35%|███▌      | 463/1319 [01:37<01:24, 10.14it/s, est. speed input: 455.45 toks/s, output: 4096.75 toks/s]
# Processed prompts:  35%|███▌      | 465/1319 [01:38<02:12,  6.46it/s, est. speed input: 454.52 toks/s, output: 4092.93 toks/s]
# Processed prompts:  35%|███▌      | 467/1319 [01:38<02:01,  7.00it/s, est. speed input: 454.89 toks/s, output: 4097.10 toks/s]
# Processed prompts:  36%|███▌      | 470/1319 [01:38<01:30,  9.34it/s, est. speed input: 456.55 toks/s, output: 4111.47 toks/s]
# Processed prompts:  36%|███▌      | 472/1319 [01:39<03:36,  3.92it/s, est. speed input: 452.15 toks/s, output: 4073.45 toks/s]
# Processed prompts:  36%|███▌      | 473/1319 [01:40<03:24,  4.15it/s, est. speed input: 452.14 toks/s, output: 4076.80 toks/s]
# Processed prompts:  36%|███▌      | 474/1319 [01:40<03:08,  4.49it/s, est. speed input: 452.28 toks/s, output: 4076.78 toks/s]
# Processed prompts:  36%|███▌      | 475/1319 [01:40<02:53,  4.86it/s, est. speed input: 452.42 toks/s, output: 4081.12 toks/s]
# Processed prompts:  36%|███▌      | 476/1319 [01:40<03:11,  4.40it/s, est. speed input: 451.97 toks/s, output: 4075.89 toks/s]
# Processed prompts:  36%|███▌      | 477/1319 [01:40<02:53,  4.85it/s, est. speed input: 452.13 toks/s, output: 4080.21 toks/s]
# Processed prompts:  36%|███▌      | 478/1319 [01:40<02:34,  5.45it/s, est. speed input: 452.44 toks/s, output: 4085.54 toks/s]
# Processed prompts:  36%|███▋      | 479/1319 [01:41<03:12,  4.37it/s, est. speed input: 451.57 toks/s, output: 4075.78 toks/s]
# Processed prompts:  36%|███▋      | 481/1319 [01:41<02:59,  4.66it/s, est. speed input: 451.45 toks/s, output: 4076.34 toks/s]
# Processed prompts:  37%|███▋      | 483/1319 [01:41<02:12,  6.31it/s, est. speed input: 452.36 toks/s, output: 4087.13 toks/s]
# Processed prompts:  37%|███▋      | 484/1319 [01:41<02:10,  6.42it/s, est. speed input: 452.52 toks/s, output: 4091.12 toks/s]
# Processed prompts:  37%|███▋      | 486/1319 [01:42<02:05,  6.62it/s, est. speed input: 452.82 toks/s, output: 4097.00 toks/s]
# Processed prompts:  37%|███▋      | 488/1319 [01:42<01:48,  7.67it/s, est. speed input: 453.60 toks/s, output: 4109.46 toks/s]
# Processed prompts:  37%|███▋      | 489/1319 [01:42<02:53,  4.79it/s, est. speed input: 452.25 toks/s, output: 4096.76 toks/s]
# Processed prompts:  37%|███▋      | 490/1319 [01:43<02:36,  5.31it/s, est. speed input: 452.60 toks/s, output: 4102.01 toks/s]
# Processed prompts:  37%|███▋      | 491/1319 [01:43<02:42,  5.11it/s, est. speed input: 452.39 toks/s, output: 4102.49 toks/s]
# Processed prompts:  37%|███▋      | 494/1319 [01:43<01:38,  8.36it/s, est. speed input: 454.03 toks/s, output: 4115.75 toks/s]
# Processed prompts:  38%|███▊      | 496/1319 [01:43<02:28,  5.55it/s, est. speed input: 452.93 toks/s, output: 4107.40 toks/s]
# Processed prompts:  38%|███▊      | 497/1319 [01:44<02:18,  5.94it/s, est. speed input: 453.05 toks/s, output: 4107.12 toks/s]
# Processed prompts:  38%|███▊      | 498/1319 [01:44<02:13,  6.14it/s, est. speed input: 453.14 toks/s, output: 4111.33 toks/s]
# Processed prompts:  38%|███▊      | 500/1319 [01:44<03:09,  4.33it/s, est. speed input: 451.63 toks/s, output: 4101.10 toks/s]
# Processed prompts:  38%|███▊      | 503/1319 [01:45<02:10,  6.26it/s, est. speed input: 452.87 toks/s, output: 4111.49 toks/s]
# Processed prompts:  38%|███▊      | 504/1319 [01:45<02:11,  6.20it/s, est. speed input: 452.85 toks/s, output: 4110.95 toks/s]
# Processed prompts:  38%|███▊      | 505/1319 [01:45<02:28,  5.47it/s, est. speed input: 452.46 toks/s, output: 4110.19 toks/s]
# Processed prompts:  38%|███▊      | 506/1319 [01:45<02:30,  5.40it/s, est. speed input: 452.49 toks/s, output: 4112.34 toks/s]
# Processed prompts:  38%|███▊      | 507/1319 [01:46<03:51,  3.51it/s, est. speed input: 450.58 toks/s, output: 4098.85 toks/s]
# Processed prompts:  39%|███▊      | 508/1319 [01:46<03:27,  3.91it/s, est. speed input: 450.54 toks/s, output: 4101.88 toks/s]
# Processed prompts:  39%|███▊      | 510/1319 [01:46<02:18,  5.85it/s, est. speed input: 451.68 toks/s, output: 4116.15 toks/s]
# Processed prompts:  39%|███▉      | 512/1319 [01:47<02:28,  5.44it/s, est. speed input: 451.44 toks/s, output: 4119.00 toks/s]
# Processed prompts:  39%|███▉      | 514/1319 [01:47<01:55,  6.98it/s, est. speed input: 452.21 toks/s, output: 4126.97 toks/s]
# Processed prompts:  39%|███▉      | 516/1319 [01:47<01:54,  7.01it/s, est. speed input: 452.48 toks/s, output: 4133.49 toks/s]
# Processed prompts:  39%|███▉      | 517/1319 [01:47<02:44,  4.87it/s, est. speed input: 451.29 toks/s, output: 4125.02 toks/s]
# Processed prompts:  39%|███▉      | 518/1319 [01:48<02:59,  4.45it/s, est. speed input: 450.75 toks/s, output: 4123.27 toks/s]
# Processed prompts:  39%|███▉      | 520/1319 [01:48<02:34,  5.17it/s, est. speed input: 450.99 toks/s, output: 4129.49 toks/s]
# Processed prompts:  40%|███▉      | 524/1319 [01:49<02:11,  6.04it/s, est. speed input: 451.41 toks/s, output: 4143.93 toks/s]
# Processed prompts:  40%|███▉      | 526/1319 [01:49<02:27,  5.37it/s, est. speed input: 450.67 toks/s, output: 4141.42 toks/s]
# Processed prompts:  40%|████      | 528/1319 [01:49<02:17,  5.76it/s, est. speed input: 450.88 toks/s, output: 4144.53 toks/s]
# Processed prompts:  40%|████      | 530/1319 [01:50<02:03,  6.37it/s, est. speed input: 451.10 toks/s, output: 4144.85 toks/s]
# Processed prompts:  40%|████      | 531/1319 [01:50<02:15,  5.83it/s, est. speed input: 450.70 toks/s, output: 4142.16 toks/s]
# Processed prompts:  40%|████      | 532/1319 [01:50<02:22,  5.54it/s, est. speed input: 450.46 toks/s, output: 4143.26 toks/s]
# Processed prompts:  40%|████      | 533/1319 [01:50<02:28,  5.30it/s, est. speed input: 450.20 toks/s, output: 4139.15 toks/s]
# Processed prompts:  41%|████      | 535/1319 [01:50<01:47,  7.29it/s, est. speed input: 451.25 toks/s, output: 4147.05 toks/s]
# Processed prompts:  41%|████      | 538/1319 [01:51<01:38,  7.96it/s, est. speed input: 451.92 toks/s, output: 4159.23 toks/s]
# Processed prompts:  41%|████      | 539/1319 [01:51<01:53,  6.85it/s, est. speed input: 451.66 toks/s, output: 4159.43 toks/s]
# Processed prompts:  41%|████      | 540/1319 [01:51<01:52,  6.90it/s, est. speed input: 451.77 toks/s, output: 4156.87 toks/s]
# Processed prompts:  41%|████      | 541/1319 [01:52<02:53,  4.48it/s, est. speed input: 450.32 toks/s, output: 4142.41 toks/s]
# Processed prompts:  41%|████      | 542/1319 [01:52<02:52,  4.49it/s, est. speed input: 450.12 toks/s, output: 4143.39 toks/s]
# Processed prompts:  42%|████▏     | 548/1319 [01:52<01:09, 11.11it/s, est. speed input: 453.61 toks/s, output: 4186.85 toks/s]
# Processed prompts:  42%|████▏     | 551/1319 [01:52<00:56, 13.64it/s, est. speed input: 455.11 toks/s, output: 4209.83 toks/s]
# Processed prompts:  42%|████▏     | 553/1319 [01:52<01:15, 10.16it/s, est. speed input: 454.91 toks/s, output: 4210.43 toks/s]
# Processed prompts:  42%|████▏     | 555/1319 [01:53<01:34,  8.10it/s, est. speed input: 454.67 toks/s, output: 4211.97 toks/s]
# Processed prompts:  42%|████▏     | 557/1319 [01:53<01:56,  6.52it/s, est. speed input: 454.08 toks/s, output: 4205.89 toks/s]
# Processed prompts:  42%|████▏     | 558/1319 [01:54<03:10,  4.00it/s, est. speed input: 451.70 toks/s, output: 4186.46 toks/s]
# Processed prompts:  42%|████▏     | 559/1319 [01:54<03:01,  4.19it/s, est. speed input: 451.53 toks/s, output: 4185.14 toks/s]
# Processed prompts:  42%|████▏     | 560/1319 [01:54<02:41,  4.70it/s, est. speed input: 451.75 toks/s, output: 4188.01 toks/s]
# Processed prompts:  43%|████▎     | 562/1319 [01:54<01:55,  6.56it/s, est. speed input: 452.70 toks/s, output: 4202.04 toks/s]
# Processed prompts:  43%|████▎     | 564/1319 [01:55<01:30,  8.35it/s, est. speed input: 453.48 toks/s, output: 4206.64 toks/s]
# Processed prompts:  43%|████▎     | 566/1319 [01:55<01:40,  7.49it/s, est. speed input: 453.51 toks/s, output: 4209.56 toks/s]
# Processed prompts:  43%|████▎     | 569/1319 [01:55<01:13, 10.27it/s, est. speed input: 454.94 toks/s, output: 4225.24 toks/s]
# Processed prompts:  43%|████▎     | 571/1319 [01:56<01:46,  7.01it/s, est. speed input: 454.13 toks/s, output: 4221.06 toks/s]
# Processed prompts:  43%|████▎     | 573/1319 [01:56<01:52,  6.61it/s, est. speed input: 453.97 toks/s, output: 4221.48 toks/s]
# Processed prompts:  44%|████▎     | 575/1319 [01:56<01:38,  7.54it/s, est. speed input: 454.53 toks/s, output: 4228.12 toks/s]
# Processed prompts:  44%|████▎     | 577/1319 [01:56<01:38,  7.50it/s, est. speed input: 454.77 toks/s, output: 4230.79 toks/s]
# Processed prompts:  44%|████▍     | 578/1319 [01:57<01:42,  7.25it/s, est. speed input: 454.79 toks/s, output: 4229.73 toks/s]
# Processed prompts:  44%|████▍     | 579/1319 [01:57<02:06,  5.83it/s, est. speed input: 454.17 toks/s, output: 4223.84 toks/s]
# Processed prompts:  44%|████▍     | 580/1319 [01:57<02:00,  6.11it/s, est. speed input: 454.34 toks/s, output: 4227.11 toks/s]
# Processed prompts:  44%|████▍     | 582/1319 [01:57<01:42,  7.22it/s, est. speed input: 454.73 toks/s, output: 4232.69 toks/s]
# Processed prompts:  44%|████▍     | 583/1319 [01:57<01:37,  7.54it/s, est. speed input: 454.92 toks/s, output: 4236.24 toks/s]
# Processed prompts:  44%|████▍     | 585/1319 [01:57<01:17,  9.47it/s, est. speed input: 455.63 toks/s, output: 4244.48 toks/s]
# Processed prompts:  45%|████▍     | 587/1319 [01:58<01:24,  8.64it/s, est. speed input: 455.79 toks/s, output: 4248.08 toks/s]
# Processed prompts:  45%|████▍     | 588/1319 [01:58<01:52,  6.51it/s, est. speed input: 455.25 toks/s, output: 4244.64 toks/s]
# Processed prompts:  45%|████▍     | 590/1319 [01:58<02:03,  5.92it/s, est. speed input: 454.99 toks/s, output: 4242.21 toks/s]
# Processed prompts:  45%|████▍     | 591/1319 [01:59<02:05,  5.81it/s, est. speed input: 454.84 toks/s, output: 4242.20 toks/s]
# Processed prompts:  45%|████▍     | 592/1319 [01:59<02:27,  4.93it/s, est. speed input: 454.27 toks/s, output: 4236.64 toks/s]
# Processed prompts:  45%|████▍     | 593/1319 [01:59<02:15,  5.37it/s, est. speed input: 454.31 toks/s, output: 4239.94 toks/s]
# Processed prompts:  45%|████▌     | 595/1319 [01:59<02:14,  5.40it/s, est. speed input: 454.21 toks/s, output: 4239.46 toks/s]
# Processed prompts:  45%|████▌     | 597/1319 [01:59<01:44,  6.93it/s, est. speed input: 454.85 toks/s, output: 4249.58 toks/s]
# Processed prompts:  45%|████▌     | 599/1319 [02:00<01:35,  7.55it/s, est. speed input: 455.10 toks/s, output: 4250.77 toks/s]
# ...
# Processed prompts:  93%|█████████▎| 9271/9996 [01:32<00:07, 93.93it/s, est. speed input: 18913.45 toks/s, output: 100.36 toks/s]
# Processed prompts:  93%|█████████▎| 9283/9996 [01:32<00:07, 97.54it/s, est. speed input: 18914.24 toks/s, output: 100.37 toks/s]
# Processed prompts:  93%|█████████▎| 9294/9996 [01:32<00:07, 98.22it/s, est. speed input: 18912.99 toks/s, output: 100.37 toks/s]
# Processed prompts:  93%|█████████▎| 9306/9996 [01:32<00:06, 101.34it/s, est. speed input: 18913.85 toks/s, output: 100.38 toks/s]
# Processed prompts:  93%|█████████▎| 9317/9996 [01:32<00:06, 100.80it/s, est. speed input: 18912.39 toks/s, output: 100.38 toks/s]
# Processed prompts:  93%|█████████▎| 9329/9996 [01:32<00:06, 103.60it/s, est. speed input: 18913.36 toks/s, output: 100.39 toks/s]
# Processed prompts:  93%|█████████▎| 9340/9996 [01:33<00:06, 102.13it/s, est. speed input: 18911.71 toks/s, output: 100.39 toks/s]
# Processed prompts:  94%|█████████▎| 9352/9996 [01:33<00:06, 104.76it/s, est. speed input: 18912.76 toks/s, output: 100.40 toks/s]
# Processed prompts:  94%|█████████▎| 9363/9996 [01:33<00:06, 103.02it/s, est. speed input: 18911.20 toks/s, output: 100.40 toks/s]
# Processed prompts:  94%|█████████▍| 9375/9996 [01:33<00:05, 105.16it/s, est. speed input: 18912.05 toks/s, output: 100.41 toks/s]
# Processed prompts:  94%|█████████▍| 9386/9996 [01:33<00:05, 103.48it/s, est. speed input: 18910.64 toks/s, output: 100.41 toks/s]
# Processed prompts:  94%|█████████▍| 9398/9996 [01:33<00:05, 105.31it/s, est. speed input: 18911.34 toks/s, output: 100.42 toks/s]
# Processed prompts:  94%|█████████▍| 9409/9996 [01:33<00:05, 103.59it/s, est. speed input: 18909.88 toks/s, output: 100.42 toks/s]
# Processed prompts:  94%|█████████▍| 9421/9996 [01:33<00:05, 105.59it/s, est. speed input: 18910.60 toks/s, output: 100.43 toks/s]
# Processed prompts:  94%|█████████▍| 9432/9996 [01:33<00:05, 103.61it/s, est. speed input: 18908.96 toks/s, output: 100.43 toks/s]
# Processed prompts:  94%|█████████▍| 9444/9996 [01:34<00:05, 105.30it/s, est. speed input: 18909.46 toks/s, output: 100.44 toks/s]
# Processed prompts:  95%|█████████▍| 9456/9996 [01:34<00:05, 107.05it/s, est. speed input: 18910.35 toks/s, output: 100.45 toks/s]
# Processed prompts:  95%|█████████▍| 9467/9996 [01:34<00:05, 104.61it/s, est. speed input: 18908.72 toks/s, output: 100.45 toks/s]
# Processed prompts:  95%|█████████▍| 9479/9996 [01:34<00:04, 106.43it/s, est. speed input: 18909.52 toks/s, output: 100.46 toks/s]
# Processed prompts:  95%|█████████▍| 9490/9996 [01:34<00:04, 104.50it/s, est. speed input: 18908.11 toks/s, output: 100.46 toks/s]
# Processed prompts:  95%|█████████▌| 9502/9996 [01:34<00:04, 106.10it/s, est. speed input: 18908.73 toks/s, output: 100.47 toks/s]
# Processed prompts:  95%|█████████▌| 9513/9996 [01:34<00:04, 104.23it/s, est. speed input: 18907.30 toks/s, output: 100.47 toks/s]
# Processed prompts:  95%|█████████▌| 9525/9996 [01:34<00:04, 105.44it/s, est. speed input: 18907.59 toks/s, output: 100.48 toks/s]
# Processed prompts:  95%|█████████▌| 9537/9996 [01:34<00:04, 106.70it/s, est. speed input: 18908.17 toks/s, output: 100.49 toks/s]
# Processed prompts:  96%|█████████▌| 9548/9996 [01:35<00:04, 104.85it/s, est. speed input: 18906.89 toks/s, output: 100.49 toks/s]
# Processed prompts:  96%|█████████▌| 9560/9996 [01:35<00:04, 105.76it/s, est. speed input: 18907.11 toks/s, output: 100.50 toks/s]
# Processed prompts:  96%|█████████▌| 9571/9996 [01:35<00:04, 103.63it/s, est. speed input: 18905.42 toks/s, output: 100.50 toks/s]
# Processed prompts:  96%|█████████▌| 9583/9996 [01:35<00:03, 105.77it/s, est. speed input: 18906.24 toks/s, output: 100.51 toks/s]
# Processed prompts:  96%|█████████▌| 9594/9996 [01:35<00:03, 103.82it/s, est. speed input: 18904.70 toks/s, output: 100.51 toks/s]
# Processed prompts:  96%|█████████▌| 9606/9996 [01:35<00:03, 105.53it/s, est. speed input: 18905.25 toks/s, output: 100.52 toks/s]
# Processed prompts:  96%|█████████▌| 9618/9996 [01:35<00:03, 107.20it/s, est. speed input: 18906.12 toks/s, output: 100.53 toks/s]
# Processed prompts:  96%|█████████▋| 9629/9996 [01:35<00:03, 104.71it/s, est. speed input: 18904.51 toks/s, output: 100.53 toks/s]
# Processed prompts:  96%|█████████▋| 9641/9996 [01:35<00:03, 106.52it/s, est. speed input: 18905.28 toks/s, output: 100.54 toks/s]
# Processed prompts:  97%|█████████▋| 9652/9996 [01:36<00:03, 104.68it/s, est. speed input: 18903.87 toks/s, output: 100.54 toks/s]
# Processed prompts:  97%|█████████▋| 9664/9996 [01:36<00:03, 105.59it/s, est. speed input: 18903.92 toks/s, output: 100.55 toks/s]
# Processed prompts:  97%|█████████▋| 9676/9996 [01:36<00:02, 107.15it/s, est. speed input: 18904.60 toks/s, output: 100.56 toks/s]
# Processed prompts:  97%|█████████▋| 9687/9996 [01:36<00:02, 104.58it/s, est. speed input: 18902.83 toks/s, output: 100.56 toks/s]
# Processed prompts:  97%|█████████▋| 9699/9996 [01:36<00:02, 106.22it/s, est. speed input: 18903.36 toks/s, output: 100.57 toks/s]
# Processed prompts:  97%|█████████▋| 9710/9996 [01:36<00:02, 104.44it/s, est. speed input: 18901.94 toks/s, output: 100.57 toks/s]
# Processed prompts:  97%|█████████▋| 9722/9996 [01:36<00:02, 105.76it/s, est. speed input: 18902.22 toks/s, output: 100.58 toks/s]
# Processed prompts:  97%|█████████▋| 9734/9996 [01:36<00:02, 106.94it/s, est. speed input: 18902.68 toks/s, output: 100.59 toks/s]
# Processed prompts:  97%|█████████▋| 9745/9996 [01:36<00:02, 104.83it/s, est. speed input: 18901.19 toks/s, output: 100.59 toks/s]
# Processed prompts:  98%|█████████▊| 9757/9996 [01:36<00:02, 105.91it/s, est. speed input: 18901.39 toks/s, output: 100.60 toks/s]
# Processed prompts:  98%|█████████▊| 9769/9996 [01:37<00:02, 107.25it/s, est. speed input: 18901.99 toks/s, output: 100.61 toks/s]
# Processed prompts:  98%|█████████▊| 9780/9996 [01:37<00:02, 105.14it/s, est. speed input: 18900.56 toks/s, output: 100.61 toks/s]
# Processed prompts:  98%|█████████▊| 9792/9996 [01:37<00:01, 105.77it/s, est. speed input: 18900.52 toks/s, output: 100.61 toks/s]
# Processed prompts:  98%|█████████▊| 9804/9996 [01:37<00:01, 107.50it/s, est. speed input: 18901.35 toks/s, output: 100.63 toks/s]
# Processed prompts:  98%|█████████▊| 9815/9996 [01:37<00:01, 105.30it/s, est. speed input: 18899.92 toks/s, output: 100.63 toks/s]
# Processed prompts:  98%|█████████▊| 9827/9996 [01:37<00:01, 106.85it/s, est. speed input: 18900.53 toks/s, output: 100.64 toks/s]
# Processed prompts:  98%|█████████▊| 9838/9996 [01:37<00:01, 104.28it/s, est. speed input: 18898.69 toks/s, output: 100.63 toks/s]
# Processed prompts:  99%|█████████▊| 9850/9996 [01:37<00:01, 105.73it/s, est. speed input: 18898.92 toks/s, output: 100.64 toks/s]
# Processed prompts:  99%|█████████▊| 9862/9996 [01:37<00:01, 106.48it/s, est. speed input: 18898.96 toks/s, output: 100.65 toks/s]
# Processed prompts:  99%|█████████▉| 9874/9996 [01:38<00:01, 107.90it/s, est. speed input: 18899.59 toks/s, output: 100.66 toks/s]
# Processed prompts:  99%|█████████▉| 9885/9996 [01:38<00:01, 105.22it/s, est. speed input: 18897.82 toks/s, output: 100.66 toks/s]
# Processed prompts:  99%|█████████▉| 9897/9996 [01:38<00:00, 106.42it/s, est. speed input: 18898.07 toks/s, output: 100.67 toks/s]
# Processed prompts:  99%|█████████▉| 9909/9996 [01:38<00:00, 107.61it/s, est. speed input: 18898.54 toks/s, output: 100.68 toks/s]
# Processed prompts:  99%|█████████▉| 9920/9996 [01:38<00:00, 104.71it/s, est. speed input: 18896.46 toks/s, output: 100.68 toks/s]
# Processed prompts:  99%|█████████▉| 9932/9996 [01:38<00:00, 106.03it/s, est. speed input: 18896.55 toks/s, output: 100.69 toks/s]
# Processed prompts:  99%|█████████▉| 9944/9996 [01:38<00:00, 107.07it/s, est. speed input: 18896.73 toks/s, output: 100.70 toks/s]
# Processed prompts: 100%|█████████▉| 9956/9996 [01:38<00:00, 107.36it/s, est. speed input: 18896.62 toks/s, output: 100.71 toks/s]
# Processed prompts: 100%|█████████▉| 9968/9996 [01:38<00:00, 108.17it/s, est. speed input: 18896.88 toks/s, output: 100.72 toks/s]
# Processed prompts: 100%|█████████▉| 9979/9996 [01:39<00:00, 105.73it/s, est. speed input: 18895.12 toks/s, output: 100.72 toks/s]
# Processed prompts: 100%|██████████| 9996/9996 [01:39<00:00, 100.84it/s, est. speed input: 18915.02 toks/s, output: 100.84 toks/s]
# 1it [01:40, 100.55s/it]
# [2025-08-23 10:13:40,366] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:512)
# [2025-08-23 10:13:40,595] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:554)
# [2025-08-23 10:13:40,617] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:544)
# [2025-08-23 10:13:40,617] [    INFO]: Saving experiment tracker (evaluation_tracker.py:201)
# [2025-08-23 10:13:42,973] [    INFO]: Saving results to /content/minicomp-codes/evaluation/eval_results/truthfulqa-mc/results/hara-CU/minicompe-model/results_2025-08-23T10-13-40.617784.json (evaluation_tracker.py:277)
# [2025-08-23 10:13:42,974] [    INFO]: Saving details to /content/minicomp-codes/evaluation/eval_results/truthfulqa-mc/details/hara-CU/minicompe-model/2025-08-23T10-13-40.617784 (evaluation_tracker.py:321)
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 13.94ba/s]
# wandb: Currently logged in as: haraguchi (haraguchi-chiba-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/minicomp-codes/evaluation/wandb/run-20250823_101346-vsx2bykz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Drgrpo_2048_verify_plus_groq_short_length_bonus
# wandb: ⭐️ View project at https://wandb.ai/haraguchi-chiba-university/minicomp-test2
# wandb: 🚀 View run at https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/vsx2bykz
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# wandb: WARNING Serializing object of type str that is 380780 bytes
# wandb: WARNING Serializing object of type str that is 468456 bytes
# wandb: WARNING Serializing object of type str that is 431964 bytes
# wandb: WARNING Serializing object of type str that is 414326 bytes
# wandb: WARNING Serializing object of type str that is 516952 bytes
# wandb: WARNING Serializing object of type str that is 886404 bytes
# wandb: WARNING Serializing object of type str that is 432538 bytes
# wandb: WARNING Serializing object of type str that is 323192 bytes
# wandb: WARNING Serializing object of type str that is 541812 bytes
# wandb: WARNING Serializing object of type str that is 533510 bytes
# wandb: WARNING Serializing object of type str that is 466616 bytes
# wandb: WARNING Serializing object of type str that is 556126 bytes
# wandb: WARNING Serializing object of type str that is 576586 bytes
# wandb: WARNING Serializing object of type str that is 541276 bytes
# wandb: WARNING Serializing object of type str that is 456510 bytes
# wandb: WARNING Serializing object of type str that is 356290 bytes
# wandb: WARNING Serializing object of type str that is 458370 bytes
# wandb: WARNING Serializing object of type str that is 571916 bytes
# wandb: WARNING Serializing object of type str that is 862620 bytes
# wandb: WARNING Serializing object of type str that is 586200 bytes
# wandb: WARNING Serializing object of type str that is 350840 bytes
# wandb: WARNING Serializing object of type str that is 538836 bytes
# wandb: WARNING Serializing object of type str that is 350970 bytes
# wandb: WARNING Serializing object of type str that is 340906 bytes
# wandb: WARNING Serializing object of type str that is 382048 bytes
# wandb: WARNING Serializing object of type str that is 482450 bytes
# wandb: WARNING Serializing object of type str that is 391314 bytes
# wandb: WARNING Serializing object of type str that is 391716 bytes
# wandb: WARNING Serializing object of type str that is 375110 bytes
# wandb: WARNING Serializing object of type str that is 405280 bytes
# wandb:
# wandb:
# wandb: Run history:
# wandb:             aime24_math_pass@1:16_samples ▁
# wandb:      aime24_math_pass@1:16_samples_stderr ▁
# wandb:              aime24_math_pass@1:1_samples ▁
# wandb:       aime24_math_pass@1:1_samples_stderr ▁
# wandb:             aime24_math_pass@1:32_samples ▁
# wandb:      aime24_math_pass@1:32_samples_stderr ▁
# wandb:              aime24_math_pass@1:4_samples ▁
# wandb:       aime24_math_pass@1:4_samples_stderr ▁
# wandb:             aime24_math_pass@1:64_samples ▁
# wandb:      aime24_math_pass@1:64_samples_stderr ▁
# wandb:              aime24_math_pass@1:8_samples ▁
# wandb:       aime24_math_pass@1:8_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:1_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:1_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:4_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:4_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:8_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:8_samples_stderr ▁
# wandb:                    gsm8k_extractive_match ▁
# wandb:             gsm8k_extractive_match_stderr ▁
# wandb:                               toxigen_acc ▁
# wandb:                          toxigen_acc_norm ▁
# wandb:                   toxigen_acc_norm_stderr ▁
# wandb:                        toxigen_acc_stderr ▁
# wandb:              truthfulqa-mc_truthfulqa_mc1 ▁
# wandb:       truthfulqa-mc_truthfulqa_mc1_stderr ▁
# wandb:              truthfulqa-mc_truthfulqa_mc2 ▁
# wandb:       truthfulqa-mc_truthfulqa_mc2_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             aime24_math_pass@1:16_samples 0.01042
# wandb:      aime24_math_pass@1:16_samples_stderr 0.00852
# wandb:              aime24_math_pass@1:1_samples 0.03333
# wandb:       aime24_math_pass@1:1_samples_stderr 0.03333
# wandb:             aime24_math_pass@1:32_samples 0.01771
# wandb:      aime24_math_pass@1:32_samples_stderr 0.01569
# wandb:              aime24_math_pass@1:4_samples 0.00833
# wandb:       aime24_math_pass@1:4_samples_stderr 0.00833
# wandb:             aime24_math_pass@1:64_samples 0.01458
# wandb:      aime24_math_pass@1:64_samples_stderr 0.0126
# wandb:              aime24_math_pass@1:8_samples 0.0125
# wandb:       aime24_math_pass@1:8_samples_stderr 0.00919
# wandb:        gpqa-diamond_gpqa_pass@1:1_samples 0.33333
# wandb: gpqa-diamond_gpqa_pass@1:1_samples_stderr 0.03359
# wandb:        gpqa-diamond_gpqa_pass@1:4_samples 0.32449
# wandb: gpqa-diamond_gpqa_pass@1:4_samples_stderr 0.02393
# wandb:        gpqa-diamond_gpqa_pass@1:8_samples 0.31629
# wandb: gpqa-diamond_gpqa_pass@1:8_samples_stderr 0.02112
# wandb:                    gsm8k_extractive_match 0.80591
# wandb:             gsm8k_extractive_match_stderr 0.01089
# wandb:                               toxigen_acc 0.43191
# wandb:                          toxigen_acc_norm 0.43191
# wandb:                   toxigen_acc_norm_stderr 0.01616
# wandb:                        toxigen_acc_stderr 0.01616
# wandb:              truthfulqa-mc_truthfulqa_mc1 0.34884
# wandb:       truthfulqa-mc_truthfulqa_mc1_stderr 0.01668
# wandb:              truthfulqa-mc_truthfulqa_mc2 0.5
# wandb:       truthfulqa-mc_truthfulqa_mc2_stderr 0.01597
# wandb:
# wandb: 🚀 View run Drgrpo_2048_verify_plus_groq_short_length_bonus at: https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/vsx2bykz
# wandb: ⭐️ View project at: https://wandb.ai/haraguchi-chiba-university/minicomp-test2
# wandb: Synced 5 W&B file(s), 4 media file(s), 8 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250823_101346-vsx2bykz/logs
