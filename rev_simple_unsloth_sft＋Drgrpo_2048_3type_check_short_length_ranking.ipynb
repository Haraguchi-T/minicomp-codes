# %% [markdown]
# <a href="https://colab.research.google.com/github/Haraguchi-T/minicomp-codes/blob/main/rev_simple_unsloth_sft%EF%BC%8BDrgrpo_2048_3type_check_short_length_ranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## GRPOを行うためのシンプルなコード
#
# GRPOとはLLMにオンライン強化学習の一種です．
# 以下が簡単なフロー解説になります．
#
# １．まず学習対象のモデルである問題に対して複数生成します．(同じプロンプトで複数回生成する)
#
# ２．次に生成した各サンプルの解答を答え合わせします．あっていたら1点，間違っていたら0点を振ります．それ以外にも同時に色々なポイント(報酬)を与えます．
#
# ３．次に各生成サンプルの報酬を"相対化(報酬分布の正規化)"します．
#
# ４．最後に計算された相対的な報酬を元に勾配を更新(モデルパラメータの更新)をします．
#
# ５．これをループしていきます．![1_IBSrfnY3ULbBsxi6RD2kdg.jpg](data:image/jpeg;base64,...)
#
#
# GRPOを効果的に機能させるためには、まずモデルに基本的な回答フォーマットを学習させる必要があります。
# これをスキップすると、モデルが適切な形式で回答を生成できず、報酬関数が正しく機能しません。
# そのため、以下の流れで学習を行います：
#
# 1. **SFT（Supervised Fine-Tuning）**: 少量のデータで正しい回答フォーマットを学習
# 2. **GRPO**: 強化学習で回答の質を向上

# %% [markdown]
# ##必要なライブラリのインストール
# ※結構長いです．最後の方にエラーがでますが，一旦は無視できるので，ほっといて下さい()
#
# 今回は学習ライブラリとしてunslothを使います．シングルGPUに最適化した超高速学習ライブラリです．GRPOは仕組み上推論も同時に行うオンライン強化学習なので，推論ライブラリのvllmを使います．unslothは標準でvllmをサポートしており，公式でもこのセットが推奨されています．
#
# ※以下のインストールセルはipythonのカーネル再起動を要求することがあります．その通りセッションを再起動して再度実行してください．

# %%
# !pip install --no-deps unsloth vllm==0.8.5.post1

import sys, re, requests; modules = list(sys.modules.keys())
for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install math-verify[antlr4_13_2]
# !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" huggingface_hub hf_transfer pyyaml

# vLLMの公式要件ファイルを取得
f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
with open("vllm_requirements.txt", "wb") as file:
    file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f)) # 競合箇所の削除
# !pip install -r vllm_requirements.txt
# 暫定対応として追加
# 途中で聞かれるY/nは全てYを選択する
# !pip uninstall -y trl unsloth unsloth_zoo
# !pip install trl==0.19.1 unsloth==2025.7.8 unsloth_zoo==2025.7.10
# Out:
# Collecting unsloth
#   Downloading unsloth-2025.8.9-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 5.0 MB/s eta 0:00:00
# Collecting vllm==0.8.5.post1
#   Downloading vllm-0.8.5.post1-cp38-abi3-manylinux1_x86_64.whl.metadata (14 kB)
# Downloading vllm-0.8.5.post1-cp38-abi3-manylinux1_x86_64.whl (326.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 326.4/326.4 MB 66.5 MB/s eta 0:00:01

# %%
# !pip install vllm
# !pip install -U datasets
# !pip install fsspec==2023.9.2

# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
# !pip install --no-deps unsloth

# %%
# !pip list

# %% [markdown]
# huggingfaceのトークンを認証しておきます．
# トークンの取得方法は下記を参照してください．
# https://zenn.dev/protoout/articles/73-hugging-face-setup

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import userdata
from huggingface_hub import login
import wandb

HF_TOKEN = userdata.get('HF_TOKEN')
login(token=HF_TOKEN)

WANDB_API_KEY = userdata.get('wandb')
wandb.login(key=WANDB_API_KEY)

# %%
# !huggingface-cli login

# %%
# !git config --global credential.helper store

# %%
# !wandb login --relogin

# %%
import torch
import numpy as np
from datasets import load_dataset
from unsloth import FastLanguageModel
from transformers import TextStreamer
from trl import GRPOConfig, GRPOTrainer, SFTTrainer, SFTConfig
from vllm import SamplingParams
from math_verify import parse, verify
import re

# %% [markdown]
# ###諸々のconfigの準備

# %%
MAX_SEQ_LENGTH = 2048 # モデルの取り扱うことのできるコンテキストの最大量を設定します．
# MAX_SEQ_LENGTH = 4096
LORA_RANK = 64# LoRAのハイパーパラメータです．更新パラメータの量を決めます．
MODEL_NAME = "unsloth/Qwen3-4B"# unslothの用意した専用モデルです．基本これを使うことが推奨されています．
RUN_NAME = "Drgrpo_4096_5type_check_length_bonus_and_penalty" # 各自自分の実験だとわかるように書き換えてください。
LEARNED_MODEL_NAME = "hara-CU/minicompe-model" #学習したモデルを保存するHFのレポジトリです

# %%
# wandbの設定
import wandb

WANDB_PROJECT = "minicomp-test"
# RUN_NAME = "test" # 各自自分の実験だとわかるように書き換えてください。
wandb.init(
    project=WANDB_PROJECT,
    name=RUN_NAME,
)
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/content/wandb/run-20250821_035248-u71fv8vo</code>
# Syncing run <strong><a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test/runs/u71fv8vo' target="_blank">Drgrpo_4096_3type_check_length_cosine_penalty</a></strong> to <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test' target="_blank">https://wandb.ai/haraguchi-chiba-university/minicomp-test</a>
#  View run at <a href='https://wandb.ai/haraguchi-chiba-university/minicomp-test/runs/u71fv8vo' target="_blank">https://wandb.ai/haraguchi-chiba-university/minicomp-test/runs/u71fv8vo</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/haraguchi-chiba-university/minicomp-test/runs/u71fv8vo?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ##モデルとトークナイザーの準備
#
# 今回はUnslothのFastLanguageModelを使ってモデルをロードし，それに対してLoRA学習のためのアダプターをガッチャンします．
#
# LoRAとはLLMのtransformerアーキテクチャにおける各層に対して追加のパラメータをアダプター的にくっつけて，そこだけ学習するという手法です．使用するGPUのvramを全層を学習するより少なく済みます．

# %%
def prepare_model_and_tokenizer():
    """モデルとトークナイザーを準備"""
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_NAME,
        max_seq_length=MAX_SEQ_LENGTH,
        load_in_4bit=False,
        fast_inference=True,  # vLLM高速推論を有効化
        max_lora_rank=LORA_RANK,
        gpu_memory_utilization=0.8,
    )

    # LoRAアダプターの追加
    model = FastLanguageModel.get_peft_model(
        model,
        r=LORA_RANK,
        target_modules=[
            "q_proj", "k_proj", "v_proj", "o_proj",
            "gate_proj", "up_proj", "down_proj",
        ],# アダプターはLLMの線形層につけますが，ここでは一般的なところにつけときます．
        lora_alpha=LORA_RANK * 2,
        use_gradient_checkpointing="unsloth", # 勾配更新の計算方法ですね．unslothは独自のgradient_checkpoingの手法を持っています．
        random_state=3407,
    )

    return model, tokenizer

# %% [markdown]
# ## SFTのデータセットの準備
#
# SFTでは、モデルに正しい回答フォーマットを学習させます。
# Qwen3は<think>タグで思考過程を記述するreasoningモードを持っているので、ここでの効果はそこまでありませんが，一般にはSFTを活用してフォーマットを学習させます。
#
# 今回はMiroMindのデータセットをサンプリングして使います．

# %%
def prepare_sft_dataset():
    """SFT用のデータセットを準備（少量のサンプル）"""
    dataset = load_dataset("miromind-ai/MiroMind-M1-SFT-719K", split="train")

    # 少量のサンプルだけを使用（100件程度）
    dataset = dataset.select(range(min(1000, len(dataset))))

    def format_sft_data(example):
        """SFT用のフォーマット：問題と解答のペアを作成"""
        messages = [
            {"role": "user", "content": example["question"]},
            {"role": "assistant", "content": example['response']}
        ]

        # chat_templateを適用してテキスト化.Qwenではこのタイミングで勝手に
        text = tokenizer.apply_chat_template(messages, tokenize=False)
        return {"text": text}

    # データセットをフォーマット
    formatted_dataset = dataset.map(format_sft_data)

    # # トークン長でフィルタリング（長すぎるものを除外）
    # def filter_by_length(example):
    #     return len(tokenizer.encode(example["text"])) <= MAX_SEQ_LENGTH // 2
    # formatted_dataset = formatted_dataset.filter(filter_by_length)
    # ↑　これはやってもいいですが，max_tokenを超えた分についてはあとでtruncateされます．

    return formatted_dataset

# %% [markdown]
# ## trainerの定義と実行

# %%
def train_sft(model, tokenizer, sft_dataset, sft_config):
    """SFTでフォーマットを学習"""

    # SFTトレーナーの作成と実行
    sft_trainer = SFTTrainer(
        model=model,
        tokenizer=tokenizer,
        train_dataset=sft_dataset,
        args=sft_config,
    )

    print("#########学習開始#########")
    sft_trainer.train()

    return model

# %% [markdown]
# ### GRPOのデータセットを準備
#
# 今回はnvidiaのAIME攻略用の数学データセットを使います．
# unslothがサイズを小さくしたものを用意してくれているので，そのまま使います．ついでにprompt状態にしておきましょう．

# %%
def prepare_grpo_dataset(SYSTEM_PROMPT):
    """GRPOトレーニング用のデータセットを準備"""
    dataset = load_dataset("unsloth/OpenMathReasoning-mini", split="cot")

    """ データセットのフォーマット（シンプルな形式）
    今回はシステムプロンプトなし＋問題のプロンプトにします．Qwen3はOpenAIのmessage形式のchattemplateの対応しているので，以下のようにpromptを用意しておきます．
    Qwen3はシステムプロンプト無しを推奨しているようです．
    """
    def format_grpo_data(example): # 修正
        return {
            "prompt": [
                {"role": "user", "content": example["problem"]},
            ],
            "answer": example["expected_answer"],
        }

    dataset = dataset.map(format_grpo_data)
    return dataset

# %% [markdown]
# ## trainerの定義と実行
#
# unslothでもtrlやtransfomersなどと同様にtrainerを作って学習を回します．てか，基本trlをラップしているライブラリなんでそうなんですが．
#
# 今回はプロンプトの時点で最大トークンを超えている場合はそのデータはfilterしておく設定にしています．
#
# またQwen3はデフォルトでReasoningモードになっていることに注意です．

# %%
def train_grpo(model, tokenizer, dataset, reward_funcs, grpo_config):
    """GRPOトレーニングを実行（reasoning mode有効）"""

    trainer = GRPOTrainer(
        model=model,
        processing_class=tokenizer,
        reward_funcs=reward_funcs,
        args=grpo_config,
        train_dataset=dataset,
    )

    print("#########学習開始#########")
    trainer.train()
    return model

# %% [markdown]
# ## メインの実行処理

# %%
print("1. モデル準備...")
model, tokenizer = prepare_model_and_tokenizer()
# Out:
# 1. モデル準備...
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2025.7.8: Fast Qwen3 patching. Transformers: 4.55.2. vLLM: 0.8.5.post1.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/Qwen3-4B with actual GPU utilization = 79.08%
# Unsloth: Your GPU has CUDA compute capability 8.0 with VRAM = 39.56 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 4096. Num Sequences = 320.
# Unsloth: vLLM's KV Cache can use up to 24.22 GB. Also swap space = 6 GB.
# INFO 08-21 03:53:12 [config.py:717] This model supports multiple tasks: {'classify', 'reward', 'embed', 'score', 'generate'}. Defaulting to 'generate'.
# INFO 08-21 03:53:12 [config.py:2003] Chunked prefill is enabled with max_num_batched_tokens=4096.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# INFO 08-21 03:53:17 [core.py:58] Initializing a V1 LLM engine (v0.8.5.post1) with config: model='unsloth/Qwen3-4B', speculative_config=None, tokenizer='unsloth/Qwen3-4B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/Qwen3-4B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":3,"backend":"inductor","custom_ops":["none"],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":true,"trace.graph_diagram":false,"compile_threads":12,"combo_kernels":false,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":true,"enable_auto_functionalized_v2":false},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":512}
# WARNING 08-21 03:53:17 [utils.py:2522] Methods determine_num_available_blocks,device_config,get_cache_block_size_bytes,initialize_cache not implemented in <vllm.v1.worker.gpu_worker.Worker object at 0x7d261f476150>
# INFO 08-21 03:53:18 [parallel_state.py:1004] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 08-21 03:53:18 [cuda.py:221] Using Flash Attention backend on V1 engine.
# WARNING 08-21 03:53:18 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 08-21 03:53:18 [gpu_model_runner.py:1329] Starting to load model unsloth/Qwen3-4B...
# INFO 08-21 03:53:18 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# INFO 08-21 03:53:42 [weight_utils.py:281] Time spent downloading weights for unsloth/Qwen3-4B: 23.259998 seconds
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 08-21 03:53:44 [loader.py:458] Loading weights took 2.36 seconds
# INFO 08-21 03:53:44 [punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 08-21 03:53:45 [gpu_model_runner.py:1347] Model loading took 7.7585 GiB and 26.637352 seconds
# INFO 08-21 03:54:06 [backends.py:420] Using cache directory: /root/.cache/vllm/torch_compile_cache/ccc64a15a9/rank_0_0 for vLLM's torch.compile
# INFO 08-21 03:54:06 [backends.py:430] Dynamo bytecode transform time: 20.95 s
# Unsloth: Compiling kernels: 100%|██████████| 6/6 [00:01<00:00,  3.18it/s, triton_poi_fused_add_mul_sub_5]
# Unsloth: Compiling kernels: 100%|██████████| 6/6 [00:00<00:00, 75.50it/s, triton_poi_fused_add_mul_sub_5]
# INFO 08-21 03:54:31 [backends.py:136] Cache the graph of shape None for later use
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:01<00:00,  6.61it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 95.80it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 109.74it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.69it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.21it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.71it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 118.83it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 119.61it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.04it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.20it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 110.21it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 121.52it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 80.77it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 122.81it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.89it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 114.76it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 117.41it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 121.21it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.70it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 122.20it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 120.85it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.80it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.71it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.16it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.60it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 110.14it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 111.12it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 115.11it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.08it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 112.92it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.29it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 120.69it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 118.80it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 108.27it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 113.72it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 10/10 [00:00<00:00, 116.80it/s, triton_poi_fused_add_mul_sub_9]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 24.04it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 87.43it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# INFO 08-21 03:55:58 [backends.py:148] Compiling a graph for general shape takes 108.55 s
# INFO 08-21 03:56:08 [monitor.py:33] torch.compile takes 129.51 s in total
# INFO 08-21 03:56:09 [kv_cache_utils.py:634] GPU KV cache size: 154,368 tokens
# INFO 08-21 03:56:09 [kv_cache_utils.py:637] Maximum concurrency for 4,096 tokens per request: 37.69x
# INFO 08-21 03:56:09 [vllm_utils.py:641] Unsloth: Running patched vLLM v1 `capture_model`.
# INFO 08-21 03:56:43 [gpu_model_runner.py:1686] Graph capturing finished in 34 secs, took 0.84 GiB
# INFO 08-21 03:56:43 [vllm_utils.py:648] Unsloth: Patched vLLM v1 graph capture finished in 34 secs.
# INFO 08-21 03:56:44 [core.py:159] init engine (profile, create kv cache, warmup model) took 179.73 seconds
# Unsloth: Just some info: will skip parsing ['post_feedforward_layernorm', 'pre_feedforward_layernorm']
# Unsloth: Just some info: will skip parsing ['post_feedforward_layernorm', 'pre_feedforward_layernorm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth 2025.7.8 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### SFTの学習します

# %%
print("SFT用データセット準備中...")
sft_dataset = prepare_sft_dataset()
# Out:
# SFT用データセット準備中...
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/22 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/22 [00:00<?, ?files/s]
# train-00000-of-00022.parquet:   0%|          | 0.00/270M [00:00<?, ?B/s]
# train-00001-of-00022.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00002-of-00022.parquet:   0%|          | 0.00/250M [00:00<?, ?B/s]
# train-00003-of-00022.parquet:   0%|          | 0.00/269M [00:00<?, ?B/s]
# train-00004-of-00022.parquet:   0%|          | 0.00/265M [00:00<?, ?B/s]
# train-00005-of-00022.parquet:   0%|          | 0.00/206M [00:00<?, ?B/s]
# train-00006-of-00022.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
# train-00007-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00008-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00009-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00010-of-00022.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00011-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00012-of-00022.parquet:   0%|          | 0.00/169M [00:00<?, ?B/s]
# train-00013-of-00022.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00014-of-00022.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# train-00015-of-00022.parquet:   0%|          | 0.00/214M [00:00<?, ?B/s]
# train-00016-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00017-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00018-of-00022.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# train-00019-of-00022.parquet:   0%|          | 0.00/221M [00:00<?, ?B/s]
# train-00020-of-00022.parquet:   0%|          | 0.00/219M [00:00<?, ?B/s]
# train-00021-of-00022.parquet:   0%|          | 0.00/220M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/719232 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/21 [00:00<?, ?it/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# SFTの設定
sft_config = SFTConfig(
    dataset_text_field="text",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=2,
    warmup_ratio=0.1,
    num_train_epochs=2, # LLMのSFTだと一般的ですかね．
    learning_rate=2e-5,
    logging_steps=5,
    optim="adamw_torch",
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs_sft",
    report_to="wandb"
)

# %%
print("\n=== 2. SFT（教師あり学習）フェーズ ===")
print("まず、正しい回答フォーマットを学習させます...")
model = train_sft(model, tokenizer, sft_dataset, sft_config)
# Out:
# === 2. SFT（教師あり学習）フェーズ ===
# まず、正しい回答フォーマットを学習させます...
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/1000 [00:00<?, ? examples/s]
# #########学習開始#########
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 2 | Total steps = 500
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 2 x 1) = 4
#  "-____-"     Trainable parameters = 132,120,576 of 4,154,588,672 (3.18% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 24:21, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.547100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.528200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.563000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.506200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.465100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.526900</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.467300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.448300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.414600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.452300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.444000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.391400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.424900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.389700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.460600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.419700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.400100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.441300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.373400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.390500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.412500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.360300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.369400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.400200</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.392600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.419100</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.375100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.424800</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.401800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.359100</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.400100</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.386100</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.420100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.358100</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.393500</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.393300</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.479500</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.430600</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.412600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.385000</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.409200</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.390400</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.403500</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.431200</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.401600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.396500</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.435500</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.399000</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.367400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.450400</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.349100</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.381600</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.456200</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.373500</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.392200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.394400</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.348000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.427700</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.373200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.430300</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.392000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.410800</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.397700</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.399600</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.404300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.417300</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.382000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.410400</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.375500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.364400</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.360500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.391700</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.411200</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.361600</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.377400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.393400</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.386600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.392900</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.352200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.400200</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.339200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.388700</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.399700</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.434100</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.383900</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.421500</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.381300</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.356800</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.335500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.391400</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.439900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.401000</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>0.410800</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.369900</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.408400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.366200</td>
#     </tr>
#     <tr>
#       <td>485</td>
#       <td>0.371300</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.395400</td>
#     </tr>
#     <tr>
#       <td>495</td>
#       <td>0.392400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.390000</td>
#     </tr>
#   </tbody>
# </table><p>
# wandb: WARNING The get_url method is deprecated and will be removed in a future release. Please use `run.url` instead.

# %%
# 学習後のテスト
print("\n### SFT後のテスト生成 ###")
test_prompt = [{"role": "user", "content": "What is 15 + 23?"}]
inputs = tokenizer.apply_chat_template(
    test_prompt,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
).to("cuda")

with torch.no_grad():
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=512,
        temperature=0.1,
        do_sample=True,
        top_p=0.95,
    )

response = tokenizer.decode(outputs[0], skip_special_tokens=False)
print("生成例:")
print(response)
print("\n正しくreasoningフォーマットで生成できているか確認してください。")
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ### SFT後のテスト生成 ###
# 生成例:
# <|im_start|>user
# What is 15 + 23?<|im_end|>
# <|im_start|>assistant
# <think>
# Okay, let's see. The problem is 15 plus 23. Hmm, I need to add these two numbers together. Let me start by breaking them down. 15 is 10 plus 5, and 23 is 20 plus 3. So if I add the tens first, 10 plus 20 is 30. Then the ones: 5 plus 3 is 8. So 30 plus 8 is 38. Wait, that seems right. Let me check another way. Maybe counting up from 15. 15 plus 10 is 25, then plus 13 more would be 38. Yeah, that matches. Or maybe using a number line. Starting at 15, moving 20 to the right gets me to 35, then 3 more makes 38. All the methods point to 38. I think that's the correct answer.
# </think>
#
# 15 + 23 = 38<|im_end|>
#
# 正しくreasoningフォーマットで生成できているか確認してください。

# %%
# メモリ解放
if 'sft_trainer' in locals(): # 修正
    del sft_trainer
torch.cuda.empty_cache()
torch.cuda.ipc_collect()  # 修正

# %% [markdown]
# ### GRPO学習します．
#
# 今回はmaxstepを100にしているので，100step(設定上実質バッチサイズは8なので，データセットのうち800件で学習したことになります．)

# %%
print("\n=== 3. GRPO（強化学習）フェーズ ===")
print("GRPOデータセット準備中...")
# Add a placeholder SYSTEM_PROMPT as it's a required argument
grpo_dataset = prepare_grpo_dataset(SYSTEM_PROMPT="") # 修正

# トークン長を計算（enable_thinking=Trueで）
def get_token_length(example):
    return len(tokenizer.apply_chat_template(
        example["prompt"],
        add_generation_prompt=True,
        tokenize=True,
    ))

grpo_dataset = grpo_dataset.map(lambda x: {"token_length": get_token_length(x)})
max_prompt_length = int(np.quantile(grpo_dataset["token_length"], 0.9))
grpo_dataset = grpo_dataset.filter(lambda x: x["token_length"] <= max_prompt_length)

MAX_STEP = 100
grpo_config = GRPOConfig(
    temperature=0.6, # Qwen3の推奨値
    learning_rate=5e-6, #LoRAなんでやや高めで．
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    num_generations=4, # 同時に生成するサンプル数です．基本4以上が推奨です．ここを2にするとオンラインDPOを同じようなことをやっていることになります(lossの仕組みとか違いますが)
    max_prompt_length=max_prompt_length,
    max_completion_length=MAX_SEQ_LENGTH - max_prompt_length,
    max_steps = MAX_STEP,
    save_steps=100,
    loss_type="dr_grpo",
    output_dir="outputs",
    report_to="wandb"
)
# Out:
# === 3. GRPO（強化学習）フェーズ ===
# GRPOデータセット準備中...
# README.md:   0%|          | 0.00/603 [00:00<?, ?B/s]
# data/cot-00000-of-00001.parquet:   0%|          | 0.00/106M [00:00<?, ?B/s]
# Generating cot split:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Map:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/19252 [00:00<?, ? examples/s]
# Unsloth: The Dr GRPO paper recommends setting `scale_rewards` to False! Will override. Set it to `None` to force False.
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %%
max_prompt_length
# Out:
# 95

# %%
#@title reward_funcの引数
"""
reward_func args: []
reward_func kwargs:
{'prompts': 'list(len=32)',
'completions': 'list(len=32)',
'completion_ids': 'list(len=32)',
'expected_answer': 'list(len=32)',
'problem_type': 'list(len=32)',
 'problem_source': 'list(len=32)',
 'generation_model': 'list(len=32)',
 'pass_rate_72b_tir': 'list(len=32)',
  'problem': 'list(len=32)',
   'generated_solution': 'list(len=32)',
   'inference_mode': 'list(len=32)',
   'answer': 'list(len=32)',
    'token_length': 'list(len=32)'}

"""
# Out:
# "\nreward_func args: []\nreward_func kwargs:\n{'prompts': 'list(len=32)',\n'completions': 'list(len=32)',\n'completion_ids': 'list(len=32)',\n'expected_answer': 'list(len=32)',\n'problem_type': 'list(len=32)',\n 'problem_source': 'list(len=32)',\n 'generation_model': 'list(len=32)',\n 'pass_rate_72b_tir': 'list(len=32)',\n  'problem': 'list(len=32)',\n   'generated_solution': 'list(len=32)',\n   'inference_mode': 'list(len=32)',\n   'answer': 'list(len=32)',\n    'token_length': 'list(len=32)'}\n\n"

# %%
#@title 報酬関数設計


import re
import numpy as np
from math_verify import parse, verify
from sympy import sympify, simplify, N, expand, factor, trigsimp, lambdify
from math_verify import parse, verify
import math
from itertools import zip_longest



def math_verify_score(gold_answer,cleaned_response):
    if verify(parse(gold_answer), parse(cleaned_response)):
        score = 1.0
    else:
      score = 0

    return score



# -----------------------------
# 複雑な式の正規化
# -----------------------------




import re

def preprocess_expr(expr_str: str) -> str:
    """
    LaTeX 式を SymPy 互換形式に正規化
    """
    # 0. 不可視文字や制御文字を除去
    expr_str = re.sub(r'[\x00-\x1f\x7f]', '', expr_str)

    # 1. 特殊文字・関数名
    replacements = {
        r"\pi": "pi",
        "ln": "log",
        "tg": "tan",
        "arctg": "atan",
        "sh": "sinh",
        "ch": "cosh"
    }
    for k, v in replacements.items():
        expr_str = expr_str.replace(k, v)

    # 2. ローマ数字
    roman_map = {
        "Ⅰ": "1", "Ⅱ": "2", "Ⅲ": "3", "Ⅳ": "4", "Ⅴ": "5",
        "Ⅵ": "6", "Ⅶ": "7", "Ⅷ": "8", "Ⅸ": "9", "Ⅹ": "10"
    }
    for k, v in roman_map.items():
        expr_str = expr_str.replace(k, v)

    # 3. LaTeX 分数 \frac{a}{b} → (a)/(b)
    pattern_frac = r'\\frac\s*{([^{}]+)}{([^{}]+)}'
    while re.search(pattern_frac, expr_str):
        expr_str = re.sub(pattern_frac, r'(\1)/(\2)', expr_str)

    # 4. 累乗の {} 対応 a^{b} → a**(b)
    expr_str = re.sub(r'\^({([^{}]+)})', r'**(\2)', expr_str)
    # 4b. 単純な ^ も ** に変換
    expr_str = re.sub(r'\^([^\s\^{}]+)', r'**\1', expr_str)

    # 5. sqrt -> sqrt()
    expr_str = re.sub(r'\\sqrt{([^{}]+)}', r'sqrt(\1)', expr_str)
    expr_str = re.sub(r'\\sqrt([^\s^_()])', r'sqrt(\1)', expr_str)

    # 6. 三角関数 \func x → func(x)
    for func in ["sin", "cos", "tan", "asin", "acos", "atan", "sinh", "cosh", "tanh"]:
        expr_str = re.sub(rf'\\{func}\s*([^\s^_()]+)', rf'{func}(\1)', expr_str)

    # 7. 他の LaTeX ギリシャ文字（必要に応じて追加）
    greek_map = {
        r"\alpha": "alpha",
        r"\beta": "beta",
        r"\gamma": "gamma",
        r"\delta": "delta",
        r"\theta": "theta",
        r"\lambda": "lambda",
        r"\mu": "mu",
        r"\sigma": "sigma",
        r"\phi": "phi",
        r"\omega": "omega"
    }
    for k, v in greek_map.items():
        expr_str = expr_str.replace(k, v)

    # 8. 空白を削除
    expr_str = expr_str.replace(" ", "")

    return expr_str

def normalize_expr_advanced(expr_str):
    try:
        expr_str = preprocess_expr(expr_str)
        expr = sympify(expr_str)
        candidates = [simplify(expr), expand(expr), factor(expr), trigsimp(expr)]
        return min(candidates, key=lambda e: len(str(e)))
    except:
        return expr_str

# -----------------------------
# Algebra Score
# 左右反転の等式も考慮
# -----------------------------
def expr_similarity_advanced(pred_expr, ref_expr, expr_weight=1.0, max_penalty=10):
    pred_norm = normalize_expr_advanced(pred_expr)
    ref_norm = normalize_expr_advanced(ref_expr)
    try:
        # 順方向と逆方向の差を取る
        diff1 = N(simplify(pred_norm - ref_norm))
        diff2 = N(simplify(ref_norm - pred_norm))
        min_diff = min(abs(diff1), abs(diff2))
        score = max(0, 1 - min_diff / max_penalty)
        return score * expr_weight
    except:
        return 0.0


# -----------------------------
# Numeric Score（0〜1に安定化）
# -----------------------------
def expr_similarity_numeric_stable(pred_expr, ref_expr, points=None, expr_weight=1.0, max_penalty=10):
    """
    pred_expr, ref_expr: 評価対象の式（str）
    points: 複数点代入リスト
    expr_weight: 最終スコアの重み
    max_penalty: この値以上の差はスコア0に換算
    """
    if points is None:
        np.random.seed(42)
        points = [-10, -5, -1,1, 2, 3, 5, 10, 20, 50] + [np.random.uniform(-10,10) for _ in range(5)] # 複数点代入

    try:
        pred_norm = normalize_expr_advanced(pred_expr)
        ref_norm  = normalize_expr_advanced(ref_expr)
        vars_all = list(set(pred_norm.free_symbols) | set(ref_norm.free_symbols))

        # ラムダ化（numpy対応）
        f_pred = lambdify(vars_all, pred_norm, "numpy")
        f_ref  = lambdify(vars_all, ref_norm, "numpy")

        diffs = []
        for pt in points:
            vals = [pt for _ in vars_all]
            diff = abs(f_pred(*vals) - f_ref(*vals))
            diffs.append(diff)

        avg_diff = np.mean(diffs)
        max_diff = np.max(diffs)

        # 平均差と最大差の両方でスコアを算出
        score = max(0.0, 1 - (0.7*avg_diff + 0.3*max_diff) / max_penalty)
        score = min(score, 1.0)

        return score * expr_weight

    except Exception as e:
        return 0.0




# -----------------------------
# Paired Score（分数や pi も float近似）
# -----------------------------
def compute_pair_score(cleaned_response, gold_answer, pair_weight=1.0, tol=1e-4):
    # 数値抽出 & 安全変換
    def safe_extract(text):
        text = preprocess_expr(text)
        nums = []
        for n in re.findall(r'-?\d+\.?\d*', text):
            try:
                nums.append(float(n))
            except ValueError:
                continue
        # 分数も eval で float に変換
        for frac in re.findall(r'\d+\s*/\s*\d+', text):
            try:
                nums.append(eval(frac))
            except:
                continue
        # π も float 近似
        nums = [float(n) if n != 'pi' else math.pi for n in nums]
        return sorted(nums)

    nums_pred = safe_extract(cleaned_response)
    nums_ref  = safe_extract(gold_answer)

    denom = max(len(nums_pred), len(nums_ref), 1)
    matches = 0
    for p, r in zip_longest(nums_pred, nums_ref, fillvalue=None):
        if p is not None and r is not None:
            if math.isclose(p, r, rel_tol=tol, abs_tol=tol):
                matches += 1

    pair_score = (matches / denom) * pair_weight
    return pair_score

from itertools import zip_longest

# -----------------------------
# Keyword-based Text Score
# -----------------------------
def keyword_similarity_score(pred_text, ref_text, keywords=None, score_weight=1.0):
    """
    pred_text: ユーザの回答文字列
    ref_text: 正解文字列
    keywords: 評価に使う主要キーワードリスト
    score_weight: 最終スコアの重み
    """
    if keywords is None:
        # デフォルトの重要キーワード
        keywords = ["region", "convergence", "ROC", "C", "complex"]

    # 小文字化してトークン化
    pred_tokens = set(pred_text.lower().split())
    ref_tokens  = set(ref_text.lower().split())

    # 参照文のキーワードのみ残す
    ref_keywords = set([k.lower() for k in keywords if k.lower() in ref_tokens])

    if not ref_keywords:
        return 0.0  # 評価対象キーワードなし

    # 一致数 / キーワード総数でスコア化
    matches = len(pred_tokens & ref_keywords)
    score = matches / len(ref_keywords)

    return min(score, 1.0) * score_weight

# -----------------------------
# 長さペナルティ
# -----------------------------
def calc_length_penalty(completion_length, max_length, start_ratio=1):
    L_start = start_ratio * max_length
    max_length = max_length
    if completion_length <= L_start:
        return 1.0
    elif completion_length >= max_length:
        return 0.0
    else:
        ratio = (completion_length - L_start)/(max_length - L_start)
        return 0.5*(1 + np.cos(np.pi*ratio))

# -----------------------------
# 長さボーナス 満点回答のうち短い回答ほど高得点
# -----------------------------
def reward_length_rank_bonus(base_scores, token_lengths):
    # 満点回答のインデックス
    full_idx = [i for i, s in enumerate(base_scores) if s >= 1.0]
    n = len(full_idx)
    if n == 0:
        return base_scores

    # 満点回答を「短い順」にソート
    ranked = sorted(full_idx, key=lambda i: token_lengths[i])

    # スコアをコピーしてボーナス加算
    final_scores = base_scores.copy()
    for rank, i in enumerate(ranked):
        bonus = 1 - rank / n  # 短いほどボーナスが大きい
        final_scores[i] += bonus

    return final_scores

# -----------------------------
# 報酬関数（5種のスコアリングで表記ゆれに対応 + 長さペナルティ適用）
# -----------------------------
def reward_five_scoring_length_penalty(prompts, completions, expected_answer, token_length,
                            numeric_points=None, max_penalty=10, expr_weight=1.0,
                            tau=0.1, min_score=0.2, max_seq_length=4096, pair_weight=1.0,
                            **kwargs):
    # batch_size = len(completions)
    scores = []
    correct_flags = []

    for completion, gold_answer, comp_len in zip(completions, expected_answer, token_length):
        response = completion[0]["content"]
        length_penalty = calc_length_penalty(comp_len, max_seq_length)

        # thinkタグ形式チェック
        if not re.search(r'<think>.*?</think>', response, flags=re.DOTALL):
            score = 0.1 if re.search(r'<think>|</think>', response, flags=re.DOTALL) else 0.0
            score *= length_penalty
            scores.append(score)
            correct_flags.append(-1)
            continue

        cleaned_response = re.sub(r'<think>.*?</think>', '', response, flags=re.DOTALL)


        # スコアリング
        verify_score = math_verify_score(cleaned_response, gold_answer)
        pair_score = compute_pair_score(cleaned_response, gold_answer)
        algebra_score = expr_similarity_advanced(cleaned_response, gold_answer, expr_weight=1.0, max_penalty=10)
        numeric_score = expr_similarity_numeric_stable(cleaned_response, gold_answer, expr_weight=1.0)
        keyword_score = keyword_similarity_score(cleaned_response, gold_answer)

        # partial_score = max(verify_score, pair_score, algebra_score, numeric_score, keyword_score)
td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.008900</td>
#       <td>0.440625</td>
#       <td>0.136154</td>
#       <td>3597.281250</td>
#       <td>2005.000000</td>
#       <td>4001.000000</td>
#       <td>0.625000</td>
#       <td>2924.416748</td>
#       <td>2005.000000</td>
#       <td>3858.000000</td>
#       <td>0.183437</td>
#       <td>0.440625</td>
#       <td>0.440571</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.021700</td>
#       <td>0.643750</td>
#       <td>0.189974</td>
#       <td>3283.781250</td>
#       <td>1036.000000</td>
#       <td>4001.000000</td>
#       <td>0.437500</td>
#       <td>2725.944580</td>
#       <td>1036.000000</td>
#       <td>3947.000000</td>
#       <td>0.201095</td>
#       <td>0.643750</td>
#       <td>0.438426</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.017000</td>
#       <td>0.534375</td>
#       <td>0.183724</td>
#       <td>2928.781250</td>
#       <td>1391.000000</td>
#       <td>4001.000000</td>
#       <t
# WARNING:math_verify.grader:Timeout during comparison
# WARNING:math_verify.grader:Timeout during comparison
# WARNING:math_verify.grader:Timeout during comparison
# WARNING:math_verify.grader:Timeout during comparison

# %%
# テスト（reasoning modeで）
test_prompt = [{"role": "user", "content": "What is 25 + 37?"}]
inputs = tokenizer.apply_chat_template(
  test_prompt,
  tokenize=True,
  add_generation_prompt=True,
  return_tensors="pt"
).to("cuda")

print("\nReasoning mode出力例:")
outputs = model.generate(
  input_ids=inputs,
  max_new_tokens=2048,
  temperature=0.6,
  streamer=TextStreamer(tokenizer, skip_prompt=True),
)
# Out:
# Reasoning mode出力例:
# <think>
# Okay, let's see. I need to add 25 and 37. Hmm, how do I do that? Well, addition is when you combine two numbers. So, 25 plus 37. Let me break it down. Maybe I can add the tens first and then the ones.
#
# 25 has a 2 in the tens place and a 5 in the ones place. 37 has a 3 in the tens place and a 7 in the ones place. So, if I add the tens: 20 + 30. That should be 50. Then the ones: 5 + 7. That's 12. Now, add those two results together: 50 + 12. Wait, 50 plus 10 is 60, and then plus 2 more is 62. So, the total should be 62.
#
# Let me check another way to make sure. Maybe using the standard addition method.
#
#   25
# +37
# ----
# Starting from the rightmost digit: 5 + 7. That's 12. So, write down 2 and carry over 1. Then add the tens place: 2 + 3 + 1 (the carried over 1). That's 6. So, the result is 62.
#
# Hmm, both methods give me 62. I think that's correct. Let me just visualize it. If I have 25 apples and 37 oranges, how many fruits do I have in total? 25 + 37. Yeah, 25 plus 30 is 55, and then plus 7 more is 62. Yep, that makes sense.
#
# I don't see any mistakes here. The answer should be 62.
# </think>
#
# 25 + 37 = 62<|im_end|>

# %%
model = model.merge_and_unload()

# %%
model.push_to_hub(LEARNED_MODEL_NAME, revision=RUN_NAME)
tokenizer.push_to_hub(LEARNED_MODEL_NAME, revision=RUN_NAME)
# Out:
# README.md:   0%|          | 0.00/552 [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...6w/model-00002-of-00002.safetensors:   0%|          |  602kB / 3.08GB
#   ...6w/model-00001-of-00002.safetensors:   1%|          | 41.9MB / 4.97GB
# Saved model to https://huggingface.co/hara-CU/minicompe-model
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   /tmp/tmpa36smngq/tokenizer.json       : 100%|##########| 11.4MB / 11.4MB

# %%
from google.colab import runtime
runtime.unassign()

# %%
MAX_STEP = 100
max_prompt_length = 95
grpo_config = GRPOConfig(
    temperature=0.6, # Qwen3の推奨値
    learning_rate=5e-6, #LoRAなんでやや高めで．
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    num_generations=4, # 同時に生成するサンプル数です．基本4以上が推奨です．ここを2にするとオンラインDPOを同じようなことをやっていることになります(lossの仕組みとか違いますが)
    max_prompt_length=max_prompt_length,
    max_completion_length=MAX_SEQ_LENGTH - max_prompt_length,
    max_steps = MAX_STEP,
    save_steps=100,
    loss_type="dr_grpo",
    output_dir="outputs",
    report_to="wandb"
)
# Out:
# Unsloth: The Dr GRPO paper recommends setting `scale_rewards` to False! Will override. Set it to `None` to force False.
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %% [markdown]
# # 評価環境の構築
# - セッションが切れてしまった場合に、HFへのモデルのアップロードが終了していれば、インストール、HFとWandBへのログイン、sft_configとgrpo_configを設定するセルを再実行することで、以下を再実行できます。

# %%
# %%bash
# # 評価環境の作成
#
# git clone https://github.com/Haraguchi-T/minicomp-codes.git
# cd minicomp-codes
# cd evaluation
#
# bash install.sh
# Out:
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# Cloning into 'minicomp-codes'...
# downloading uv 0.8.12 x86_64-unknown-linux-gnu
# Downloading cpython-3.11.13-linux-x86_64-gnu (download) (27.7MiB)
#  Downloading cpython-3.11.13-linux-x86_64-gnu (download)
# Using CPython 3.11.13
# Creating virtual environment at: .venv
# Resolved 184 packages in 1ms
# Downloading nvidia-curand-cu12 (53.7MiB)
# Downloading numpy (17.4MiB)
# Downloading pandas (11.8MiB)
# Downloading pydantic-core (1.9MiB)
# Downloading pygments (1.2MiB)
# Downloading pyarrow (40.8MiB)
# Downloading llguidance (14.3MiB)
# Downloading pillow (6.3MiB)
# Downloading networkx (1.9MiB)
# Downloading lxml (5.0MiB)
# Downloading nvidia-cudnn-cu12 (544.5MiB)
# Downloading scipy (33.6MiB)
# Downloading aiohttp (1.6MiB)
# Downloading tokenizers (3.0MiB)
# Downloading nvidia-cusparse-cu12 (206.5MiB)
# Downloading hf-xet (3.0MiB)
# Downloading nvidia-cusparselt-cu12 (149.5MiB)
# Downloading sympy (6.0MiB)
# Downloading nvidia-cusolver-cu12 (150.9MiB)
# Downloading vllm (365.6MiB)
# Downloading mistral-common (6.2MiB)
# Downloading sentencepiece (1.2MiB)
# Downloading nvidia-nvjitlink-cu12 (18.8MiB)
# Downloading uvloop (3.8MiB)
# Downloading hf-transfer (3.4MiB)
# Downloading torchvision (7.1MiB)
# Downloading nvidia-cuda-cupti-cu12 (8.5MiB)
# Downloading llvmlite (40.4MiB)
# Downloading wandb (21.2MiB)
# Downloading transformers (10.3MiB)
# Downloading ray (66.8MiB)
# Downloading cupy-cuda12x (108.0MiB)
# Downloading xformers (30.1MiB)
# Downloading torchaudio (3.3MiB)
# Downloading nvidia-nccl-cu12 (192.0MiB)
# Downloading nvidia-cublas-cu12 (374.9MiB)
# Downloading opencv-python-headless (47.7MiB)
# Downloading nvidia-cufile-cu12 (1.1MiB)
# Downloading nvidia-cufft-cu12 (190.9MiB)
# Downloading numba (3.7MiB)
# Downloading nltk (1.4MiB)
# Downloading xgrammar (5.6MiB)
# Downloading torch (825.1MiB)
# Downloading nvidia-cuda-nvrtc-cu12 (22.6MiB)
# Downloading tiktoken (1.1MiB)
# Downloading scikit-learn (9.3MiB)
# Downloading triton (149.3MiB)
# Downloading pycountry (6.0MiB)
# Downloading setuptools (1.2MiB)
#  Downloading tiktoken
#  Downloading nvidia-cufile-cu12
#  Downloading sentencepiece
#  Downloading aiohttp
#  Downloading pygments
#  Downloading pydantic-core
#  Downloading nltk
#  Downloading setuptools
#  Downloading tokenizers
#  Downloading hf-xet
#  Downloading networkx
#  Downloading hf-transfer
#  Downloading torchaudio
#  Downloading uvloop
#  Downloading numba
#  Downloading xgrammar
#    Building rouge-score==0.1.2
#  Downloading lxml
#  Downloading pycountry
#  Downloading pillow
#  Downloading mistral-common
#  Downloading nvidia-cuda-cupti-cu12
#  Downloading torchvision
#  Downloading scikit-learn
#  Downloading sympy
#       Built rouge-score==0.1.2
#  Downloading transformers
#  Downloading llguidance
#  Downloading numpy
#  Downloading nvidia-nvjitlink-cu12
#  Downloading nvidia-cuda-nvrtc-cu12
#  Downloading pandas
#  Downloading wandb
#  Downloading xformers
#  Downloading scipy
#  Downloading llvmlite
#  Downloading nvidia-curand-cu12
#  Downloading opencv-python-headless
#  Downloading pyarrow
#  Downloading nvidia-cusparselt-cu12
#  Downloading nvidia-cusolver-cu12
#  Downloading triton
#  Downloading cupy-cuda12x
#  Downloading nvidia-cufft-cu12
#  Downloading nvidia-nccl-cu12
#  Downloading nvidia-cusparse-cu12
#  Downloading ray
#  Downloading nvidia-cublas-cu12
#  Downloading nvidia-cudnn-cu12
#  Downloading vllm
#  Downloading torch
# Prepared 177 packages in 1m 03s
# Installed 177 packages in 299ms
#  + absl-py==2.3.1
#  + accelerate==1.9.0
#  + aenum==3.1.15
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.14
#  + aiosignal==1.4.0
#  + airportsdata==20250706
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.13.2
#  + anyio==4.9.0
#  + astor==0.8.1
#  + attrs==25.3.0
#  + blake3==1.0.5
#  + cachetools==6.1.0
#  + certifi==2025.7.14
#  + chardet==5.2.0
#  + charset-normalizer==3.4.2
#  + click==8.2.1
#  + cloudpickle==3.1.1
#  + colorama==0.4.6
#  + colorlog==6.9.0
#  + compressed-tensors==0.10.2
#  + cupy-cuda12x==13.5.1
#  + dataproperty==1.1.0
#  + datasets==3.6.0
#  + depyf==0.18.0
#  + dill==0.3.8
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + dnspython==2.7.0
#  + einops==0.8.1
#  + email-validator==2.2.0
#  + fastapi==0.116.1
#  + fastapi-cli==0.0.8
#  + fastapi-cloud-cli==0.1.4
#  + fastrlock==0.8.3
#  + filelock==3.18.0
#  + frozenlist==1.7.0
#  + fsspec==2025.3.0
#  + gguf==0.17.1
#  + gitdb==4.0.12
#  + gitpython==3.1.45
#  + h11==0.16.0
#  + hf-transfer==0.1.9
#  + hf-xet==1.1.5
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + huggingface-hub==0.33.5
#  + idna==3.10
#  + interegular==0.3.3
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + joblib==1.5.1
#  + jsonschema==4.25.0
#  + jsonschema-specifications==2025.4.1
#  + lark==1.2.2
#  + latex2sympy2-extended==1.0.6
#  + lighteval==0.10.0
#  + llguidance==0.7.30
#  + llvmlite==0.44.0
#  + lm-format-enforcer==0.10.11
#  + lxml==6.0.0
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + mbstrdecoder==1.1.4
#  + mdurl==0.1.2
#  + mistral-common==1.8.2
#  + more-itertools==10.7.0
#  + mpmath==1.3.0
#  + msgpack==1.1.1
#  + msgspec==0.19.0
#  + multidict==6.6.3
#  + multiprocess==0.70.16
#  + nest-asyncio==1.6.0
#  + networkx==3.5
#  + ninja==1.11.1.4
#  + nltk==3.9.1
#  + numba==0.61.2
#  + numpy==1.26.4
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.6.3
#  + nvidia-nccl-cu12==2.26.2
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvtx-cu12==12.6.77
#  + openai==1.90.0
#  + opencv-python-headless==4.11.0.86
#  + outlines==0.1.11
#  + outlines-core==0.1.26
#  + packaging==25.0
#  + pandas==2.3.1
#  + partial-json-parser==0.2.1.1.post6
#  + pathvalidate==3.3.1
#  + pillow==11.3.0
#  + platformdirs==4.3.8
#  + portalocker==3.2.0
#  + prometheus-client==0.22.1
#  + prometheus-fastapi-instrumentator==7.1.0
#  + propcache==0.3.2
#  + protobuf==6.31.1
#  + psutil==7.0.0
#  + py-cpuinfo==9.0.0
#  + pyarrow==21.0.0
#  + pybase64==1.4.1
#  + pycountry==24.6.1
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydantic-extra-types==2.10.5
#  + pygments==2.19.2
#  + pytablewriter==1.2.1
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.1
#  + python-json-logger==3.3.0
#  + python-multipart==0.0.20
#  + pytz==2025.2
#  + pyyaml==6.0.2
#  + pyzmq==27.0.0
#  + ray==2.48.0
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.4
#  + rich==14.0.0
#  + rich-toolkit==0.14.8
#  + rignore==0.6.4
#  + rouge-score==0.1.2
#  + rpds-py==0.26.0
#  + sacrebleu==2.5.1
#  + safetensors==0.5.3
#  + scikit-learn==1.7.1
#  + scipy==1.16.0
#  + sentencepiece==0.2.0
#  + sentry-sdk==2.33.2
#  + setuptools==79.0.1
#  + shellingham==1.5.4
#  + six==1.17.0
#  + smmap==5.0.2
#  + sniffio==1.3.1
#  + starlette==0.47.2
#  + sympy==1.14.0
#  + tabledata==1.3.4
#  + tabulate==0.9.0
#  + tcolorpy==0.1.7
#  + termcolor==2.3.0
#  + threadpoolctl==3.6.0
#  + tiktoken==0.9.0
#  + tokenizers==0.21.2
#  + torch==2.7.0
#  + torchaudio==2.7.0
#  + torchvision==0.22.0
#  + tqdm==4.67.1
#  + transformers==4.53.3
#  + triton==3.3.0
#  + typepy==1.3.4
#  + typer==0.16.0
#  + typing-extensions==4.14.1
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uvicorn==0.35.0
#  + uvloop==0.21.0
#  + vllm==0.9.2
#  + wandb==0.21.0
#  + watchfiles==1.1.0
#  + websockets==15.0.1
#  + xformers==0.0.30
#  + xgrammar==0.1.19
#  + xxhash==3.5.0
#  + yarl==1.20.1

# %%
import json
report_sft_key = {"dataset_text_field",
        "per_device_train_batch_size",
        "gradient_accumulation_steps",
        "warmup_ratio",
        "num_train_epochs",
        "learning_rate",
        "logging_steps",
        "optim",
        "weight_decay",
        "lr_scheduler_type",
        "seed"}
report_grpo_key = {"temperature",
        "learning_rate",
        "per_device_train_batch_size",
        "gradient_accumulation_steps",
        "num_generations",
        "max_prompt_length",
        "max_completion_length",
        "max_steps"}
output_sft_config = {key: value for key, value in sft_config.to_dict().items() if key in report_sft_key}
output_grpo_config = {key: value for key, value in grpo_config.to_dict().items() if key in report_grpo_key}
output_grpo_config["reward_funcs"] = "--".join([func.__name__ for func in reward_funcs])

configs = {
    "run_name": RUN_NAME,
    "base_model_name": MODEL_NAME,
    "sft_config": output_sft_config,
    "grpo_config": output_grpo_config,
    "model_name": LEARNED_MODEL_NAME,
}

eval_code_path = "./minicomp-codes/evaluation"

with open(f"{eval_code_path}/train_configs.json", "w") as f:
    json.dump(configs, f)

# %%
import yaml
with open(f"{eval_code_path}/eval_config.yaml", "r") as f:
    eval_config = yaml.safe_load(f)

eval_config["model_parameters"]["model_name"] = LEARNED_MODEL_NAME
eval_config["model_parameters"]["revision"] = RUN_NAME
with open(f"{eval_code_path}/eval_config.yaml", "w") as f:
    yaml.dump(eval_config, f)

# %%
import gc, torch

if 'grpo_trainer' in locals(): # 修正
    del grpo_trainer
if "model" in locals():
  del model
gc.collect()
torch.cuda.empty_cache()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()  # 修正

# %% [markdown]
# # 評価の実行とwandbへのアップロード
# - GPUメモリが足りない場合があります。その場合はセッション再起動をして、ここからやり直してください。

# %%
# %%bash
# nvidia-smi
# Out:
# Thu Aug 21 09:16:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             63W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %%bash
# cd ./minicomp-codes/evaluation
# bash run.sh
# Out:
# INFO 08-21 09:16:47 [__init__.py:244] Automatically detected platform cuda.
# |      Task       |Version|     Metric     |Value|   |Stderr|
# |-----------------|------:|----------------|----:|---|-----:|
# |all              |       |extractive_match|0.793|±  |0.0112|
# |lighteval:gsm8k:0|      0|extractive_match|0.793|±  |0.0112|
#
# INFO 08-21 09:25:36 [__init__.py:244] Automatically detected platform cuda.
# |       Task       |Version|        Metric        |Value |   |Stderr|
# |------------------|------:|----------------------|-----:|---|-----:|
# |all               |       |math_pass@1:1_samples |0.0333|±  |0.0333|
# |                  |       |math_pass@1:4_samples |0.0250|±  |0.0250|
# |                  |       |math_pass@1:8_samples |0.0167|±  |0.0167|
# |                  |       |math_pass@1:16_samples|0.0146|±  |0.0126|
# |                  |       |math_pass@1:32_samples|0.0135|±  |0.0125|
# |                  |       |math_pass@1:64_samples|0.0151|±  |0.0135|
# |lighteval:aime24:0|      2|math_pass@1:1_samples |0.0333|±  |0.0333|
# |                  |       |math_pass@1:4_samples |0.0250|±  |0.0250|
# |                  |       |math_pass@1:8_samples |0.0167|±  |0.0167|
# |                  |       |math_pass@1:16_samples|0.0146|±  |0.0126|
# |                  |       |math_pass@1:32_samples|0.0135|±  |0.0125|
# |                  |       |math_pass@1:64_samples|0.0151|±  |0.0135|
#
# INFO 08-21 09:34:16 [__init__.py:244] Automatically detected platform cuda.
# |          Task          |Version|       Metric        |Value |   |Stderr|
# |------------------------|------:|---------------------|-----:|---|-----:|
# |all                     |       |gpqa_pass@1:1_samples|0.2828|±  |0.0321|
# |                        |       |gpqa_pass@1:4_samples|0.2904|±  |0.0234|
# |                        |       |gpqa_pass@1:8_samples|0.3030|±  |0.0209|
# |lighteval:gpqa:diamond:0|      1|gpqa_pass@1:1_samples|0.2828|±  |0.0321|
# |                        |       |gpqa_pass@1:4_samples|0.2904|±  |0.0234|
# |                        |       |gpqa_pass@1:8_samples|0.3030|±  |0.0209|
#
# INFO 08-21 09:41:53 [__init__.py:244] Automatically detected platform cuda.
# |       Task        |Version| Metric |Value |   |Stderr|
# |-------------------|------:|--------|-----:|---|-----:|
# |all                |       |acc     |0.4319|±  |0.0162|
# |                   |       |acc_norm|0.4319|±  |0.0162|
# |lighteval:toxigen:0|      0|acc     |0.4319|±  |0.0162|
# |                   |       |acc_norm|0.4319|±  |0.0162|
#
# INFO 08-21 09:43:40 [__init__.py:244] Automatically detected platform cuda.
# |           Task            |Version|    Metric    |Value |   |Stderr|
# |---------------------------|------:|--------------|-----:|---|-----:|
# |all                        |       |truthfulqa_mc1|0.3452|±  |0.0166|
# |                           |       |truthfulqa_mc2|0.5007|±  |0.0159|
# |leaderboard:truthfulqa:mc:0|      0|truthfulqa_mc1|0.3452|±  |0.0166|
# |                           |       |truthfulqa_mc2|0.5007|±  |0.0159|
#
# Loading evaluation results...
#
# Processing task: gsm8k
# Loading results from: eval_results/gsm8k/results/hara-CU/minicompe-model/results_2025-08-21T09-25-24.978688.json
#   Loaded 2 metrics
#
# Processing task: aime24
# Loading results from: eval_results/aime24/results/hara-CU/minicompe-model/results_2025-08-21T09-34-04.257574.json
#   Loaded 12 metrics
#
# Processing task: gpqa-diamond
# Loading results from: eval_results/gpqa-diamond/results/hara-CU/minicompe-model/results_2025-08-21T09-41-42.024817.json
#   Loaded 6 metrics
#
# Processing task: truthfulqa-mc
# Loading results from: eval_results/truthfulqa-mc/results/hara-CU/minicompe-model/results_2025-08-21T09-46-57.814524.json
#   Loaded 4 metrics
#
# Processing task: toxigen
# Loading results from: eval_results/toxigen/results/hara-CU/minicompe-model/results_2025-08-21T09-43-30.952679.json
#   Loaded 4 metrics
#
# Calculating averages...
# Calculated 6 average metrics
#
# === Task Results ===
#
# gsm8k:
#   extractive_match: 0.7930
#   extractive_match_stderr: 0.0112
#
# aime24:
#   math_pass@1:1_samples: 0.0333
#   math_pass@1:1_samples_stderr: 0.0333
#   math_pass@1:4_samples: 0.0250
#   math_pass@1:4_samples_stderr: 0.0250
#   math_pass@1:8_samples: 0.0167
#   math_pass@1:8_samples_stderr: 0.0167
#   math_pass@1:16_samples: 0.0146
#   math_pass@1:16_samples_stderr: 0.0126
#   math_pass@1:32_samples: 0.0135
#   math_pass@1:32_samples_stderr: 0.0125
#   math_pass@1:64_samples: 0.0151
#   math_pass@1:64_samples_stderr: 0.0135
#
# gpqa-diamond:
#   gpqa_pass@1:1_samples: 0.2828
#   gpqa_pass@1:1_samples_stderr: 0.0321
#   gpqa_pass@1:4_samples: 0.2904
#   gpqa_pass@1:4_samples_stderr: 0.0234
#   gpqa_pass@1:8_samples: 0.3030
#   gpqa_pass@1:8_samples_stderr: 0.0209
#
# truthfulqa-mc:
#   truthfulqa_mc1: 0.3452
#   truthfulqa_mc1_stderr: 0.0166
#   truthfulqa_mc2: 0.5007
#   truthfulqa_mc2_stderr: 0.0159
#
# toxigen:
#   acc: 0.4319
#   acc_stderr: 0.0162
#   acc_norm: 0.4319
#   acc_norm_stderr: 0.0162
#
# === Average Results ===
# Average metrics: 0.3716
#
# Uploading to wandb...
# Training Config Table logged
# Detail Metrics Table logged
# Evaluation Score Table logged
# Evaluation Samples Table logged
# Successfully uploaded to wandb!
# [2025-08-21 09:16:43,726] [    INFO]: PyTorch version 2.7.0 available. (config.py:54)
# [2025-08-21 09:16:50,357] [    INFO]: --- LOADING MODEL --- (pipeline.py:187)
# [2025-08-21 09:17:01,385] [    INFO]: This model supports multiple tasks: {'generate', 'classify', 'reward', 'embed'}. Defaulting to 'generate'. (config.py:841)
# [2025-08-21 09:17:01,386] [    INFO]: Using max model len 2048 (config.py:1472)
# [2025-08-21 09:17:01,387] [    INFO]: Chunked prefill is enabled with max_num_batched_tokens=2048. (config.py:2285)
# [2025-08-21 09:17:02,926] [    INFO]: Waiting for init message from front-end. (core.py:526)
# [2025-08-21 09:17:02,930] [    INFO]: Initializing a V1 LLM engine (v0.9.2) with config: model='hara-CU/minicompe-model', speculative_config=None, tokenizer='hara-CU/minicompe-model', skip_tokenizer_init=False, tokenizer_mode=auto, revision=Drgrpo_4096_3type_check_length_cosine_penalty, override_neuron_config={}, tokenizer_revision=Drgrpo_4096_3type_check_length_cosine_penalty, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=1, served_model_name=hara-CU/minicompe-model, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":512,"local_cache_dir":null} (core.py:69)
# [2025-08-21 09:17:04,714] [    INFO]: rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0 (parallel_state.py:1076)
# [2025-08-21 09:17:04,718] [ WARNING]: FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer. (topk_topp_sampler.py:59)
# [2025-08-21 09:17:04,744] [    INFO]: Starting to load model hara-CU/minicompe-model... (gpu_model_runner.py:1770)
# [2025-08-21 09:17:05,074] [    INFO]: Loading model from scratch... (gpu_model_runner.py:1775)
# [2025-08-21 09:17:05,220] [    INFO]: Using Flash Attention backend on V1 engine. (cuda.py:284)
# [2025-08-21 09:17:06,093] [    INFO]: Using model weights format ['*.safetensors'] (weight_utils.py:292)
# [2025-08-21 09:19:05,387] [    INFO]: Time spent downloading weights for hara-CU/minicompe-model: 119.293519 seconds (weight_utils.py:308)
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:00<00:00,  1.19it/s]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.17s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.12s/it]
#
# [2025-08-21 09:19:08,512] [    INFO]: Loading weights took 2.36 seconds (default_loader.py:272)
# [2025-08-21 09:19:09,151] [    INFO]: Model loading took 7.5552 GiB and 123.443111 seconds (gpu_model_runner.py:1801)
# [2025-08-21 09:19:23,232] [    INFO]: Using cache directory: /root/.cache/vllm/torch_compile_cache/38bad8171a/rank_0_0/backbone for vLLM's torch.compile (backends.py:508)
# [2025-08-21 09:19:23,232] [    INFO]: Dynamo bytecode transform time: 13.77 s (backends.py:519)
# [2025-08-21 09:19:30,271] [    INFO]: Cache the graph of shape None for later use (backends.py:181)
# [2025-08-21 09:20:13,361] [    INFO]: Compiling a graph for general shape takes 48.61 s (backends.py:193)
# [2025-08-21 09:20:32,474] [    INFO]: torch.compile takes 62.38 s in total (monitor.py:34)
# [2025-08-21 09:20:33,783] [    INFO]: Available KV cache memory: 27.25 GiB (gpu_worker.py:232)
# [2025-08-21 09:20:34,270] [    INFO]: GPU KV cache size: 198,384 tokens (kv_cache_utils.py:716)
# [2025-08-21 09:20:34,271] [    INFO]: Maximum concurrency for 2,048 tokens per request: 96.87x (kv_cache_utils.py:720)
# Capturing CUDA graph shapes: 100%|██████████| 67/67 [00:36<00:00,  1.85it/s]
# [2025-08-21 09:21:10,604] [    INFO]: Graph capturing finished in 36 secs, took 0.61 GiB (gpu_model_runner.py:2326)
# [2025-08-21 09:21:10,618] [    INFO]: init engine (profile, create kv cache, warmup model) took 121.47 seconds (core.py:172)
# [2025-08-21 09:21:11,702] [    INFO]: --- INIT SEEDS --- (pipeline.py:258)
# [2025-08-21 09:21:11,702] [    INFO]: --- LOADING TASKS --- (pipeline.py:212)
# [2025-08-21 09:21:11,703] [ WARNING]: If you want to use extended_tasks, make sure you installed their dependencies using `pip install -e .[extended_tasks]`. (registry.py:137)
# [2025-08-21 09:21:11,706] [    INFO]: gsm8k main (lighteval_task.py:187)
# Generating train split: 100%|██████████| 7473/7473 [00:00<00:00, 408982.81 examples/s]
# Generating test split: 100%|██████████| 1319/1319 [00:00<00:00, 280371.32 examples/s]
# [2025-08-21 09:21:23,534] [    INFO]: --- RUNNING MODEL --- (pipeline.py:482)
# [2025-08-21 09:21:23,534] [    INFO]: Running RequestType.GREEDY_UNTIL requests (pipeline.py:468)
# [2025-08-21 09:21:23,904] [ WARNING]: You cannot select the number of dataset splits for a generative evaluation at the moment. Automatically inferring. (data.py:237)
# Splits:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests:   0%|          | 0/1319 [00:00<?, ?it/s]
# Adding requests:  47%|████▋     | 621/1319 [00:00<00:00, 6208.11it/s]
# Adding requests: 100%|██████████| 1319/1319 [00:00<00:00, 6410.74it/s]
#
# Processed prompts:   0%|          | 0/1319 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts:   0%|          | 1/1319 [00:10<3:40:38, 10.04s/it, est. speed input: 10.65 toks/s, output: 42.31 toks/s]
# Processed prompts:   0%|          | 2/1319 [00:10<1:39:09,  4.52s/it, est. speed input: 20.29 toks/s, output: 82.21 toks/s]
# Processed prompts:   0%|          | 3/1319 [00:10<56:18,  2.57s/it, est. speed input: 30.62 toks/s, output: 122.77 toks/s]
# Processed prompts:   0%|          | 4/1319 [00:11<35:19,  1.61s/it, est. speed input: 41.40 toks/s, output: 163.26 toks/s]
# Processed prompts:   0%|          | 5/1319 [00:12<31:28,  1.44s/it, est. speed input: 48.06 toks/s, output: 190.18 toks/s]
# Processed prompts:   0%|          | 6/1319 [00:13<31:18,  1.43s/it, est. speed input: 51.79 toks/s, output: 211.63 toks/s]
# Processed prompts:   1%|          | 7/1319 [00:13<22:56,  1.05s/it, est. speed input: 58.22 toks/s, output: 248.56 toks/s]
# Processed prompts:   1%|          | 8/1319 [00:14<18:13,  1.20it/s, est. speed input: 64.89 toks/s, output: 282.90 toks/s]
# Processed prompts:   1%|          | 9/1319 [00:14<14:55,  1.46it/s, est. speed input: 72.36 toks/s, output: 317.07 toks/s]
# Processed prompts:   1%|          | 10/1319 [00:15<14:06,  1.55it/s, est. speed input: 76.45 toks/s, output: 345.71 toks/s]
# Processed prompts:   1%|          | 11/1319 [00:15<11:02,  1.97it/s, est. speed input: 82.27 toks/s, output: 381.76 toks/s]
# Processed prompts:   1%|          | 12/1319 [00:15<09:50,  2.21it/s, est. speed input: 87.70 toks/s, output: 414.15 toks/s]
# Processed prompts:   1%|          | 13/1319 [00:15<07:55,  2.74it/s, est. speed input: 94.86 toks/s, output: 450.23 toks/s]
# Processed prompts:   1%|          | 14/1319 [00:16<07:41,  2.83it/s, est. speed input: 99.36 toks/s, output: 481.07 toks/s]
# Processed prompts:  95%|█████████▍| 9480/9996 [01:35<00:05, 97.68it/s, est. speed input: 18688.76 toks/s, output: 99.29 toks/s]
# Processed prompts:  95%|█████████▍| 9492/9996 [01:35<00:05, 100.24it/s, est. speed input: 18689.35 toks/s, output: 99.30 toks/s]
# Processed prompts:  95%|█████████▌| 9503/9996 [01:35<00:04, 99.77it/s, est. speed input: 18687.86 toks/s, output: 99.30 toks/s]
# Processed prompts:  95%|█████████▌| 9515/9996 [01:35<00:04, 102.31it/s, est. speed input: 18688.65 toks/s, output: 99.31 toks/s]
# Processed prompts:  95%|█████████▌| 9526/9996 [01:35<00:04, 101.22it/s, est. speed input: 18687.16 toks/s, output: 99.31 toks/s]
# Processed prompts:  95%|█████████▌| 9538/9996 [01:36<00:04, 103.50it/s, est. speed input: 18687.92 toks/s, output: 99.32 toks/s]
# Processed prompts:  96%|█████████▌| 9549/9996 [01:36<00:04, 102.49it/s, est. speed input: 18686.79 toks/s, output: 99.32 toks/s]
# Processed prompts:  96%|█████████▌| 9561/9996 [01:36<00:04, 103.70it/s, est. speed input: 18686.99 toks/s, output: 99.33 toks/s]
# Processed prompts:  96%|█████████▌| 9573/9996 [01:36<00:04, 105.43it/s, est. speed input: 18687.81 toks/s, output: 99.34 toks/s]
# Processed prompts:  96%|█████████▌| 9584/9996 [01:36<00:03, 103.49it/s, est. speed input: 18686.45 toks/s, output: 99.34 toks/s]
# Processed prompts:  96%|█████████▌| 9596/9996 [01:36<00:03, 105.22it/s, est. speed input: 18687.21 toks/s, output: 99.35 toks/s]
# Processed prompts:  96%|█████████▌| 9607/9996 [01:36<00:03, 103.41it/s, est. speed input: 18685.91 toks/s, output: 99.35 toks/s]
# Processed prompts:  96%|█████████▌| 9619/9996 [01:36<00:03, 104.92it/s, est. speed input: 18686.49 toks/s, output: 99.36 toks/s]
# Processed prompts:  96%|█████████▋| 9630/9996 [01:36<00:03, 103.03it/s, est. speed input: 18685.08 toks/s, output: 99.36 toks/s]
# Processed prompts:  96%|█████████▋| 9642/9996 [01:37<00:03, 104.73it/s, est. speed input: 18685.68 toks/s, output: 99.37 toks/s]
# Processed prompts:  97%|█████████▋| 9654/9996 [01:37<00:03, 106.03it/s, est. speed input: 18686.26 toks/s, output: 99.38 toks/s]
# Processed prompts:  97%|█████████▋| 9665/9996 [01:37<00:03, 103.82it/s, est. speed input: 18684.75 toks/s, output: 99.38 toks/s]
# Processed prompts:  97%|█████████▋| 9677/9996 [01:37<00:03, 105.62it/s, est. speed input: 18685.49 toks/s, output: 99.40 toks/s]
# Processed prompts:  97%|█████████▋| 9688/9996 [01:37<00:02, 103.65it/s, est. speed input: 18684.07 toks/s, output: 99.40 toks/s]
# Processed prompts:  97%|█████████▋| 9700/9996 [01:37<00:02, 104.90it/s, est. speed input: 18684.39 toks/s, output: 99.40 toks/s]
# Processed prompts:  97%|█████████▋| 9712/9996 [01:37<00:02, 106.26it/s, est. speed input: 18685.05 toks/s, output: 99.42 toks/s]
# Processed prompts:  97%|█████████▋| 9723/9996 [01:37<00:02, 104.03it/s, est. speed input: 18683.59 toks/s, output: 99.42 toks/s]
# Processed prompts:  97%|█████████▋| 9735/9996 [01:37<00:02, 104.86it/s, est. speed input: 18683.71 toks/s, output: 99.42 toks/s]
# Processed prompts:  98%|█████████▊| 9747/9996 [01:38<00:02, 106.65it/s, est. speed input: 18684.64 toks/s, output: 99.44 toks/s]
# Processed prompts:  98%|█████████▊| 9758/9996 [01:38<00:02, 103.76it/s, est. speed input: 18682.82 toks/s, output: 99.43 toks/s]
# Processed prompts:  98%|█████████▊| 9770/9996 [01:38<00:02, 105.12it/s, est. speed input: 18683.24 toks/s, output: 99.44 toks/s]
# Processed prompts:  98%|█████████▊| 9782/9996 [01:38<00:02, 106.51it/s, est. speed input: 18683.96 toks/s, output: 99.46 toks/s]
# Processed prompts:  98%|█████████▊| 9793/9996 [01:38<00:01, 104.04it/s, est. speed input: 18682.40 toks/s, output: 99.45 toks/s]
# Processed prompts:  98%|█████████▊| 9805/9996 [01:38<00:01, 105.84it/s, est. speed input: 18683.17 toks/s, output: 99.47 toks/s]
# Processed prompts:  98%|█████████▊| 9816/9996 [01:38<00:01, 103.74it/s, est. speed input: 18681.73 toks/s, output: 99.47 toks/s]
# Processed prompts:  98%|█████████▊| 9828/9996 [01:38<00:01, 105.04it/s, est. speed input: 18682.10 toks/s, output: 99.47 toks/s]
# Processed prompts:  98%|█████████▊| 9840/9996 [01:38<00:01, 106.63it/s, est. speed input: 18682.88 toks/s, output: 99.49 toks/s]
# Processed prompts:  99%|█████████▊| 9851/9996 [01:39<00:01, 104.33it/s, est. speed input: 18681.35 toks/s, output: 99.49 toks/s]
# Processed prompts:  99%|█████████▊| 9863/9996 [01:39<00:01, 105.51it/s, est. speed input: 18681.65 toks/s, output: 99.50 toks/s]
# Processed prompts:  99%|█████████▉| 9875/9996 [01:39<00:01, 106.39it/s, est. speed input: 18681.98 toks/s, output: 99.51 toks/s]
# Processed prompts:  99%|█████████▉| 9887/9996 [01:39<00:01, 107.10it/s, est. speed input: 18682.37 toks/s, output: 99.52 toks/s]
# Processed prompts:  99%|█████████▉| 9898/9996 [01:39<00:00, 104.65it/s, est. speed input: 18680.84 toks/s, output: 99.52 toks/s]
# Processed prompts:  99%|█████████▉| 9910/9996 [01:39<00:00, 105.82it/s, est. speed input: 18681.19 toks/s, output: 99.53 toks/s]
# Processed prompts:  99%|█████████▉| 9922/9996 [01:39<00:00, 106.08it/s, est. speed input: 18681.05 toks/s, output: 99.53 toks/s]
# Processed prompts:  99%|█████████▉| 9934/9996 [01:39<00:00, 107.54it/s, est. speed input: 18681.75 toks/s, output: 99.55 toks/s]
# Processed prompts:  99%|█████████▉| 9945/9996 [01:39<00:00, 104.83it/s, est. speed input: 18680.04 toks/s, output: 99.55 toks/s]
# Processed prompts: 100%|█████████▉| 9957/9996 [01:40<00:00, 105.66it/s, est. speed input: 18680.08 toks/s, output: 99.55 toks/s]
# Processed prompts: 100%|█████████▉| 9969/9996 [01:40<00:00, 106.44it/s, est. speed input: 18680.22 toks/s, output: 99.56 toks/s]
# Processed prompts: 100%|█████████▉| 9981/9996 [01:40<00:00, 107.34it/s, est. speed input: 18680.51 toks/s, output: 99.57 toks/s]
# Processed prompts: 100%|██████████| 9996/9996 [01:40<00:00, 99.68it/s, est. speed input: 18698.81 toks/s, output: 99.68 toks/s]
# 1it [01:41, 101.50s/it]
# [2025-08-21 09:46:57,561] [    INFO]: --- COMPUTING METRICS --- (pipeline.py:512)
# [2025-08-21 09:46:57,792] [    INFO]: --- DISPLAYING RESULTS --- (pipeline.py:554)
# [2025-08-21 09:46:57,814] [    INFO]: --- SAVING AND PUSHING RESULTS --- (pipeline.py:544)
# [2025-08-21 09:46:57,814] [    INFO]: Saving experiment tracker (evaluation_tracker.py:201)
# [2025-08-21 09:47:00,111] [    INFO]: Saving results to /content/minicomp-codes/evaluation/eval_results/truthfulqa-mc/results/hara-CU/minicompe-model/results_2025-08-21T09-46-57.814524.json (evaluation_tracker.py:277)
# [2025-08-21 09:47:00,113] [    INFO]: Saving details to /content/minicomp-codes/evaluation/eval_results/truthfulqa-mc/details/hara-CU/minicompe-model/2025-08-21T09-46-57.814524 (evaluation_tracker.py:321)
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 13.48ba/s]
# wandb: Currently logged in as: haraguchi (haraguchi-chiba-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/minicomp-codes/evaluation/wandb/run-20250821_094704-pjo0sqoy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Drgrpo_4096_3type_check_length_cosine_penalty
# wandb: ⭐️ View project at https://wandb.ai/haraguchi-chiba-university/minicomp-test2
# wandb: 🚀 View run at https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/pjo0sqoy
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# /content/minicomp-codes/evaluation/upload_results.py:125: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["example", "predictions", "gold"]] = df[["example", "predictions", "gold"]].applymap(
# wandb: WARNING Serializing object of type str that is 112404 bytes
# wandb: WARNING Serializing object of type str that is 117916 bytes
# wandb: WARNING Serializing object of type str that is 381226 bytes
# wandb: WARNING Serializing object of type str that is 461400 bytes
# wandb: WARNING Serializing object of type str that is 428396 bytes
# wandb: WARNING Serializing object of type str that is 410622 bytes
# wandb: WARNING Serializing object of type str that is 509826 bytes
# wandb: WARNING Serializing object of type str that is 888616 bytes
# wandb: WARNING Serializing object of type str that is 432798 bytes
# wandb: WARNING Serializing object of type str that is 322414 bytes
# wandb: WARNING Serializing object of type str that is 540538 bytes
# wandb: WARNING Serializing object of type str that is 535144 bytes
# wandb: WARNING Serializing object of type str that is 469446 bytes
# wandb: WARNING Serializing object of type str that is 555660 bytes
# wandb: WARNING Serializing object of type str that is 571268 bytes
# wandb: WARNING Serializing object of type str that is 546836 bytes
# wandb: WARNING Serializing object of type str that is 457320 bytes
# wandb: WARNING Serializing object of type str that is 352082 bytes
# wandb: WARNING Serializing object of type str that is 451964 bytes
# wandb: WARNING Serializing object of type str that is 577000 bytes
# wandb: WARNING Serializing object of type str that is 423100 bytes
# wandb: WARNING Serializing object of type str that is 582510 bytes
# wandb: WARNING Serializing object of type str that is 350966 bytes
# wandb: WARNING Serializing object of type str that is 537940 bytes
# wandb: WARNING Serializing object of type str that is 353420 bytes
# wandb: WARNING Serializing object of type str that is 339898 bytes
# wandb: WARNING Serializing object of type str that is 381172 bytes
# wandb: WARNING Serializing object of type str that is 473966 bytes
# wandb: WARNING Serializing object of type str that is 388570 bytes
# wandb: WARNING Serializing object of type str that is 384554 bytes
# wandb: WARNING Serializing object of type str that is 374768 bytes
# wandb: WARNING Serializing object of type str that is 403718 bytes
# wandb: uploading artifact run-pjo0sqoy-DetailMetricsTable-361a325fdb35c10eb43ae97daba0ca19; uploading artifact run-pjo0sqoy-EvaluationScoreTable-b208397f5dc00ee275482ad11881a583; uploading artifact run-pjo0sqoy-EvaluationSamplesTable-13c700b1cd2992a3d1ea62b2f82c6f43; uploading media/table/Evaluation Samples Table_8_339cb01e4c334efe3ac2.table.json; uploading output.log (+ 2 more)
# wandb: uploading artifact run-pjo0sqoy-EvaluationSamplesTable-13c700b1cd2992a3d1ea62b2f82c6f43; uploading media/table/Evaluation Samples Table_8_339cb01e4c334efe3ac2.table.json
# wandb: uploading artifact run-pjo0sqoy-EvaluationSamplesTable-13c700b1cd2992a3d1ea62b2f82c6f43
# wandb:
# wandb:
# wandb: Run history:
# wandb:             aime24_math_pass@1:16_samples ▁
# wandb:      aime24_math_pass@1:16_samples_stderr ▁
# wandb:              aime24_math_pass@1:1_samples ▁
# wandb:       aime24_math_pass@1:1_samples_stderr ▁
# wandb:             aime24_math_pass@1:32_samples ▁
# wandb:      aime24_math_pass@1:32_samples_stderr ▁
# wandb:              aime24_math_pass@1:4_samples ▁
# wandb:       aime24_math_pass@1:4_samples_stderr ▁
# wandb:             aime24_math_pass@1:64_samples ▁
# wandb:      aime24_math_pass@1:64_samples_stderr ▁
# wandb:              aime24_math_pass@1:8_samples ▁
# wandb:       aime24_math_pass@1:8_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:1_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:1_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:4_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:4_samples_stderr ▁
# wandb:        gpqa-diamond_gpqa_pass@1:8_samples ▁
# wandb: gpqa-diamond_gpqa_pass@1:8_samples_stderr ▁
# wandb:                    gsm8k_extractive_match ▁
# wandb:             gsm8k_extractive_match_stderr ▁
# wandb:                               toxigen_acc ▁
# wandb:                          toxigen_acc_norm ▁
# wandb:                   toxigen_acc_norm_stderr ▁
# wandb:                        toxigen_acc_stderr ▁
# wandb:              truthfulqa-mc_truthfulqa_mc1 ▁
# wandb:       truthfulqa-mc_truthfulqa_mc1_stderr ▁
# wandb:              truthfulqa-mc_truthfulqa_mc2 ▁
# wandb:       truthfulqa-mc_truthfulqa_mc2_stderr ▁
# wandb:
# wandb: Run summary:
# wandb:             aime24_math_pass@1:16_samples 0.01458
# wandb:      aime24_math_pass@1:16_samples_stderr 0.0126
# wandb:              aime24_math_pass@1:1_samples 0.03333
# wandb:       aime24_math_pass@1:1_samples_stderr 0.03333
# wandb:             aime24_math_pass@1:32_samples 0.01354
# wandb:      aime24_math_pass@1:32_samples_stderr 0.01251
# wandb:              aime24_math_pass@1:4_samples 0.025
# wandb:       aime24_math_pass@1:4_samples_stderr 0.025
# wandb:             aime24_math_pass@1:64_samples 0.0151
# wandb:      aime24_math_pass@1:64_samples_stderr 0.01354
# wandb:              aime24_math_pass@1:8_samples 0.01667
# wandb:       aime24_math_pass@1:8_samples_stderr 0.01667
# wandb:        gpqa-diamond_gpqa_pass@1:1_samples 0.28283
# wandb: gpqa-diamond_gpqa_pass@1:1_samples_stderr 0.03209
# wandb:        gpqa-diamond_gpqa_pass@1:4_samples 0.2904
# wandb: gpqa-diamond_gpqa_pass@1:4_samples_stderr 0.02337
# wandb:        gpqa-diamond_gpqa_pass@1:8_samples 0.30303
# wandb: gpqa-diamond_gpqa_pass@1:8_samples_stderr 0.02094
# wandb:                    gsm8k_extractive_match 0.79303
# wandb:             gsm8k_extractive_match_stderr 0.01116
# wandb:                               toxigen_acc 0.43191
# wandb:                          toxigen_acc_norm 0.43191
# wandb:                   toxigen_acc_norm_stderr 0.01616
# wandb:                        toxigen_acc_stderr 0.01616
# wandb:              truthfulqa-mc_truthfulqa_mc1 0.34517
# wandb:       truthfulqa-mc_truthfulqa_mc1_stderr 0.01664
# wandb:              truthfulqa-mc_truthfulqa_mc2 0.50067
# wandb:       truthfulqa-mc_truthfulqa_mc2_stderr 0.01593
# wandb:
# wandb: 🚀 View run Drgrpo_4096_3type_check_length_cosine_penalty at: https://wandb.ai/haraguchi-chiba-university/minicomp-test2/runs/pjo0sqoy
# wandb: ⭐️ View project at: https://wandb.ai/haraguchi-chiba-university/minicomp-test2
# wandb: Synced 5 W&B file(s), 4 media file(s), 8 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250821_094704-pjo0sqoy/logs
